# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://media.licdn.com/dms/image/C4E0BAQFlOZSAJABP4w/company-logo_200_200/0/1548285168598?e=2147483647&v=beta&t=g4jl8rEhB7HLJuNZhU6OkJWHW4cul_y9Kj_aoD7p0_Y" alt="STI Logo" style="height: 98px;">
# </div>
#
#
# <h1>Point Selection for sFWRD</h1>
# By: Kayla Besong, PhD
#     <br>
# Last Edited: 05/21/24
# <br>
# <br>
# <br>
# Select the closest latitude, longitude point from a sFWRD file. The GACC stations are used here as an example for extraction. <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ## Import needed libraries, etc.

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from dask.distributed import Client, LocalCluster
import dask.array as da
import os
import glob

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## The integral notebook of functions to run + some others

# %%
# %run ../../../../Universal_Functions/File_concat_mod_functions.ipynb

# %%
def euclid(input_lat, input_lon, new_lat, new_lon):

    ''' Compute the euclidean distance!

    Inputs:

    input_lat: (float) the observational latitude
    input_lon: (float) the observational longitude
    new_lat: (float) the found model latitude
    new_lon: (float) the found model longitude
    
    Outputs:

    The euclidean distance: (float)

    '''
    
    return np.sqrt((new_lat - input_lat)**2 + (new_lon - input_lon)**2)

# %%
def latlon_sel(df, obs_lat, obs_lon):

    ''' Function that takes the input sFWRD dataset and selects the closest latitude/longitude to an observational point.
    Two methods are used to find the closest point, one is the average of 4 points forming a box around the observational point,
    the other is a single point. The smallest distance between the two methods to the observational point using euclidean distance is returned.
    This seems redundant but for models with high resolution, such as NCEP, the closest point using just euclidean distance of one point
    can be up to 2.5 degrees away from an observed location. 

    Inputs:

    df: (xarray dataset) the input dataset 
    obs_lat: (float) the observational latitude
    obs_lon: (float) the observational longitude
    
    Outputs:

    df_avg or df_euc: (xarray dataset) the returned xarray dataset either the box averaged or euclidean depending on which is closest to the point

    '''    
    
    northern_most = obs_lat + 1                                                                                          # Define the northernmost latitude boundary
    southern_most = obs_lat - 1                                                                                          # Define the southernmost latitude boundary

    eastern_most = obs_lon + 1                                                                                           # Define the easternmost longitude boundary
    western_most = obs_lon - 1                                                                                           # Define the westernmost longitude boundary

    df_avg = df.sel(latitude=slice(southern_most, northern_most), longitude=slice(western_most, eastern_most))           # Select a subset of the dataframe within the defined latitude and longitude boundaries

    distances = xr.apply_ufunc(euclid, obs_lat, obs_lon, df['latitude'], df['longitude'])                                # Compute the Euclidean distances between the observation point and all points in the dataframe
    y_sel_euc, x_sel_euc = np.unravel_index(distances.argmin(), distances.shape)                                         # Find the indices of the minimum distance
    df_euc = df.isel(latitude=y_sel_euc, longitude=x_sel_euc)                                                            # Select the point in the dataframe with the minimum distance

    dis_avg = euclid(obs_lat, obs_lon, float(df_avg.latitude.mean().values), float(df_avg.longitude.mean().values))      # Compute the Euclidean distance between the observation point and the average point in the subset
    dis_euc = euclid(obs_lat, obs_lon, float(df_euc.latitude.values), float(df_euc.longitude.values))                    # Compute the Euclidean distance between the observation point and the closest point

    if dis_avg < dis_euc:                                                                                                # Compare the distances

        return df_avg.mean('latitude').mean('longitude')                                                                 # Return the mean value of the subset if its distance is smaller

    else:

        return df_euc                                                                                                    # Return the closest point if its distance is smaller

# %% [markdown]
# ## Get observation files by variable and station

# %%
sites = pd.read_csv('obs/SiteList_LatLon.csv', sep = ',')

# %%
site_list = sites['Site'].values
site_list
# Out:
# array(['KPDX', 'KRDD', 'PHKO', 'KRAL', 'KSLC', 'PAFA', 'KABQ', 'KMSO',
#        'KDEN', 'KATL', 'KMKE'], dtype=object)

# %%
sites
# Out:
#     Site  Latitude  Longitude  Elevation-Ft  Elevation-Meter
# 0   KPDX  45.59578 -122.60917            20              6.1
# 1   KRDD  40.51461 -122.29770           499            152.1
# 2   PHKO  19.74083 -156.05056            43             13.1
# 3   KRAL  33.95189 -117.44511           819            249.6
# 4   KSLC  40.77069 -111.96503          4226           1288.0
# 5   PAFA  64.80389 -147.87611           433            132.0
# 6   KABQ  35.04167 -106.61472          5351           1630.9
# 7   KMSO  46.92083 -114.09250          3199            975.0
# 8   KDEN  39.84658 -104.65622          5404           1647.1
# 9   KATL  33.64028  -84.42694          1027            313.0
# 10  KMKE  42.95500  -87.90444           722            220.1

# %%
# vars = ['temp',
#          'rh',
#          'windspeed',
#          'winddir',
#          'windgust',
#          'precip_1hr',
#          'precip_24hr', 
#          'vpd', 
#          'hdwi']

# %%
obs_to_mod_var = {'temp': 't2',
                  'rh': 'rh',
                  'windspeed': 'ws',
                  'winddir': 'wd',
                  'windgust': 'gust',
                  'precip_1hr': 'tp',
                  'vpd': 'vpd',
                  'hdwi': 'hdw'  
}

# %%
models =  ['ERA5', 'NCEP', 'CONUS404', 'NAM', 'NARR', 'HRRR']

# %%
# %%time                                                                                                                                
                          
t = 'Abs'                                                                                                                             # Set the type of data to 'Abs'
                            
for sitename in site_list:                                                                                                            # Loop through each site name in site_list
                            
    dir_maker(f'obs/model_by_site/{sitename}')                                                                                        # Create a directory for the current site
                            
    print(f'{sitename} IS STARTING')                                                                                                  # Print a message indicating the start of processing for the current site
                                 
    for obs_v, mod_v in obs_to_mod_var.items():                                                                                       # Loop through each observation variable and its corresponding model variable
        
        obs = xr.open_mfdataset(glob.glob(os.path.join('obs/database_like_files', f'{obs_v}*{sitename}*{t}*.nc'))[0])                 # Open the observation dataset for the current variable and site
        
        obs_lat = float(obs.latitude.values)                                                                                          # Get the latitude of the observation site
        obs_lon = float(obs.longitude.values)                                                                                         # Get the longitude of the observation site
                                            
        for m in models:                                                                                                              # Loop through each model
                            
            dir_maker(f'obs/model_by_site/{sitename}/{m}')                                                                            # Create a directory for the current model
                            
            print(f'{m}: {mod_v}')                                                                                                    # Print a message indicating the current model and variable

            try:
            
                mod = xr.open_mfdataset(f'database_files_final/{m}/{mod_v}_{get_filename(m)}_{t}*.nc', chunks=get_chunk_sFWD(m))       # Open the model dataset for the current variable and model
                mod_sel = latlon_sel(mod, obs_lat, obs_lon)                                                                            # Select the data for the observation site's latitude and longitude
                                 
                mod_sel.to_netcdf(f'obs/model_by_site/{sitename}/{m}/{mod_v}_{m}_{sitename}.nc')                                       # Save the selected model data to a NetCDF file
                print(f'obs/model_by_site/{sitename}/{m}/{mod_v}_{m}_{sitename}.nc')                                                   # Print the path of the saved NetCDF file
                                             
                del mod_sel                                                
                                         
            except:                                                                                                                    # Handle exceptions
                             
                print(f'{m}: {mod_v} is not available')                                                                                # Print a message indicating the model variable is not available
                             
                                                                                                                                       # Delete the selected model data to free up memory
# Out:
# KPDX IS STARTING
# ERA5: t2
# obs/model_by_site/KPDX/ERA5/t2_ERA5_KPDX.nc
# NCEP: t2
# obs/model_by_site/KPDX/NCEP/t2_NCEP_KPDX.nc
# CONUS404: t2
# obs/model_by_site/KPDX/CONUS404/t2_CONUS404_KPDX.nc
# NAM: t2
# obs/model_by_site/KPDX/NAM/t2_NAM_KPDX.nc
# NARR: t2
# obs/model_by_site/KPDX/NARR/t2_NARR_KPDX.nc
# HRRR: t2
# obs/model_by_site/KPDX/HRRR/t2_HRRR_KPDX.nc
# ERA5: rh
# obs/model_by_site/KPDX/ERA5/rh_ERA5_KPDX.nc
# NCEP: rh
# obs/model_by_site/KPDX/NCEP/rh_NCEP_KPDX.nc
# CONUS404: rh
# obs/model_by_site/KPDX/CONUS404/rh_CONUS404_KPDX.nc
# NAM: rh
# obs/model_by_site/KPDX/NAM/rh_NAM_KPDX.nc
# NARR: rh
# obs/model_by_site/KPDX/NARR/rh_NARR_KPDX.nc
# HRRR: rh
# obs/model_by_site/KPDX/HRRR/rh_HRRR_KPDX.nc
# ERA5: ws
# obs/model_by_site/KPDX/ERA5/ws_ERA5_KPDX.nc
# NCEP: ws
# obs/model_by_site/KPDX/NCEP/ws_NCEP_KPDX.nc
# CONUS404: ws
# obs/model_by_site/KPDX/CONUS404/ws_CONUS404_KPDX.nc
# NAM: ws
# obs/model_by_site/KPDX/NAM/ws_NAM_KPDX.nc
# NARR: ws
# obs/model_by_site/KPDX/NARR/ws_NARR_KPDX.nc
# HRRR: ws
# obs/model_by_site/KPDX/HRRR/ws_HRRR_KPDX.nc
# ERA5: wd
# obs/model_by_site/KPDX/ERA5/wd_ERA5_KPDX.nc
# NCEP: wd
# obs/model_by_site/KPDX/NCEP/wd_NCEP_KPDX.nc
# CONUS404: wd
# obs/model_by_site/KPDX/CONUS404/wd_CONUS404_KPDX.nc
# NAM: wd
# obs/model_by_site/KPDX/NAM/wd_NAM_KPDX.nc
# NARR: wd
# obs/model_by_site/KPDX/NARR/wd_NARR_KPDX.nc
# HRRR: wd
# obs/model_by_site/KPDX/HRRR/wd_HRRR_KPDX.nc
# ERA5: gust
# obs/model_by_site/KPDX/ERA5/gust_ERA5_KPDX.nc
# NCEP: gust
# NCEP: gust is not available
# CONUS404: gust
# CONUS404: gust is not available
# NAM: gust
# obs/model_by_site/KPDX/NAM/gust_NAM_KPDX.nc
# NARR: gust
# NARR: gust is not available
# HRRR: gust
# obs/model_by_site/KPDX/HRRR/gust_HRRR_KPDX.nc
# ERA5: tp
# obs/model_by_site/KPDX/ERA5/tp_ERA5_KPDX.nc
# NCEP: tp
# NCEP: tp is not available
# CONUS404: tp
# obs/model_by_site/KPDX/CONUS404/tp_CONUS404_KPDX.nc
# NAM: tp
# obs/model_by_site/KPDX/NAM/tp_NAM_KPDX.nc
# NARR: tp
# obs/model_by_site/KPDX/NARR/tp_NARR_KPDX.nc
# HRRR: tp
# obs/model_by_site/KPDX/HRRR/tp_HRRR_KPDX.nc
# ERA5: vpd
# obs/model_by_site/KPDX/ERA5/vpd_ERA5_KPDX.nc
# NCEP: vpd
# obs/model_by_site/KPDX/NCEP/vpd_NCEP_KPDX.nc
# CONUS404: vpd
# obs/model_by_site/KPDX/CONUS404/vpd_CONUS404_KPDX.nc
# NAM: vpd
# obs/model_by_site/KPDX/NAM/vpd_NAM_KPDX.nc
# NARR: vpd
# obs/model_by_site/KPDX/NARR/vpd_NARR_KPDX.nc
# HRRR: vpd
# obs/model_by_site/KPDX/HRRR/vpd_HRRR_KPDX.nc
# ERA5: hdw
# obs/model_by_site/KPDX/ERA5/hdw_ERA5_KPDX.nc
# NCEP: hdw
# obs/model_by_site/KPDX/NCEP/hdw_NCEP_KPDX.nc
# CONUS404: hdw
# obs/model_by_site/KPDX/CONUS404/hdw_CONUS404_KPDX.nc
# NAM: hdw
# obs/model_by_site/KPDX/NAM/hdw_NAM_KPDX.nc
# NARR: hdw
# obs/model_by_site/KPDX/NARR/hdw_NARR_KPDX.nc
# HRRR: hdw
# obs/model_by_site/KPDX/HRRR/hdw_HRRR_KPDX.nc
# KRDD IS STARTING
# ERA5: t2
# obs/model_by_site/KRDD/ERA5/t2_ERA5_KRDD.nc
# NCEP: t2
# obs/model_by_site/KRDD/NCEP/t2_NCEP_KRDD.nc
# CONUS404: t2
# obs/model_by_site/KRDD/CONUS404/t2_CONUS404_KRDD.nc
# NAM: t2
# obs/model_by_site/KRDD/NAM/t2_NAM_KRDD.nc
# NARR: t2
# obs/model_by_site/KRDD/NARR/t2_NARR_KRDD.nc
# HRRR: t2
# obs/model_by_site/KRDD/HRRR/t2_HRRR_KRDD.nc
# ERA5: rh
# obs/model_by_site/KRDD/ERA5/rh_ERA5_KRDD.nc
# NCEP: rh
# obs/model_by_site/KRDD/NCEP/rh_NCEP_KRDD.nc
# CONUS404: rh
# obs/model_by_site/KRDD/CONUS404/rh_CONUS404_KRDD.nc
# NAM: rh
# obs/model_by_site/KRDD/NAM/rh_NAM_KRDD.nc
# NARR: rh
# obs/model_by_site/KRDD/NARR/rh_NARR_KRDD.nc
# HRRR: rh
# obs/model_by_site/KRDD/HRRR/rh_HRRR_KRDD.nc
# ERA5: ws
# obs/model_by_site/KRDD/ERA5/ws_ERA5_KRDD.nc
# NCEP: ws
# obs/model_by_site/KRDD/NCEP/ws_NCEP_KRDD.nc
# CONUS404: ws
# obs/model_by_site/KRDD/CONUS404/ws_CONUS404_KRDD.nc
# NAM: ws
# obs/model_by_site/KRDD/NAM/ws_NAM_KRDD.nc
# NARR: ws
# obs/model_by_site/KRDD/NARR/ws_NARR_KRDD.nc
# HRRR: ws
# obs/model_by_site/KRDD/HRRR/ws_HRRR_KRDD.nc
# ERA5: wd
# obs/model_by_site/KRDD/ERA5/wd_ERA5_KRDD.nc
# NCEP: wd
# obs/model_by_site/KRDD/NCEP/wd_NCEP_KRDD.nc
# CONUS404: wd
# obs/model_by_site/KRDD/CONUS404/wd_CONUS404_KRDD.nc
# NAM: wd
# obs/model_by_site/KRDD/NAM/wd_NAM_KRDD.nc
# NARR: wd
# obs/model_by_site/KRDD/NARR/wd_NARR_KRDD.nc
# HRRR: wd
# obs/model_by_site/KRDD/HRRR/wd_HRRR_KRDD.nc
# ERA5: gust
# obs/model_by_site/KRDD/ERA5/gust_ERA5_KRDD.nc
# NCEP: gust
# NCEP: gust is not available
# CONUS404: gust
# CONUS404: gust is not available
# NAM: gust
# obs/model_by_site/KRDD/NAM/gust_NAM_KRDD.nc
# NARR: gust
# NARR: gust is not available
# HRRR: gust
# obs/model_by_site/KRDD/HRRR/gust_HRRR_KRDD.nc
# ERA5: tp
# obs/model_by_site/KRDD/ERA5/tp_ERA5_KRDD.nc
# NCEP: tp
# NCEP: tp is not available
# CONUS404: tp
# obs/model_by_site/KRDD/CONUS404/tp_CONUS404_KRDD.nc
# NAM: tp
# obs/model_by_site/KRDD/NAM/tp_NAM_KRDD.nc
# NARR: tp
# obs/model_by_site/KRDD/NARR/tp_NARR_KRDD.nc
# HRRR: tp
# obs/model_by_site/KRDD/HRRR/tp_HRRR_KRDD.nc
# ERA5: vpd
# obs/model_by_site/KRDD/ERA5/vpd_ERA5_KRDD.nc
# NCEP: vpd
# obs/model_by_site/KRDD/NCEP/vpd_NCEP_KRDD.nc
# CONUS404: vpd
# obs/model_by_site/KRDD/CONUS404/vpd_CONUS404_KRDD.nc
# NAM: vpd
# obs/model_by_site/KRDD/NAM/vpd_NAM_KRDD.nc
# NARR: vpd
# obs/model_by_site/KRDD/NARR/vpd_NARR_KRDD.nc
# HRRR: vpd
# obs/model_by_site/KRDD/HRRR/vpd_HRRR_KRDD.nc
# ERA5: hdw
# obs/model_by_site/KRDD/ERA5/hdw_ERA5_KRDD.nc
# NCEP: hdw
# obs/model_by_site/KRDD/NCEP/hdw_NCEP_KRDD.nc
# CONUS404: hdw
# obs/model_by_site/KRDD/CONUS404/hdw_CONUS404_KRDD.nc
# NAM: hdw
# obs/model_by_site/KRDD/NAM/hdw_NAM_KRDD.nc
# NARR: hdw
# obs/model_by_site/KRDD/NARR/hdw_NARR_KRDD.nc
# HRRR: hdw
# obs/model_by_site/KRDD/HRRR/hdw_HRRR_KRDD.nc
# PHKO IS STARTING
# ERA5: t2
# obs/model_by_site/PHKO/ERA5/t2_ERA5_PHKO.nc
# NCEP: t2
# obs/model_by_site/PHKO/NCEP/t2_NCEP_PHKO.nc
# CONUS404: t2
# obs/model_by_site/PHKO/CONUS404/t2_CONUS404_PHKO.nc
# NAM: t2
# obs/model_by_site/PHKO/NAM/t2_NAM_PHKO.nc
# NARR: t2
# obs/model_by_site/PHKO/NARR/t2_NARR_PHKO.nc
# HRRR: t2
# obs/model_by_site/PHKO/HRRR/t2_HRRR_PHKO.nc
# ERA5: rh
# obs/model_by_site/PHKO/ERA5/rh_ERA5_PHKO.nc
# NCEP: rh
# obs/model_by_site/PHKO/NCEP/rh_NCEP_PHKO.nc
# CONUS404: rh
# obs/model_by_site/PHKO/CONUS404/rh_CONUS404_PHKO.nc
# NAM: rh
# obs/model_by_site/PHKO/NAM/rh_NAM_PHKO.nc
# NARR: rh
# obs/model_by_site/PHKO/NARR/rh_NARR_PHKO.nc
# HRRR: rh
# obs/model_by_site/PHKO/HRRR/rh_HRRR_PHKO.nc
# ERA5: ws
# obs/model_by_site/PHKO/ERA5/ws_ERA5_PHKO.nc
# NCEP: ws
# obs/model_by_site/PHKO/NCEP/ws_NCEP_PHKO.nc
# CONUS404: ws
# obs/model_by_site/PHKO/CONUS404/ws_CONUS404_PHKO.nc
# NAM: ws
# obs/model_by_site/PHKO/NAM/ws_NAM_PHKO.nc
# NARR: ws
# obs/model_by_site/PHKO/NARR/ws_NARR_PHKO.nc
# HRRR: ws
# obs/model_by_site/PHKO/HRRR/ws_HRRR_PHKO.nc
# ERA5: wd
# obs/model_by_site/PHKO/ERA5/wd_ERA5_PHKO.nc
# NCEP: wd
# obs/model_by_site/PHKO/NCEP/wd_NCEP_PHKO.nc
# CONUS404: wd
# obs/model_by_site/PHKO/CONUS404/wd_CONUS404_PHKO.nc
# NAM: wd
# obs/model_by_site/PHKO/NAM/wd_NAM_PHKO.nc
# NARR: wd
# obs/model_by_site/PHKO/NARR/wd_NARR_PHKO.nc
# HRRR: wd
# obs/model_by_site/PHKO/HRRR/wd_HRRR_PHKO.nc
# ERA5: gust
# obs/model_by_site/PHKO/ERA5/gust_ERA5_PHKO.nc
# NCEP: gust
# NCEP: gust is not available
# CONUS404: gust
# CONUS404: gust is not available
# NAM: gust
# obs/model_by_site/PHKO/NAM/gust_NAM_PHKO.nc
# NARR: gust
# NARR: gust is not available
# HRRR: gust
# obs/model_by_site/PHKO/HRRR/gust_HRRR_PHKO.nc
# ERA5: tp
# obs/model_by_site/PHKO/ERA5/tp_ERA5_PHKO.nc
# NCEP: tp
# NCEP: tp is not available
# CONUS404: tp
# obs/model_by_site/PHKO/CONUS404/tp_CONUS404_PHKO.nc
# NAM: tp
# obs/model_by_site/PHKO/NAM/tp_NAM_PHKO.nc
# NARR: tp
# obs/model_by_site/PHKO/NARR/tp_NARR_PHKO.nc
# HRRR: tp
# obs/model_by_site/PHKO/HRRR/tp_HRRR_PHKO.nc
# ERA5: vpd
# obs/model_by_site/PHKO/ERA5/vpd_ERA5_PHKO.nc
# NCEP: vpd
# obs/model_by_site/PHKO/NCEP/vpd_NCEP_PHKO.nc
# CONUS404: vpd
# obs/model_by_site/PHKO/CONUS404/vpd_CONUS404_PHKO.nc
# NAM: vpd
# obs/model_by_site/PHKO/NAM/vpd_NAM_PHKO.nc
# NARR: vpd
# obs/model_by_site/PHKO/NARR/vpd_NARR_PHKO.nc
# HRRR: vpd
# obs/model_by_site/PHKO/HRRR/vpd_HRRR_PHKO.nc
# ERA5: hdw
# obs/model_by_site/PHKO/ERA5/hdw_ERA5_PHKO.nc
# NCEP: hdw
# obs/model_by_site/PHKO/NCEP/hdw_NCEP_PHKO.nc
# CONUS404: hdw
# obs/model_by_site/PHKO/CONUS404/hdw_CONUS404_PHKO.nc
# NAM: hdw
# obs/model_by_site/PHKO/NAM/hdw_NAM_PHKO.nc
# NARR: hdw
# obs/model_by_site/PHKO/NARR/hdw_NARR_PHKO.nc
# HRRR: hdw
# obs/model_by_site/PHKO/HRRR/hdw_HRRR_PHKO.nc
# KRAL IS STARTING
# ERA5: t2
# obs/model_by_site/KRAL/ERA5/t2_ERA5_KRAL.nc
# NCEP: t2
# obs/model_by_site/KRAL/NCEP/t2_NCEP_KRAL.nc
# CONUS404: t2
# obs/model_by_site/KRAL/CONUS404/t2_CONUS404_KRAL.nc
# NAM: t2
# obs/model_by_site/KRAL/NAM/t2_NAM_KRAL.nc
# NARR: t2
# obs/model_by_site/KRAL/NARR/t2_NARR_KRAL.nc
# HRRR: t2
# obs/model_by_site/KRAL/HRRR/t2_HRRR_KRAL.nc
# ERA5: rh
# obs/model_by_site/KRAL/ERA5/rh_ERA5_KRAL.nc
# NCEP: rh
# obs/model_by_site/KRAL/NCEP/rh_NCEP_KRAL.nc
# CONUS404: rh
# obs/model_by_site/KRAL/CONUS404/rh_CONUS404_KRAL.nc
# NAM: rh
# obs/model_by_site/KRAL/NAM/rh_NAM_KRAL.nc
# NARR: rh
# obs/model_by_site/KRAL/NARR/rh_NARR_KRAL.nc
# HRRR: rh
# obs/model_by_site/KRAL/HRRR/rh_HRRR_KRAL.nc
# ERA5: ws
# obs/model_by_site/KRAL/ERA5/ws_ERA5_KRAL.nc
# NCEP: ws
# obs/model_by_site/KRAL/NCEP/ws_NCEP_KRAL.nc
# CONUS404: ws
# obs/model_by_site/KRAL/CONUS404/ws_CONUS404_KRAL.nc
# NAM: ws
# obs/model_by_site/KRAL/NAM/ws_NAM_KRAL.nc
# NARR: ws
# obs/model_by_site/KRAL/NARR/ws_NARR_KRAL.nc
# HRRR: ws
# obs/model_by_site/KRAL/HRRR/ws_HRRR_KRAL.nc
# ERA5: wd
# obs/model_by_site/KRAL/ERA5/wd_ERA5_KRAL.nc
# NCEP: wd
# obs/model_by_site/KRAL/NCEP/wd_NCEP_KRAL.nc
# CONUS404: wd
# obs/model_by_site/KRAL/CONUS404/wd_CONUS404_KRAL.nc
# NAM: wd
# obs/model_by_site/KRAL/NAM/wd_NAM_KRAL.nc
# NARR: wd
# obs/model_by_site/KRAL/NARR/wd_NARR_KRAL.nc
# HRRR: wd
# obs/model_by_site/KRAL/HRRR/wd_HRRR_KRAL.nc
# ERA5: gust
# obs/model_by_site/KRAL/ERA5/gust_ERA5_KRAL.nc
# NCEP: gust
# NCEP: gust is not available
# CONUS404: gust
# CONUS404: gust is not available
# NAM: gust
# obs/model_by_site/KRAL/NAM/gust_NAM_KRAL.nc
# NARR: gust
# NARR: gust is not available
# HRRR: gust
# obs/model_by_site/KRAL/HRRR/gust_HRRR_KRAL.nc
# ERA5: tp
# obs/model_by_site/KRAL/ERA5/tp_ERA5_KRAL.nc
# NCEP: tp
# NCEP: tp is not available
# CONUS404: tp
# obs/model_by_site/KRAL/CONUS404/tp_CONUS404_KRAL.nc
# NAM: tp
# obs/model_by_site/KRAL/NAM/tp_NAM_KRAL.nc
# NARR: tp
# obs/model_by_site/KRAL/NARR/tp_NARR_KRAL.nc
# HRRR: tp
# obs/model_by_site/KRAL/HRRR/tp_HRRR_KRAL.nc
# ERA5: vpd
# obs/model_by_site/KRAL/ERA5/vpd_ERA5_KRAL.nc
# NCEP: vpd
# obs/model_by_site/KRAL/NCEP/vpd_NCEP_KRAL.nc
# CONUS404: vpd
# obs/model_by_site/KRAL/CONUS404/vpd_CONUS404_KRAL.nc
# NAM: vpd
# obs/model_by_site/KRAL/NAM/vpd_NAM_KRAL.nc
# NARR: vpd
# obs/model_by_site/KRAL/NARR/vpd_NARR_KRAL.nc
# HRRR: vpd
# obs/model_by_site/KRAL/HRRR/vpd_HRRR_KRAL.nc
# ERA5: hdw
# obs/model_by_site/KRAL/ERA5/hdw_ERA5_KRAL.nc
# NCEP: hdw
# obs/model_by_site/KRAL/NCEP/hdw_NCEP_KRAL.nc
# CONUS404: hdw
# obs/model_by_site/KRAL/CONUS404/hdw_CONUS404_KRAL.nc
# NAM: hdw
# obs/model_by_site/KRAL/NAM/hdw_NAM_KRAL.nc
# NARR: hdw
# obs/model_by_site/KRAL/NARR/hdw_NARR_KRAL.nc
# HRRR: hdw
# obs/model_by_site/KRAL/HRRR/hdw_HRRR_KRAL.nc
# KSLC IS STARTING
# ERA5: t2
# obs/model_by_site/KSLC/ERA5/t2_ERA5_KSLC.nc
# NCEP: t2
# obs/model_by_site/KSLC/NCEP/t2_NCEP_KSLC.nc
# CONUS404: t2
# obs/model_by_site/KSLC/CONUS404/t2_CONUS404_KSLC.nc
# NAM: t2
# obs/model_by_site/KSLC/NAM/t2_NAM_KSLC.nc
# NARR: t2
# obs/model_by_site/KSLC/NARR/t2_NARR_KSLC.nc
# HRRR: t2
# obs/model_by_site/KSLC/HRRR/t2_HRRR_KSLC.nc
# ERA5: rh
# obs/model_by_site/KSLC/ERA5/rh_ERA5_KSLC.nc
# NCEP: rh
# obs/model_by_site/KSLC/NCEP/rh_NCEP_KSLC.nc
# CONUS404: rh
# obs/model_by_site/KSLC/CONUS404/rh_CONUS404_KSLC.nc
# NAM: rh
# obs/model_by_site/KSLC/NAM/rh_NAM_KSLC.nc
# NARR: rh
# obs/model_by_site/KSLC/NARR/rh_NARR_KSLC.nc
# HRRR: rh
# obs/model_by_site/KSLC/HRRR/rh_HRRR_KSLC.nc
# ERA5: ws
# obs/model_by_site/KSLC/ERA5/ws_ERA5_KSLC.nc
# NCEP: ws
# obs/model_by_site/KSLC/NCEP/ws_NCEP_KSLC.nc
# CONUS404: ws
# obs/model_by_site/KSLC/CONUS404/ws_CONUS404_KSLC.nc
# NAM: ws
# obs/model_by_site/KSLC/NAM/ws_NAM_KSLC.nc
# NARR: ws
# obs/model_by_site/KSLC/NARR/ws_NARR_KSLC.nc
# HRRR: ws
# obs/model_by_site/KSLC/HRRR/ws_HRRR_KSLC.nc
# ERA5: wd
# obs/model_by_site/KSLC/ERA5/wd_ERA5_KSLC.nc
# NCEP: wd
# obs/model_by_site/KSLC/NCEP/wd_NCEP_KSLC.nc
# CONUS404: wd
# obs/model_by_site/KSLC/CONUS404/wd_CONUS404_KSLC.nc
# NAM: wd
# obs/model_by_site/KSLC/NAM/wd_NAM_KSLC.nc
# NARR: wd
# obs/model_by_site/KSLC/NARR/wd_NARR_KSLC.nc
# HRRR: wd
# obs/model_by_site/KSLC/HRRR/wd_HRRR_KSLC.nc
# ERA5: gust
# obs/model_by_site/KSLC/ERA5/gust_ERA5_KSLC.nc
# NCEP: gust
# NCEP: gust is not available
# CONUS404: gust
# CONUS404: gust is not available
# NAM: gust
# obs/model_by_site/KSLC/NAM/gust_NAM_KSLC.nc
# NARR: gust
# NARR: gust is not available
# HRRR: gust
# obs/model_by_site/KSLC/HRRR/gust_HRRR_KSLC.nc
# ERA5: tp
# obs/model_by_site/KSLC/ERA5/tp_ERA5_KSLC.nc
# NCEP: tp
# NCEP: tp is not available
# CONUS404: tp
# obs/model_by_site/KSLC/CONUS404/tp_CONUS404_KSLC.nc
# NAM: tp
# obs/model_by_site/KSLC/NAM/tp_NAM_KSLC.nc
# NARR: tp
# obs/model_by_site/KSLC/NARR/tp_NARR_KSLC.nc
# HRRR: tp
# obs/model_by_site/KSLC/HRRR/tp_HRRR_KSLC.nc
# ERA5: vpd
# obs/model_by_site/KSLC/ERA5/vpd_ERA5_KSLC.nc
# NCEP: vpd
# obs/model_by_site/KSLC/NCEP/vpd_NCEP_KSLC.nc
# CONUS404: vpd
# obs/model_by_site/KSLC/CONUS404/vpd_CONUS404_KSLC.nc
# NAM: vpd
# obs/model_by_site/KSLC/NAM/vpd_NAM_KSLC.nc
# NARR: vpd
# obs/model_by_site/KSLC/NARR/vpd_NARR_KSLC.nc
# HRRR: vpd
# obs/model_by_site/KSLC/HRRR/vpd_HRRR_KSLC.nc
# ERA5: hdw
# obs/model_by_site/KSLC/ERA5/hdw_ERA5_KSLC.nc
# NCEP: hdw
# obs/model_by_site/KSLC/NCEP/hdw_NCEP_KSLC.nc
# CONUS404: hdw
# obs/model_by_site/KSLC/CONUS404/hdw_CONUS404_KSLC.nc
# NAM: hdw
# obs/model_by_site/KSLC/NAM/hdw_NAM_KSLC.nc
# NARR: hdw
# obs/model_by_site/KSLC/NARR/hdw_NARR_KSLC.nc
# HRRR: hdw
# obs/model_by_site/KSLC/HRRR/hdw_HRRR_KSLC.nc
# PAFA IS STARTING
# ERA5: t2
# obs/model_by_site/PAFA/ERA5/t2_ERA5_PAFA.nc
# NCEP: t2
# obs/model_by_site/PAFA/NCEP/t2_NCEP_PAFA.nc
# CONUS404: t2
