# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://media.licdn.com/dms/image/C4E0BAQFlOZSAJABP4w/company-logo_200_200/0/1548285168598?e=2147483647&v=beta&t=g4jl8rEhB7HLJuNZhU6OkJWHW4cul_y9Kj_aoD7p0_Y" alt="STI Logo" style="height: 98px;">
# </div>
#
#
# <h1>Finalize Database Files - UFS S2S</h1>
# By: Kayla Besong, PhD
#     <br>
# Last Edited: 05/15/24
# <br>
# <br>
# <br>
# This script takes all the downloaded forecast data in the database and generates the final form of each file. This includes changing variable names where needed, adding metadata, and unifying missing/nan values.
# <br>
# <br>
# A second section for finalizing harmonic analysis output is provided.
# <br>
# <br>
# This code is not pretty but it got the job done in the time it needed to get done! Make appropriate edits you need for your version. Adapted from a version that iterated over many models and changes everything to the sFWRD database. The original UFSS2S files provide plenty of metadata.
# <br>
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %%
import numpy as np
import xarray as xr
import pandas as pd
import os
import glob

# %%
# %run File_concat_mod_functions.ipynb

# %%
model_options = ['UFS_S2S']

# %%
### manually input the attributes you'd like to store as metadata in each netcdf file

var_names_units = {

          'PBL': {'name': 'pbl', 'long': 'Planetary Boundary Layer Height', 'units': 'm'},                   
          'CAPE': {'name': 'cape', 'long': 'Convective Available Potential Enegery', 'units': 'J/kg'},
          'MLCAPE': {'name': 'mlcape',  'long': 'Mixed Layer Convective Available Potential Enegery', 'units': 'J/kg'},
          'SBCAPE': {'name': 'sbcape', 'long': 'Surface Based Convective Available Potential Enegery', 'units': 'J/kg'},
          'SOILM': {'name': 'sm', 'long': 'Soil Moisture', 'units': 'kg/m^3', 'other': 'The first layer below the surface, varies per sFWD to what depth'},
          'VSM': {'name': 'vsm', 'long': 'Volumetric Soil Moisture', 'units': 'm^3/m^3 (ratio)', 'other': 'The first layer below the surface, varies per sFWD to what depth'},
          'U10': {'name': 'u10', 'long': 'u-component of the 10-m wind', 'units': 'm/s'},
          'V10': {'name': 'v10', 'long': 'v-component of the 10-m wind', 'units': 'm/s'},
          'GUST':{'name':  'gust', 'long': 'Instantaneous 10-m Wind Gust', 'units': 'm/s'},
          'PRATE': {'name': 'prate', 'long': 'Precipitation Rate', 'units': 'kg/m^2s'},
          'TP': {'name': 'tp', 'long': 'Total Precipitation', 'units': 'kg/m^2'},
          'TCP': {'name': 'tcp', 'long': 'Total Convective Precipitation', 'units': 'm'},
          'LSPR': {'name': 'lspr', 'long': 'Large Scale Rain Rate', 'units': 'kg/m^2s'},
          'TEMP': {'name': 't2',  'long': '2-m Temperature', 'units': 'K'},
          'RH': {'name': 'rh', 'long': 'Relative Humidity', 'units': '%'},
          'DEWPOINT': {'name': 'd2', 'long': '2-m Dewpoint', 'units': 'K'},
          'WINDSPEED': {'name': 'ws',  'long': 'Wind Speed', 'units': 'm/s'},
          'WINDDIR': {'name': 'wd',  'long': 'Wind Direction', 'units': 'degrees'},
          'HDWI': {'name': 'hdw',  'long': 'Surface-Based Hot Dry Windy', 'units': 'hPa*m/s'},
          'VPD': {'name': 'vpd', 'long': 'Vapor Pressure Deficit', 'units': 'hPa'},
          'FOSBERG': {'name': 'ffwi', 'long': 'Fosberg Fire Weather Index', 'units': 'N/A [0-100 scale]'}}

# %%
### A manual list of variables that link via keys-to-keys to the metadata dict. It is seperate from the dictionaries stored in File_concat_mod_functions.ipynb for that reason. 

variables_by_model =  {
    'UFS_S2S': {'PBL': 'hpbl', 'CAPE': 'cape', 'VSM':'soilw', 'U10': 'u10', 'V10': 'v10', 'GUST': 'gust', 'PRATE': 'prate', 'TEMP': 't2m', 'RH': 'r2', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'}}

# %% [markdown]
# # For the Database

# %% [markdown]
# ### make final directory for files

# %%
input_dir = 'database_files'
output_dir = 'database_files_final'

# %%
m = 'UFS_S2S'
prototypes = [5,6,7,8, 'MPM']

# %%
for m in model_options:
    dir_maker(f'{output_dir}/{m}')

# %%
for p in prototypes:
    
    dir_maker(f'{output_dir}/{m}')
    dir_maker(os.path.join(f'{output_dir}/{m}', f'{p}'))
    parent_dirs = glob.glob(os.path.join(f'{input_dir}/{m}/{p}/', '*'))
    
    for i in parent_dirs:
        subdir = i.split('/')[-1]                         
        dir_maker(os.path.join(f'{output_dir}/{m}/{p}', f'{subdir}'))

# %% [markdown]
# ## Final Clean Function

# %%
def final_clean_db(m, vars, p):

    ''' This function takes database files and unifies all variable and coordinate names, 
    alters the file out names, performs any cleaning still necessary, assigns attributes
    and information such as units, exporting to the database_files_final directory. 

    This function assumes that CONUS404, HRRR, NAM, and NARR have already been regridded. 
    These 4 models were already 'cleaned' through the regridding process. 
    
    Inputs:
    
    m: (str) model name
    vars: (list of strings) list of variable names for the model 
    p: (str) the prototype number, 5, 6, 7, 8, MPM 

    Outputs:
    
    bad: (list of str) list of filenames that failed during execution  
    
    '''

    
    vars_dict = {}                                                                                                                                   # Initialize a dictionary to store variable mappings
                                                                      
    for v in vars:                                                                                                                                   # Iterate over variables
        vars_dict[v.split('_')[0]] = v                                                                                                               # Map the first part of the variable name to the full variable name
                                                                      
    input_dir = f'database_files/{m}/{p}'                                                                                                            # Set the input directory for standard models
    
    bad = []

    for subdir in sorted(os.listdir(input_dir)):
    
        for f in sorted(os.listdir(f'{input_dir}/{subdir}')):                                                                                        # Iterate over sorted files in the input directory
            
            try:
            
                if f[-2:] == 'nc':                                                                                                                   # Check if the file is a NetCDF file
                    file = f'{input_dir}/{subdir}/{f}'                                                                                               # Construct the full file path
                    db_file = xr.open_dataset(file)                                                                                                  
            
                    if 'Abs' in file.split('/')[-1].split('_'):
                        v = vars_dict[file.split('/')[-1].split('_')[0]]                                                                             # Extract the variable name from the file name
                        outfile_pre = f'{get_filename(m)}_Abs_{file.split('/')[-1].split('_')[-1]}'                                                  # Prepare the output file prefix
                    
                    elif 'Daily' in file.split('/')[-1].split('_'):                                                                                  # Handle cases where the variable is not found
                        v = vars_dict[file.split('/')[-1].split('_')[0][0:-3]]                                                                       # Adjust the variable extraction for special cases
                        outfile_pre = f'{get_filename(m)}_{file.split('/')[-1].split('_')[0][-3:]}_Daily_{file.split('/')[-1].split('_')[-1]}'          
    
                    else:
                        print('file type does not match')
                        raise
                    
                    searchkey = list(variables_by_model[m].keys())[list(variables_by_model[m].values()).index(v)]                                    # Find the search key for the variable
                    newkey = var_names_units[searchkey]    
                                        
                    if newkey['name'] != v:                                                                                                          # Check if the variable name needs to be updated
                        db_file[newkey['name']] = db_file[v]                                                                                         # Update the variable name
                        db_file = db_file.drop(v)                                                                                                    # Drop the old variable name
                                                                      
                    
                    vars_to_keep = ['time', 'step', 'valid_time', 'latitude', 'longitude', newkey['name']]
    
                    if 'step' not in list(db_file.variables):
                        db_file = db_file.assign_coords({'step': db_file['valid_time'] -  db_file['time']})
                    
                    for keepv in vars_to_keep:
                        
                        attrs_to_del_var = []                                                                                                         # Clear old attributes             
                        
                        for key, item in db_file[keepv].attrs.items():
                            attrs_to_del_var.append(key)
                        
                        for j in attrs_to_del_var:
                            del db_file[keepv].attrs[j]  
                    
                    time_attrs = {'time': {'long_name': 'initial time of forecast','standard_name': 'forecast_reference_time'},
                                  'step': {'long_name': 'time since forecast_reference_time','standard_name': 'forecast_period'},
                                  'valid_time': {'long_name': 'time + step', 'standard_name': 'time'}}
                    
                    db_file[newkey['name']] = db_file[newkey['name']].assign_attrs({'Variable Name': newkey['long'], 'Units': newkey['units']})    # Assign new attributes
                                             
                    
                    for vout in list(db_file.coords):                            
                        if vout not in vars_to_keep:                            
                            db_file = db_file.drop(vout)
                    
                        if vout in vars_to_keep[0:3]:
                    
                            db_file[vout] = db_file[vout].assign_attrs(time_attrs[vout])               
                                                                        
                    db_file = db_file.sortby('valid_time')                                                                                           # Sort the dataset by time
                                                                        
                    outfile = f'{newkey['name']}_{outfile_pre}'                                                                                      # Construct the final output file name
                    db_file.to_netcdf(f'database_files_final/{m}/{p}/{subdir}/{outfile}')                                                            # Save the dataset to a NetCDF file
                    
                    print(outfile)                                                                                                                   
                    del outfile                                                                                                                      
            
            except:
                print(f'{f} to bad')
                bad.append(f)
    
    return bad

# %% [markdown]
# ### P = 5

# %%
m = 'UFS_S2S'
p = 5

# %%
ufs_vars = [value for key,value in variables_by_model[m].items()]

# %%
ufs_vars
# Out:
# ['hpbl',
#  'cape',
#  'soilw',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  't2m',
#  'r2',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_ufs_5_1 = final_clean_db(m, ufs_vars, p)
# Out:
# /home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'gini' loading failed:
# Struct() takes at most 1 argument (3 given)
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# cape_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_Abs_20110401.nc to bad
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110401.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_Abs_20110401.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# hdw_UFS_S2S_FORECAST_Abs_20110401.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_Abs_20110401.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_Abs_20110401.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_Abs_20110401.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_Abs_20110401.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_Abs_20110401.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_Abs_20110401.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_Abs_20110401.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_Abs_20110401.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_Abs_20110401.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_Abs_20110415.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110415.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_Abs_20110415.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# hdw_UFS_S2S_FORECAST_Abs_20110415.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_Abs_20110415.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_Abs_20110415.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_Abs_20110415.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_Abs_20110415.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_Abs_20110415.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_Abs_20110415.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_Abs_20110415.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_Abs_20110415.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_Abs_20110415.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_Abs_20110501.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110501.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_Abs_20110501.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# hdw_UFS_S2S_FORECAST_Abs_20110501.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_Abs_20110501.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_Abs_20110501.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_Abs_20110501.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_Abs_20110501.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_Abs_20110501.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_Abs_20110501.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_Abs_20110501.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_Abs_20110501.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_Abs_20110501.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_Abs_20110515.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110515.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_Abs_20110515.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# hdw_UFS_S2S_FORECAST_Abs_20110515.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_Abs_20110515.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_Abs_20110515.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_Abs_20110515.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_Abs_20110515.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_Abs_20110515.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_Abs_20110515.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_Abs_20110515.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_Abs_20110515.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_Abs_20110515.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_Abs_20110601.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110601.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_Abs_20110601.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# hdw_UFS_S2S_FORECAST_Abs_20110601.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_Abs_20110601.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_Abs_20110601.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_Abs_20110601.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_Abs_20110601.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_Abs_20110601.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_Abs_20110601.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_Abs_20110601.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_Abs_20110601.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_Abs_20110601.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_Abs_20110615.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110615.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_Abs_20110615.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# hdw_UFS_S2S_FORECAST_Abs_20110615.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_Abs_20110615.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_Abs_20110615.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_Abs_20110615.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_Abs_20110615.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_Abs_20110615.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_Abs_20110615.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_Abs_20110615.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_Abs_20110615.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_Abs_20110615.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_Abs_20110701.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110701.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_Abs_20110701.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# hdw_UFS_S2S_FORECAST_Abs_20110701.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_Abs_20110701.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_Abs_20110701.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_Abs_20110701.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_Abs_20110701.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_Abs_20110701.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_Abs_20110701.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_Abs_20110701.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_Abs_20110701.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_Abs_20110701.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_Abs_20110715.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110715.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_Abs_20110715.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# hdw_UFS_S2S_FORECAST_Abs_20110715.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_Abs_20110715.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_Abs_20110715.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_Abs_20110715.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_Abs_20110715.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_Abs_20110715.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_Abs_20110715.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_Abs_20110715.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_Abs_20110715.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_Abs_20110715.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_Abs_20110801.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110801.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_Abs_20110801.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# hdw_UFS_S2S_FORECAST_Abs_20110801.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_Abs_20110801.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_Abs_20110801.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_Abs_20110801.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_Abs_20110801.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_Abs_20110801.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_Abs_20110801.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_Abs_20110801.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_Abs_20110801.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_Abs_20110801.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_Abs_20110815.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110815.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_Abs_20110815.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# hdw_UFS_S2S_FORECAST_Abs_20110815.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_Abs_20110815.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_Abs_20110815.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_Abs_20110815.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_Abs_20110815.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_Abs_20110815.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_Abs_20110815.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_Abs_20110815.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_Abs_20110815.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_Abs_20110815.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_Abs_20110901.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110901.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_Abs_20110901.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# hdw_UFS_S2S_FORECAST_Abs_20110901.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_Abs_20110901.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_Abs_20110901.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_Abs_20110901.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_Abs_20110901.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_Abs_20110901.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_Abs_20110901.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_Abs_20110901.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_Abs_20110901.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_Abs_20110901.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_Abs_20110915.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110915.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_Abs_20110915.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# hdw_UFS_S2S_FORECAST_Abs_20110915.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_Abs_20110915.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_Abs_20110915.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_Abs_20110915.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_Abs_20110915.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_Abs_20110915.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_Abs_20110915.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_Abs_20110915.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_Abs_20110915.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_Abs_20110915.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_Abs_20111001.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111001.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_Abs_20111001.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# hdw_UFS_S2S_FORECAST_Abs_20111001.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_Abs_20111001.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_Abs_20111001.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_Abs_20111001.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_Abs_20111001.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_Abs_20111001.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_Abs_20111001.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_Abs_20111001.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_Abs_20111001.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_Abs_20111001.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_Abs_20111015.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111015.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_Abs_20111015.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# hdw_UFS_S2S_FORECAST_Abs_20111015.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_Abs_20111015.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_Abs_20111015.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_Abs_20111015.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_Abs_20111015.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_Abs_20111015.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_Abs_20111015.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_Abs_20111015.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_Abs_20111015.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_Abs_20111015.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_Abs_20111101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_Abs_20111101.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# hdw_UFS_S2S_FORECAST_Abs_20111101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_Abs_20111101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_Abs_20111101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_Abs_20111101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_Abs_20111101.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_Abs_20111101.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_Abs_20111101.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_Abs_20111101.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_Abs_20111101.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_Abs_20111101.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_Abs_20111115.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111115.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_Abs_20111115.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# hdw_UFS_S2S_FORECAST_Abs_20111115.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_Abs_20111115.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_Abs_20111115.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_Abs_20111115.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_Abs_20111115.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_Abs_20111115.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_Abs_20111115.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_Abs_20111115.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_Abs_20111115.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_Abs_20111115.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_Abs_20111201.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111201.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_Abs_20111201.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# hdw_UFS_S2S_FORECAST_Abs_20111201.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_Abs_20111201.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_Abs_20111201.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_Abs_20111201.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_Abs_20111201.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_Abs_20111201.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_Abs_20111201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_Abs_20111201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_Abs_20111201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_Abs_20111201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_Abs_20111215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_Abs_20111215.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# hdw_UFS_S2S_FORECAST_Abs_20111215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_Abs_20111215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_Abs_20111215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_Abs_20111215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_Abs_20111215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_Abs_20111215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_Abs_20111215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_Abs_20111215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_Abs_20111215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_Abs_20111215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_Abs_20120101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_Abs_20120101.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# hdw_UFS_S2S_FORECAST_Abs_20120101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_Abs_20120101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_Abs_20120101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_Abs_20120101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_Abs_20120101.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_Abs_20120101.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_Abs_20120101.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_Abs_20120101.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_Abs_20120101.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_Abs_20120101.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_Abs_20120115.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120115.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_Abs_20120115.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# hdw_UFS_S2S_FORECAST_Abs_20120115.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_Abs_20120115.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_Abs_20120115.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_Abs_20120115.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_Abs_20120115.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_Abs_20120115.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_Abs_20120115.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_Abs_20120115.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_Abs_20120115.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_Abs_20120115.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_Abs_20120201.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120201.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_Abs_20120201.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# hdw_UFS_S2S_FORECAST_Abs_20120201.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_Abs_20120201.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_Abs_20120201.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_Abs_20120201.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_Abs_20120201.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_Abs_20120201.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_Abs_20120201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_Abs_20120201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_Abs_20120201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_Abs_20120201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_Abs_20120215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_Abs_20120215.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# hdw_UFS_S2S_FORECAST_Abs_20120215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_Abs_20120215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_Abs_20120215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_Abs_20120215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_Abs_20120215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_Abs_20120215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_Abs_20120215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_Abs_20120215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_Abs_20120215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_Abs_20120215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# ...
# v10_UFS_S2S_FORECAST_MAX_Daily_20171201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20171201.nc
# v10_UFS_S2S_FORECAST_Abs_20171201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20171201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20171201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20171201.nc
# vpd_UFS_S2S_FORECAST_Abs_20171201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20171201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20171201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20171201.nc
# wd_UFS_S2S_FORECAST_Abs_20171201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20171201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20171201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20171201.nc
# ws_UFS_S2S_FORECAST_Abs_20171201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# cape_UFS_S2S_FORECAST_Abs_20171215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20171215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# gust_UFS_S2S_FORECAST_Abs_20171215.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# hdw_UFS_S2S_FORECAST_Abs_20171215.nc
# pbl_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# pbl_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# pbl_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# pbl_UFS_S2S_FORECAST_Abs_20171215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# prate_UFS_S2S_FORECAST_Abs_20171215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# rh_UFS_S2S_FORECAST_Abs_20171215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# vsm_UFS_S2S_FORECAST_Abs_20171215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# t2_UFS_S2S_FORECAST_Abs_20171215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# u10_UFS_S2S_FORECAST_Abs_20171215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# v10_UFS_S2S_FORECAST_Abs_20171215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# vpd_UFS_S2S_FORECAST_Abs_20171215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# wd_UFS_S2S_FORECAST_Abs_20171215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20171215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20171215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20171215.nc
# ws_UFS_S2S_FORECAST_Abs_20171215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# cape_UFS_S2S_FORECAST_Abs_20180101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# gust_UFS_S2S_FORECAST_Abs_20180101.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# hdw_UFS_S2S_FORECAST_Abs_20180101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# prate_UFS_S2S_FORECAST_Abs_20180101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# rh_UFS_S2S_FORECAST_Abs_20180101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# vsm_UFS_S2S_FORECAST_Abs_20180101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# t2_UFS_S2S_FORECAST_Abs_20180101.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# u10_UFS_S2S_FORECAST_Abs_20180101.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# v10_UFS_S2S_FORECAST_Abs_20180101.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# vpd_UFS_S2S_FORECAST_Abs_20180101.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# wd_UFS_S2S_FORECAST_Abs_20180101.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180101.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180101.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180101.nc
# ws_UFS_S2S_FORECAST_Abs_20180101.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# cape_UFS_S2S_FORECAST_Abs_20180115.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180115.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# gust_UFS_S2S_FORECAST_Abs_20180115.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# hdw_UFS_S2S_FORECAST_Abs_20180115.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# prate_UFS_S2S_FORECAST_Abs_20180115.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# rh_UFS_S2S_FORECAST_Abs_20180115.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# vsm_UFS_S2S_FORECAST_Abs_20180115.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# t2_UFS_S2S_FORECAST_Abs_20180115.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# u10_UFS_S2S_FORECAST_Abs_20180115.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# v10_UFS_S2S_FORECAST_Abs_20180115.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# vpd_UFS_S2S_FORECAST_Abs_20180115.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# wd_UFS_S2S_FORECAST_Abs_20180115.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180115.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180115.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180115.nc
# ws_UFS_S2S_FORECAST_Abs_20180115.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# cape_UFS_S2S_FORECAST_Abs_20180201.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180201.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# gust_UFS_S2S_FORECAST_Abs_20180201.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# hdw_UFS_S2S_FORECAST_Abs_20180201.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# prate_UFS_S2S_FORECAST_Abs_20180201.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# rh_UFS_S2S_FORECAST_Abs_20180201.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# vsm_UFS_S2S_FORECAST_Abs_20180201.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# t2_UFS_S2S_FORECAST_Abs_20180201.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# u10_UFS_S2S_FORECAST_Abs_20180201.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# v10_UFS_S2S_FORECAST_Abs_20180201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# vpd_UFS_S2S_FORECAST_Abs_20180201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# wd_UFS_S2S_FORECAST_Abs_20180201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180201.nc
# ws_UFS_S2S_FORECAST_Abs_20180201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# cape_UFS_S2S_FORECAST_Abs_20180215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# gust_UFS_S2S_FORECAST_Abs_20180215.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# hdw_UFS_S2S_FORECAST_Abs_20180215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# prate_UFS_S2S_FORECAST_Abs_20180215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# rh_UFS_S2S_FORECAST_Abs_20180215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# vsm_UFS_S2S_FORECAST_Abs_20180215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# t2_UFS_S2S_FORECAST_Abs_20180215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# u10_UFS_S2S_FORECAST_Abs_20180215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# v10_UFS_S2S_FORECAST_Abs_20180215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# vpd_UFS_S2S_FORECAST_Abs_20180215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# wd_UFS_S2S_FORECAST_Abs_20180215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180215.nc
# ws_UFS_S2S_FORECAST_Abs_20180215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# cape_UFS_S2S_FORECAST_Abs_20180301.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180301.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# gust_UFS_S2S_FORECAST_Abs_20180301.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# hdw_UFS_S2S_FORECAST_Abs_20180301.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# prate_UFS_S2S_FORECAST_Abs_20180301.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# rh_UFS_S2S_FORECAST_Abs_20180301.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# vsm_UFS_S2S_FORECAST_Abs_20180301.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# t2_UFS_S2S_FORECAST_Abs_20180301.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# u10_UFS_S2S_FORECAST_Abs_20180301.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# v10_UFS_S2S_FORECAST_Abs_20180301.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# vpd_UFS_S2S_FORECAST_Abs_20180301.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# wd_UFS_S2S_FORECAST_Abs_20180301.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180301.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180301.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180301.nc
# ws_UFS_S2S_FORECAST_Abs_20180301.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# cape_UFS_S2S_FORECAST_Abs_20180315.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# ffwi_UFS_S2S_FORECAST_Abs_20180315.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# gust_UFS_S2S_FORECAST_Abs_20180315.nc
# hdw_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# hdw_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# hdw_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# hdw_UFS_S2S_FORECAST_Abs_20180315.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# prate_UFS_S2S_FORECAST_Abs_20180315.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# rh_UFS_S2S_FORECAST_Abs_20180315.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# vsm_UFS_S2S_FORECAST_Abs_20180315.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# t2_UFS_S2S_FORECAST_Abs_20180315.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# u10_UFS_S2S_FORECAST_Abs_20180315.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# v10_UFS_S2S_FORECAST_Abs_20180315.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# vpd_UFS_S2S_FORECAST_Abs_20180315.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# wd_UFS_S2S_FORECAST_Abs_20180315.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20180315.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20180315.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20180315.nc
# ws_UFS_S2S_FORECAST_Abs_20180315.nc
# CPU times: user 7min 46s, sys: 27min 37s, total: 35min 23s
# Wall time: 1h 22s

# %%
bad_ufs_5_1
# Out:
# ['cape_UFS_S2S_FORECAST_Abs_20110401.nc']

# %% [markdown]
# ### P = 6, 7, 8, MPM
# 5 was used for testing

# %%
m = 'UFS_S2S'
ps = [6, 7, 8, 'MPM']

# %%
ufs_vars = [value for key,value in variables_by_model[m].items()]

# %%
ufs_vars
# Out:
# ['hpbl',
#  'cape',
#  'soilw',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  't2m',
#  'r2',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_ufs_all_1 = []
for p in ps:
    bad_ufs_all_1.append(final_clean_db(m, ufs_vars, p))
# Out:
# cape_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# cape_UFS_S2S_FORECAST_Abs_20110401.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110401.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# gust_UFS_S2S_FORECAST_Abs_20110401.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# prate_UFS_S2S_FORECAST_Abs_20110401.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# rh_UFS_S2S_FORECAST_Abs_20110401.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# vsm_UFS_S2S_FORECAST_Abs_20110401.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# t2_UFS_S2S_FORECAST_Abs_20110401.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# u10_UFS_S2S_FORECAST_Abs_20110401.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# v10_UFS_S2S_FORECAST_Abs_20110401.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# vpd_UFS_S2S_FORECAST_Abs_20110401.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# wd_UFS_S2S_FORECAST_Abs_20110401.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110401.nc
# ws_UFS_S2S_FORECAST_Abs_20110401.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# cape_UFS_S2S_FORECAST_Abs_20110415.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110415.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# gust_UFS_S2S_FORECAST_Abs_20110415.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# prate_UFS_S2S_FORECAST_Abs_20110415.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# rh_UFS_S2S_FORECAST_Abs_20110415.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# vsm_UFS_S2S_FORECAST_Abs_20110415.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# t2_UFS_S2S_FORECAST_Abs_20110415.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# u10_UFS_S2S_FORECAST_Abs_20110415.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# v10_UFS_S2S_FORECAST_Abs_20110415.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# vpd_UFS_S2S_FORECAST_Abs_20110415.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# wd_UFS_S2S_FORECAST_Abs_20110415.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110415.nc
# ws_UFS_S2S_FORECAST_Abs_20110415.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# cape_UFS_S2S_FORECAST_Abs_20110501.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110501.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# gust_UFS_S2S_FORECAST_Abs_20110501.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# prate_UFS_S2S_FORECAST_Abs_20110501.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# rh_UFS_S2S_FORECAST_Abs_20110501.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# vsm_UFS_S2S_FORECAST_Abs_20110501.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# t2_UFS_S2S_FORECAST_Abs_20110501.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# u10_UFS_S2S_FORECAST_Abs_20110501.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# v10_UFS_S2S_FORECAST_Abs_20110501.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# vpd_UFS_S2S_FORECAST_Abs_20110501.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# wd_UFS_S2S_FORECAST_Abs_20110501.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110501.nc
# ws_UFS_S2S_FORECAST_Abs_20110501.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# cape_UFS_S2S_FORECAST_Abs_20110515.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110515.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# gust_UFS_S2S_FORECAST_Abs_20110515.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# prate_UFS_S2S_FORECAST_Abs_20110515.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# rh_UFS_S2S_FORECAST_Abs_20110515.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# vsm_UFS_S2S_FORECAST_Abs_20110515.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# t2_UFS_S2S_FORECAST_Abs_20110515.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# u10_UFS_S2S_FORECAST_Abs_20110515.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# v10_UFS_S2S_FORECAST_Abs_20110515.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# vpd_UFS_S2S_FORECAST_Abs_20110515.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# wd_UFS_S2S_FORECAST_Abs_20110515.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110515.nc
# ws_UFS_S2S_FORECAST_Abs_20110515.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# cape_UFS_S2S_FORECAST_Abs_20110601.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110601.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# gust_UFS_S2S_FORECAST_Abs_20110601.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# prate_UFS_S2S_FORECAST_Abs_20110601.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# rh_UFS_S2S_FORECAST_Abs_20110601.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# vsm_UFS_S2S_FORECAST_Abs_20110601.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# t2_UFS_S2S_FORECAST_Abs_20110601.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# u10_UFS_S2S_FORECAST_Abs_20110601.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# v10_UFS_S2S_FORECAST_Abs_20110601.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# vpd_UFS_S2S_FORECAST_Abs_20110601.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# wd_UFS_S2S_FORECAST_Abs_20110601.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110601.nc
# ws_UFS_S2S_FORECAST_Abs_20110601.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# cape_UFS_S2S_FORECAST_Abs_20110615.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110615.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# gust_UFS_S2S_FORECAST_Abs_20110615.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# prate_UFS_S2S_FORECAST_Abs_20110615.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# rh_UFS_S2S_FORECAST_Abs_20110615.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# vsm_UFS_S2S_FORECAST_Abs_20110615.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# t2_UFS_S2S_FORECAST_Abs_20110615.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# u10_UFS_S2S_FORECAST_Abs_20110615.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# v10_UFS_S2S_FORECAST_Abs_20110615.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# vpd_UFS_S2S_FORECAST_Abs_20110615.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# wd_UFS_S2S_FORECAST_Abs_20110615.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110615.nc
# ws_UFS_S2S_FORECAST_Abs_20110615.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# cape_UFS_S2S_FORECAST_Abs_20110701.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110701.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# gust_UFS_S2S_FORECAST_Abs_20110701.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# prate_UFS_S2S_FORECAST_Abs_20110701.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# rh_UFS_S2S_FORECAST_Abs_20110701.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# vsm_UFS_S2S_FORECAST_Abs_20110701.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# t2_UFS_S2S_FORECAST_Abs_20110701.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# u10_UFS_S2S_FORECAST_Abs_20110701.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# v10_UFS_S2S_FORECAST_Abs_20110701.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# vpd_UFS_S2S_FORECAST_Abs_20110701.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# wd_UFS_S2S_FORECAST_Abs_20110701.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110701.nc
# ws_UFS_S2S_FORECAST_Abs_20110701.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# cape_UFS_S2S_FORECAST_Abs_20110715.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110715.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# gust_UFS_S2S_FORECAST_Abs_20110715.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# prate_UFS_S2S_FORECAST_Abs_20110715.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# rh_UFS_S2S_FORECAST_Abs_20110715.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# vsm_UFS_S2S_FORECAST_Abs_20110715.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# t2_UFS_S2S_FORECAST_Abs_20110715.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# u10_UFS_S2S_FORECAST_Abs_20110715.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# v10_UFS_S2S_FORECAST_Abs_20110715.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# vpd_UFS_S2S_FORECAST_Abs_20110715.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# wd_UFS_S2S_FORECAST_Abs_20110715.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110715.nc
# ws_UFS_S2S_FORECAST_Abs_20110715.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# cape_UFS_S2S_FORECAST_Abs_20110801.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110801.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# gust_UFS_S2S_FORECAST_Abs_20110801.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# prate_UFS_S2S_FORECAST_Abs_20110801.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# rh_UFS_S2S_FORECAST_Abs_20110801.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# vsm_UFS_S2S_FORECAST_Abs_20110801.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# t2_UFS_S2S_FORECAST_Abs_20110801.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# u10_UFS_S2S_FORECAST_Abs_20110801.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# v10_UFS_S2S_FORECAST_Abs_20110801.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# vpd_UFS_S2S_FORECAST_Abs_20110801.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# wd_UFS_S2S_FORECAST_Abs_20110801.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110801.nc
# ws_UFS_S2S_FORECAST_Abs_20110801.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# cape_UFS_S2S_FORECAST_Abs_20110815.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110815.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# gust_UFS_S2S_FORECAST_Abs_20110815.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# prate_UFS_S2S_FORECAST_Abs_20110815.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# rh_UFS_S2S_FORECAST_Abs_20110815.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# vsm_UFS_S2S_FORECAST_Abs_20110815.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# t2_UFS_S2S_FORECAST_Abs_20110815.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# u10_UFS_S2S_FORECAST_Abs_20110815.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# v10_UFS_S2S_FORECAST_Abs_20110815.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# vpd_UFS_S2S_FORECAST_Abs_20110815.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# wd_UFS_S2S_FORECAST_Abs_20110815.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110815.nc
# ws_UFS_S2S_FORECAST_Abs_20110815.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# cape_UFS_S2S_FORECAST_Abs_20110901.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110901.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# gust_UFS_S2S_FORECAST_Abs_20110901.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# prate_UFS_S2S_FORECAST_Abs_20110901.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# rh_UFS_S2S_FORECAST_Abs_20110901.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# vsm_UFS_S2S_FORECAST_Abs_20110901.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# t2_UFS_S2S_FORECAST_Abs_20110901.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# u10_UFS_S2S_FORECAST_Abs_20110901.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# v10_UFS_S2S_FORECAST_Abs_20110901.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# vpd_UFS_S2S_FORECAST_Abs_20110901.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# wd_UFS_S2S_FORECAST_Abs_20110901.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110901.nc
# ws_UFS_S2S_FORECAST_Abs_20110901.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# cape_UFS_S2S_FORECAST_Abs_20110915.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# ffwi_UFS_S2S_FORECAST_Abs_20110915.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# gust_UFS_S2S_FORECAST_Abs_20110915.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# prate_UFS_S2S_FORECAST_Abs_20110915.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# rh_UFS_S2S_FORECAST_Abs_20110915.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# vsm_UFS_S2S_FORECAST_Abs_20110915.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# t2_UFS_S2S_FORECAST_Abs_20110915.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# u10_UFS_S2S_FORECAST_Abs_20110915.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# v10_UFS_S2S_FORECAST_Abs_20110915.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# vpd_UFS_S2S_FORECAST_Abs_20110915.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# wd_UFS_S2S_FORECAST_Abs_20110915.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20110915.nc
# ws_UFS_S2S_FORECAST_Abs_20110915.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# cape_UFS_S2S_FORECAST_Abs_20111001.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111001.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# gust_UFS_S2S_FORECAST_Abs_20111001.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# prate_UFS_S2S_FORECAST_Abs_20111001.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# rh_UFS_S2S_FORECAST_Abs_20111001.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# vsm_UFS_S2S_FORECAST_Abs_20111001.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# t2_UFS_S2S_FORECAST_Abs_20111001.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# u10_UFS_S2S_FORECAST_Abs_20111001.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# v10_UFS_S2S_FORECAST_Abs_20111001.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# vpd_UFS_S2S_FORECAST_Abs_20111001.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# wd_UFS_S2S_FORECAST_Abs_20111001.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111001.nc
# ws_UFS_S2S_FORECAST_Abs_20111001.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# cape_UFS_S2S_FORECAST_Abs_20111015.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111015.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# gust_UFS_S2S_FORECAST_Abs_20111015.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# prate_UFS_S2S_FORECAST_Abs_20111015.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# rh_UFS_S2S_FORECAST_Abs_20111015.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# vsm_UFS_S2S_FORECAST_Abs_20111015.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# t2_UFS_S2S_FORECAST_Abs_20111015.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# u10_UFS_S2S_FORECAST_Abs_20111015.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# v10_UFS_S2S_FORECAST_Abs_20111015.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# vpd_UFS_S2S_FORECAST_Abs_20111015.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# wd_UFS_S2S_FORECAST_Abs_20111015.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111015.nc
# ws_UFS_S2S_FORECAST_Abs_20111015.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# cape_UFS_S2S_FORECAST_Abs_20111101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# gust_UFS_S2S_FORECAST_Abs_20111101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# prate_UFS_S2S_FORECAST_Abs_20111101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# rh_UFS_S2S_FORECAST_Abs_20111101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# vsm_UFS_S2S_FORECAST_Abs_20111101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# t2_UFS_S2S_FORECAST_Abs_20111101.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# u10_UFS_S2S_FORECAST_Abs_20111101.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# v10_UFS_S2S_FORECAST_Abs_20111101.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# vpd_UFS_S2S_FORECAST_Abs_20111101.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# wd_UFS_S2S_FORECAST_Abs_20111101.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111101.nc
# ws_UFS_S2S_FORECAST_Abs_20111101.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# cape_UFS_S2S_FORECAST_Abs_20111115.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111115.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# gust_UFS_S2S_FORECAST_Abs_20111115.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# prate_UFS_S2S_FORECAST_Abs_20111115.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# rh_UFS_S2S_FORECAST_Abs_20111115.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# vsm_UFS_S2S_FORECAST_Abs_20111115.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# t2_UFS_S2S_FORECAST_Abs_20111115.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# u10_UFS_S2S_FORECAST_Abs_20111115.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# v10_UFS_S2S_FORECAST_Abs_20111115.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# vpd_UFS_S2S_FORECAST_Abs_20111115.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# wd_UFS_S2S_FORECAST_Abs_20111115.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111115.nc
# ws_UFS_S2S_FORECAST_Abs_20111115.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# cape_UFS_S2S_FORECAST_Abs_20111201.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111201.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# gust_UFS_S2S_FORECAST_Abs_20111201.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# prate_UFS_S2S_FORECAST_Abs_20111201.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# rh_UFS_S2S_FORECAST_Abs_20111201.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# vsm_UFS_S2S_FORECAST_Abs_20111201.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# t2_UFS_S2S_FORECAST_Abs_20111201.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# u10_UFS_S2S_FORECAST_Abs_20111201.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# v10_UFS_S2S_FORECAST_Abs_20111201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# vpd_UFS_S2S_FORECAST_Abs_20111201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# wd_UFS_S2S_FORECAST_Abs_20111201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111201.nc
# ws_UFS_S2S_FORECAST_Abs_20111201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# cape_UFS_S2S_FORECAST_Abs_20111215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20111215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# gust_UFS_S2S_FORECAST_Abs_20111215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# prate_UFS_S2S_FORECAST_Abs_20111215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# rh_UFS_S2S_FORECAST_Abs_20111215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# vsm_UFS_S2S_FORECAST_Abs_20111215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# t2_UFS_S2S_FORECAST_Abs_20111215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# u10_UFS_S2S_FORECAST_Abs_20111215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# v10_UFS_S2S_FORECAST_Abs_20111215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# vpd_UFS_S2S_FORECAST_Abs_20111215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# wd_UFS_S2S_FORECAST_Abs_20111215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20111215.nc
# ws_UFS_S2S_FORECAST_Abs_20111215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# cape_UFS_S2S_FORECAST_Abs_20120101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# gust_UFS_S2S_FORECAST_Abs_20120101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# prate_UFS_S2S_FORECAST_Abs_20120101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# rh_UFS_S2S_FORECAST_Abs_20120101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# vsm_UFS_S2S_FORECAST_Abs_20120101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# t2_UFS_S2S_FORECAST_Abs_20120101.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# u10_UFS_S2S_FORECAST_Abs_20120101.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# v10_UFS_S2S_FORECAST_Abs_20120101.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# vpd_UFS_S2S_FORECAST_Abs_20120101.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# wd_UFS_S2S_FORECAST_Abs_20120101.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120101.nc
# ws_UFS_S2S_FORECAST_Abs_20120101.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# cape_UFS_S2S_FORECAST_Abs_20120115.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120115.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# gust_UFS_S2S_FORECAST_Abs_20120115.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# prate_UFS_S2S_FORECAST_Abs_20120115.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# rh_UFS_S2S_FORECAST_Abs_20120115.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# vsm_UFS_S2S_FORECAST_Abs_20120115.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# t2_UFS_S2S_FORECAST_Abs_20120115.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# u10_UFS_S2S_FORECAST_Abs_20120115.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# v10_UFS_S2S_FORECAST_Abs_20120115.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# vpd_UFS_S2S_FORECAST_Abs_20120115.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# wd_UFS_S2S_FORECAST_Abs_20120115.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120115.nc
# ws_UFS_S2S_FORECAST_Abs_20120115.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# cape_UFS_S2S_FORECAST_Abs_20120201.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120201.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# gust_UFS_S2S_FORECAST_Abs_20120201.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# prate_UFS_S2S_FORECAST_Abs_20120201.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# rh_UFS_S2S_FORECAST_Abs_20120201.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# vsm_UFS_S2S_FORECAST_Abs_20120201.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# t2_UFS_S2S_FORECAST_Abs_20120201.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# u10_UFS_S2S_FORECAST_Abs_20120201.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# v10_UFS_S2S_FORECAST_Abs_20120201.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# vpd_UFS_S2S_FORECAST_Abs_20120201.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# wd_UFS_S2S_FORECAST_Abs_20120201.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120201.nc
# ws_UFS_S2S_FORECAST_Abs_20120201.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# cape_UFS_S2S_FORECAST_Abs_20120215.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120215.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# gust_UFS_S2S_FORECAST_Abs_20120215.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# prate_UFS_S2S_FORECAST_Abs_20120215.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# rh_UFS_S2S_FORECAST_Abs_20120215.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# vsm_UFS_S2S_FORECAST_Abs_20120215.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# t2_UFS_S2S_FORECAST_Abs_20120215.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# u10_UFS_S2S_FORECAST_Abs_20120215.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# v10_UFS_S2S_FORECAST_Abs_20120215.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# vpd_UFS_S2S_FORECAST_Abs_20120215.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# wd_UFS_S2S_FORECAST_Abs_20120215.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120215.nc
# ws_UFS_S2S_FORECAST_Abs_20120215.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# cape_UFS_S2S_FORECAST_Abs_20120301.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120301.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# gust_UFS_S2S_FORECAST_Abs_20120301.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# prate_UFS_S2S_FORECAST_Abs_20120301.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# rh_UFS_S2S_FORECAST_Abs_20120301.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# vsm_UFS_S2S_FORECAST_Abs_20120301.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# t2_UFS_S2S_FORECAST_Abs_20120301.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# u10_UFS_S2S_FORECAST_Abs_20120301.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# v10_UFS_S2S_FORECAST_Abs_20120301.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# vpd_UFS_S2S_FORECAST_Abs_20120301.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# wd_UFS_S2S_FORECAST_Abs_20120301.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120301.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120301.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120301.nc
# ws_UFS_S2S_FORECAST_Abs_20120301.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# cape_UFS_S2S_FORECAST_Abs_20120315.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# ffwi_UFS_S2S_FORECAST_Abs_20120315.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# gust_UFS_S2S_FORECAST_Abs_20120315.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# prate_UFS_S2S_FORECAST_Abs_20120315.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# rh_UFS_S2S_FORECAST_Abs_20120315.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# vsm_UFS_S2S_FORECAST_Abs_20120315.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# t2_UFS_S2S_FORECAST_Abs_20120315.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# u10_UFS_S2S_FORECAST_Abs_20120315.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# v10_UFS_S2S_FORECAST_Abs_20120315.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# vpd_UFS_S2S_FORECAST_Abs_20120315.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# wd_UFS_S2S_FORECAST_Abs_20120315.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20120315.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20120315.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20120315.nc
# ws_UFS_S2S_FORECAST_Abs_20120315.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20120401.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20120401.nc
# ...
# v10_UFS_S2S_FORECAST_Abs_20130701.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130701.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130701.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130701.nc
# vpd_UFS_S2S_FORECAST_Abs_20130701.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130701.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130701.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130701.nc
# wd_UFS_S2S_FORECAST_Abs_20130701.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130701.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130701.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130701.nc
# ws_UFS_S2S_FORECAST_Abs_20130701.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# cape_UFS_S2S_FORECAST_Abs_20130715.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# ffwi_UFS_S2S_FORECAST_Abs_20130715.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# gust_UFS_S2S_FORECAST_Abs_20130715.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# prate_UFS_S2S_FORECAST_Abs_20130715.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# rh_UFS_S2S_FORECAST_Abs_20130715.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# vsm_UFS_S2S_FORECAST_Abs_20130715.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# t2_UFS_S2S_FORECAST_Abs_20130715.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# u10_UFS_S2S_FORECAST_Abs_20130715.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# v10_UFS_S2S_FORECAST_Abs_20130715.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# vpd_UFS_S2S_FORECAST_Abs_20130715.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# wd_UFS_S2S_FORECAST_Abs_20130715.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130715.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130715.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130715.nc
# ws_UFS_S2S_FORECAST_Abs_20130715.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# cape_UFS_S2S_FORECAST_Abs_20130801.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# ffwi_UFS_S2S_FORECAST_Abs_20130801.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# gust_UFS_S2S_FORECAST_Abs_20130801.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# prate_UFS_S2S_FORECAST_Abs_20130801.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# rh_UFS_S2S_FORECAST_Abs_20130801.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# vsm_UFS_S2S_FORECAST_Abs_20130801.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# t2_UFS_S2S_FORECAST_Abs_20130801.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# u10_UFS_S2S_FORECAST_Abs_20130801.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# v10_UFS_S2S_FORECAST_Abs_20130801.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# vpd_UFS_S2S_FORECAST_Abs_20130801.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# wd_UFS_S2S_FORECAST_Abs_20130801.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130801.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130801.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130801.nc
# ws_UFS_S2S_FORECAST_Abs_20130801.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# cape_UFS_S2S_FORECAST_Abs_20130815.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# ffwi_UFS_S2S_FORECAST_Abs_20130815.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# gust_UFS_S2S_FORECAST_Abs_20130815.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# prate_UFS_S2S_FORECAST_Abs_20130815.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# rh_UFS_S2S_FORECAST_Abs_20130815.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# vsm_UFS_S2S_FORECAST_Abs_20130815.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# t2_UFS_S2S_FORECAST_Abs_20130815.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# u10_UFS_S2S_FORECAST_Abs_20130815.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# v10_UFS_S2S_FORECAST_Abs_20130815.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# vpd_UFS_S2S_FORECAST_Abs_20130815.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# wd_UFS_S2S_FORECAST_Abs_20130815.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130815.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130815.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130815.nc
# ws_UFS_S2S_FORECAST_Abs_20130815.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# cape_UFS_S2S_FORECAST_Abs_20130901.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# ffwi_UFS_S2S_FORECAST_Abs_20130901.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# gust_UFS_S2S_FORECAST_Abs_20130901.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# prate_UFS_S2S_FORECAST_Abs_20130901.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# rh_UFS_S2S_FORECAST_Abs_20130901.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# vsm_UFS_S2S_FORECAST_Abs_20130901.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# t2_UFS_S2S_FORECAST_Abs_20130901.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# u10_UFS_S2S_FORECAST_Abs_20130901.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# v10_UFS_S2S_FORECAST_Abs_20130901.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# vpd_UFS_S2S_FORECAST_Abs_20130901.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# wd_UFS_S2S_FORECAST_Abs_20130901.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130901.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130901.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130901.nc
# ws_UFS_S2S_FORECAST_Abs_20130901.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# cape_UFS_S2S_FORECAST_Abs_20130915.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# ffwi_UFS_S2S_FORECAST_Abs_20130915.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# gust_UFS_S2S_FORECAST_Abs_20130915.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# prate_UFS_S2S_FORECAST_Abs_20130915.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# rh_UFS_S2S_FORECAST_Abs_20130915.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# vsm_UFS_S2S_FORECAST_Abs_20130915.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# t2_UFS_S2S_FORECAST_Abs_20130915.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# u10_UFS_S2S_FORECAST_Abs_20130915.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# v10_UFS_S2S_FORECAST_Abs_20130915.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# vpd_UFS_S2S_FORECAST_Abs_20130915.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# wd_UFS_S2S_FORECAST_Abs_20130915.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20130915.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20130915.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20130915.nc
# ws_UFS_S2S_FORECAST_Abs_20130915.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# cape_UFS_S2S_FORECAST_Abs_20131001.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# ffwi_UFS_S2S_FORECAST_Abs_20131001.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# gust_UFS_S2S_FORECAST_Abs_20131001.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# prate_UFS_S2S_FORECAST_Abs_20131001.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# rh_UFS_S2S_FORECAST_Abs_20131001.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# vsm_UFS_S2S_FORECAST_Abs_20131001.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# t2_UFS_S2S_FORECAST_Abs_20131001.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# u10_UFS_S2S_FORECAST_Abs_20131001.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# v10_UFS_S2S_FORECAST_Abs_20131001.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# vpd_UFS_S2S_FORECAST_Abs_20131001.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# wd_UFS_S2S_FORECAST_Abs_20131001.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20131001.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20131001.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20131001.nc
# ws_UFS_S2S_FORECAST_Abs_20131001.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# cape_UFS_S2S_FORECAST_Abs_20131015.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# ffwi_UFS_S2S_FORECAST_Abs_20131015.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# gust_UFS_S2S_FORECAST_Abs_20131015.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# prate_UFS_S2S_FORECAST_Abs_20131015.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# rh_UFS_S2S_FORECAST_Abs_20131015.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# vsm_UFS_S2S_FORECAST_Abs_20131015.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# t2_UFS_S2S_FORECAST_Abs_20131015.nc
# u10_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# u10_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# u10_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# u10_UFS_S2S_FORECAST_Abs_20131015.nc
# v10_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# v10_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# v10_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# v10_UFS_S2S_FORECAST_Abs_20131015.nc
# vpd_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# vpd_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# vpd_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# vpd_UFS_S2S_FORECAST_Abs_20131015.nc
# wd_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# wd_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# wd_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# wd_UFS_S2S_FORECAST_Abs_20131015.nc
# ws_UFS_S2S_FORECAST_AVG_Daily_20131015.nc
# ws_UFS_S2S_FORECAST_MAX_Daily_20131015.nc
# ws_UFS_S2S_FORECAST_MIN_Daily_20131015.nc
# ws_UFS_S2S_FORECAST_Abs_20131015.nc
# cape_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# cape_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# cape_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# cape_UFS_S2S_FORECAST_Abs_20131101.nc
# ffwi_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# ffwi_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# ffwi_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# ffwi_UFS_S2S_FORECAST_Abs_20131101.nc
# gust_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# gust_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# gust_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# gust_UFS_S2S_FORECAST_Abs_20131101.nc
# prate_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# prate_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# prate_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# prate_UFS_S2S_FORECAST_Abs_20131101.nc
# rh_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# rh_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# rh_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# rh_UFS_S2S_FORECAST_Abs_20131101.nc
# vsm_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# vsm_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# vsm_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# vsm_UFS_S2S_FORECAST_Abs_20131101.nc
# t2_UFS_S2S_FORECAST_AVG_Daily_20131101.nc
# t2_UFS_S2S_FORECAST_MAX_Daily_20131101.nc
# t2_UFS_S2S_FORECAST_MIN_Daily_20131101.nc
# t2_UFS_S2S_FORECAST_Abs_20131101.nc
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
bad_ufs_all_1
# Out:
# [[],
#  [],
#  ['ffwiMAX_UFS_S2S_FORECAST_Daily_20171201.nc',
#   'ffwiMIN_UFS_S2S_FORECAST_Daily_20171201.nc'],
#  []]

# %% [markdown]
# # For Harmonic Normals and Anomalies

# %% [markdown]
# ### make final directory for files

# %%
input_dir = 'database_files'
output_dir = 'database_files_final'

# %%
m = 'UFS_S2S'
prototypes = [5,6,7,8, 'MPM']
dd = ['climos', 'anoms']
ddd = ['day', 'week']

# %%
for m in model_options:
    dir_maker(f'{output_dir}/{m}')

# %%
for d in dd:

    dir_maker(f'{output_dir}/{m}/{d}')
    
    for p in prototypes:
        
        dir_maker(os.path.join(f'{output_dir}/{m}/{d}', f'{p}'))
        
        for i in ddd:
                                  
            dir_maker(os.path.join(f'{output_dir}/{m}/{d}/{p}', f'{i}'))

# %% [markdown]
# ## Final Clean Functions

# %%
def get_harmonic(m, v, ac, subdir):


    ''' This function is designed to generate specific attribute information for harmonics. 
    
    Inputs:
    
    m: (str) model name
    v: (str) variable name
    ac: (str) anomaly or normal harmonic 
    
    Outputs:
    
    harm_dict: (str) attribute information for harmonic
    
    '''
  
    k_out = 5

    if ac == 'anoms':

        harm_dict = f'Anomaly generated by taking the difference of the timeseries with the period normal, based on lead {subdir}, which was computed as the sum of the first ({k_out}) harmonics'

    else:

        harm_dict = f'Period normal, based on lead {subdir}, computed as the sum of the first ({k_out}) harmonics'
            
    
    return harm_dict

# %%
def special_NCEP_cleaner_ac(db_file, v, f):

    ''' This function takes problematic NCEP Renalysis II files from the database 
        and adds a missing time dimension that got lost or selects one level, and 
        changes -inf values to np.nan for consistency. 
    
    
    Inputs:
    
    db_file: (xarray dataset) a NCEP Renalysis file opened with xarray
    v: (str) variable name
    f: (str) file name -- not path, just filename from final_clean_db function
    
    Outputs:
    
    db_file: (xarray dataset) the new, cleaned version of the input 
    
    '''
    

    if 'level' in list(db_file.dims):

        db_file = db_file.isel(level = 0)
        db_file = db_file.drop('level')

    if 'level' in list(db_file.coords):
        
        db_file = db_file.drop('level')        

    db_file[v] = xr.where(db_file[v] == -np.Inf, np.nan, db_file[v])

    try:
    
        db_file = db_file.rename({'lat': 'latitude', 'lon': 'longitude'})

    except:
        pass

    return db_file

# %%
def final_clean_db_ac(m, vars, p, ac):

    ''' This function takes database files and unifies all variable and coordinate names, 
    alters the file out names, performs any cleaning still necessary, assigns attributes
    and information such as units, exporting to the database_files_final directory. 

    This function assumes that CONUS404, HRRR, NAM, and NARR have already been regridded. 
    These 4 models were already 'cleaned' through the regridding process. 
    
    Inputs:
    
    m: (str) model name
    vars: (list of str) list of variable names for the model 
    p: (str) the prototype number, 5, 6, 7, 8, MPM 
    ac: (str) anoms or climos subfolder or harmonic type 
    
    Outputs:
    
    bad: (list of str) list of filenames that failed during execution  
    
    '''
    
    vars_dict = {}                                                                                                                                   # Initialize a dictionary to store variable mappings
                                                                      
    for v in vars:                                                                                                                                   # Iterate over variables
        vars_dict[v.split('_')[0]] = v                                                                                                               # Map the first part of the variable name to the full variable name
                                                                      
    input_dir = f'database_files/{m}/LEAD/{ac}/{p}'                                                                                                            # Set the input directory for standard models
    
    bad = []

    for subdir in sorted(os.listdir(input_dir)):
    
        for f in sorted(os.listdir(f'{input_dir}/{subdir}')):                                                                                        # Iterate over sorted files in the input directory
            
            try:
                
                if f[-2:] == 'nc':                                                                                                                   # Check if the file is a NetCDF file
                    file = f'{input_dir}/{subdir}/{f}'                                                                                               # Construct the full file path
                    db_file = xr.open_dataset(file)
        
        
                    if ac == 'anoms':
                        
                        file_ac = 'ANOM'
        
                    else:
                        file_ac = 'NORM'
                    
                    v = vars_dict[file.split('/')[-1].split('_')[0]]
        
                    if 'Abs' in file.split('/')[-1].split('_'):
        
                        outfile_pre = f'{file_ac}_{get_filename(m)}_Abs_{file.split('/')[-1].split('_')[-1]}'                                                  # Prepare the output file prefix
                    
                    else:
                        
                        possible = ['MIN', 'MAX', 'AVG']
                        outfile_pre = f'{list(set(possible) & set(file.split('/')[-1].split('_')))[0]}_{file_ac}_{get_filename(m)}_{file.split('/')[-1].split('_')[-1]}'     
                    
                    searchkey = list(variables_by_model[m].keys())[list(variables_by_model[m].values()).index(v)]                                    # Find the search key for the variable
                    newkey = var_names_units[searchkey]    
    
                    
                    try:
                    
                        if newkey['name'] != v:
                            db_file[newkey['name']] = db_file[v]                                                                                                         # Update the variable name
                            db_file = db_file.drop(v)                                                                                                                    # Drop the old variable name
                    
                        elif newkey['name'] == v:
                    
                            try:
                                
                                db_file[newkey['name']] = db_file[v]                                                                                                     # Update the variable name
                    
                            except KeyError:
                                
                                if ac == 'anoms':
                                    vnew = f'{v}_anoms'
                    
                                else:
                                    vnew = f'{v}_climo'                        
                                
                                db_file[newkey['name']] = db_file[vnew]                                                                                                     # Update the variable name
                                db_file = db_file.drop(vnew)                                                                                                                # Drop the old variable name
                        
                    
                    except KeyError:
                    
                        try:
                        
                            if ac == 'anoms':
                                v = f'{v}_anoms'
                    
                            else:
                                v = f'{v}_climo'
                            
                            if newkey['name'] != v:
                                db_file[newkey['name']] = db_file[v]                                                                                                    # Update the variable name
                                db_file = db_file.drop(v)                                                                                                               # Drop the old variable name
                    
                        except:
                            
                            raise
    
                    
                    if subdir == 'week':
                        
                        db_file = db_file.assign_coords({'lead_week': int(file.split('/')[-1].split('_')[-1][4:6])})                  
                        vars_to_keep = ['time', 'valid_time', 'latitude', 'longitude', newkey['name'], 'lead_week']
                    
                    else:
    
                        db_file = db_file.assign_coords({'lead_day': int(file.split('/')[-1].split('_')[-1][4:6])})                  
                        vars_to_keep = ['time', 'valid_time', 'latitude', 'longitude', newkey['name'], 'lead_day']
    
                    for keepv in vars_to_keep:
                        
                        attrs_to_del_var = []                                                                                                         # Clear old attributes             
                        
                        for key, item in db_file[keepv].attrs.items():
                            attrs_to_del_var.append(key)
                        
                        for j in attrs_to_del_var:
                            del db_file[keepv].attrs[j]  
                    
                    time_attrs = {'time': {'long_name': 'initial time of forecast','standard_name': 'forecast_reference_time'},
                                  'valid_time': {'long_name': 'time + lead', 'standard_name': 'time'}}
                    
                    db_file[newkey['name']] = db_file[newkey['name']].assign_attrs({'Variable Name': newkey['long'], 'Units': newkey['units'], 'Harmonic': get_harmonic(m, newkey['name'], ac, subdir)})    # Assign new attributes
                    
                    if subdir == 'week':
                    
                        db_file['lead_week'] = db_file['lead_week'].assign_attrs({'Description': "We aligned all valid times that have the same lead time (in weeks) from the initialization date along the 'week' axis. This means that for each forecast, the valid times that are a specific number of weeks from the initialization date are grouped together, allowing us to analyze the forecast accuracy for each lead time."
                        }) 
                    
                    else:
                    
                        db_file['lead_day'] = db_file['lead_day'].assign_attrs({'Description': "We aligned all valid times that have the same lead time (in days) from the initialization date along the 'day' axis. This means that for each forecast, the valid times that are a specific number of days from the initialization date are grouped together, allowing us to analyze the forecast accuracy for each lead time."
                        })                                              
                    
                    for vout in list(db_file.coords):                            
                        if vout not in vars_to_keep:                            
                            db_file = db_file.drop(vout)
                    
                        if vout in vars_to_keep[0:2]:
                    
                            db_file[vout] = db_file[vout].assign_attrs(time_attrs[vout])               
                                                                        
                    db_file = db_file.sortby('valid_time')                                                                                           # Sort the dataset by time
                                                                        
                    outfile = f'{newkey['name']}_{outfile_pre}'                                                                                       # Construct the final output file name
                    db_file.to_netcdf(f'database_files_final/{m}/{ac}/{p}/{subdir}/{outfile}')                                                            # Save the dataset to a NetCDF file
                    
                    print(outfile)                                                                                                                   
                    del outfile                                                                                                                      
            
            except:
                print(f'{f} to bad')
                bad.append(f)

    return bad

# %% [markdown]
# ### P = 5

# %%
m = 'UFS_S2S'
p = 5
harms = ['anoms', 'climos']

# %%
ufs_vars = [value for key,value in variables_by_model[m].items()]

# %%
ufs_vars
# Out:
# ['hpbl',
#  'cape',
#  'soilw',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  't2m',
#  'r2',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_ufs_5 = []
for ac in harms:
    print(ac)
    bad_ufs_5.append(final_clean_db_ac(m, ufs_vars, p, ac))
# Out:
# anoms
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# ...
# wd_MIN_NORM_UFS_S2S_FORECAST_lead18.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead19.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead20.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead21.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead22.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead23.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead24.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead25.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead26.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead27.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead28.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead29.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead30.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead31.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead32.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead33.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead34.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead06.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead07.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead08.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead09.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead10.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead11.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead12.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead13.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead14.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead15.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead16.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead17.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead18.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead19.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead20.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead21.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead22.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead23.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead24.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead25.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead26.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead27.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead28.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead29.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead30.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead31.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead32.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead33.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead34.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead35.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead35.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# CPU times: user 3min 5s, sys: 54min 21s, total: 57min 26s
# Wall time: 1h 31min 47s

# %%
bad_ufs_5
# Out:
# [[], []]

# %% [markdown]
# ### P = 6, 7, 8, MPM
# 5 was used for testing

# %%
m = 'UFS_S2S'
ps = [6, 7, 8, 'MPM']
harms = ['anoms', 'climos']

# %%
ufs_vars = [value for key,value in variables_by_model[m].items()]

# %%
ufs_vars
# Out:
# ['hpbl',
#  'cape',
#  'soilw',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  't2m',
#  'r2',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_ufs_all = []
for p in ps:
    sub_bad = []
    for ac in harms:
        sub_bad.append(final_clean_db_ac(m, ufs_vars, p, ac))

    bad_ufs_all.append(sub_bad)
# Out:
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# cape_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# cape_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# gust_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# gust_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# prate_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# prate_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# rh_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# rh_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# vsm_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# vsm_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# t2_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# t2_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# u10_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# u10_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead05.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead06.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead07.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead08.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead09.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead10.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead11.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead12.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead13.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead14.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead15.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead16.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead17.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead18.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead19.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead20.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead21.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead22.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead23.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead24.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead25.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead26.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead27.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead28.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead29.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead30.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead31.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead32.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead33.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead34.nc
# v10_ANOM_UFS_S2S_FORECAST_Abs_lead35.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_MAX_ANOM_UFS_S2S_FORECAST_lead35.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead00.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead01.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead02.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead03.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead04.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead05.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead06.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead07.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead08.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead09.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead10.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead11.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead12.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead13.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead14.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead15.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead16.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead17.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead18.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead19.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead20.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead21.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead22.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead23.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead24.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead25.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead26.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead27.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead28.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead29.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead30.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead31.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead32.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead33.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead34.nc
# v10_MIN_ANOM_UFS_S2S_FORECAST_lead35.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead00.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead01.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead02.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead03.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead04.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead05.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead06.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead07.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead08.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead09.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead10.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead11.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead12.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead13.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead14.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead15.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead16.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead17.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead18.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead19.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead20.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead21.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead22.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead23.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead24.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead25.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead26.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead27.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead28.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead29.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead30.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead31.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead32.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead33.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead34.nc
# wd_AVG_ANOM_UFS_S2S_FORECAST_lead35.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead00.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead01.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead02.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead03.nc
# wd_ANOM_UFS_S2S_FORECAST_Abs_lead04.nc
# ...
# wd_MIN_NORM_UFS_S2S_FORECAST_lead19.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead20.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead21.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead22.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead23.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead24.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead25.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead26.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead27.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead28.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead29.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead30.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead31.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead32.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead33.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead34.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead06.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead07.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead08.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead09.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead10.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead11.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead12.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead13.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead14.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead15.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead16.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead17.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead18.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead19.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead20.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead21.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead22.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead23.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead24.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead25.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead26.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead27.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead28.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead29.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead30.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead31.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead32.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead33.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead34.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead35.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead35.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead06.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead07.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead08.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead09.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead10.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead11.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead12.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead13.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead14.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead15.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead16.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead17.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead18.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead19.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead20.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead21.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead22.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead23.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead24.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead25.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead26.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead27.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead28.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead29.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead30.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead31.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead32.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead33.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead34.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead35.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# cape_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# cape_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# gust_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# gust_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# prate_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# prate_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# rh_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# rh_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# vsm_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# vsm_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# t2_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# t2_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# u10_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# u10_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# v10_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# v10_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# wd_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# wd_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_AVG_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead00.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead01.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead02.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead03.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead04.nc
# ws_NORM_UFS_S2S_FORECAST_Abs_lead05.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MAX_NORM_UFS_S2S_FORECAST_lead05.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead00.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead01.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead02.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead03.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead04.nc
# ws_MIN_NORM_UFS_S2S_FORECAST_lead05.nc
# CPU times: user 12min 5s, sys: 3h 41min 26s, total: 3h 53min 32s
# Wall time: 6h 6min 33s

# %%
bad_ufs_all
# Out:
# [[[], []], [[], []], [[], []], [[], []]]
