# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://media.licdn.com/dms/image/C4E0BAQFlOZSAJABP4w/company-logo_200_200/0/1548285168598?e=2147483647&v=beta&t=g4jl8rEhB7HLJuNZhU6OkJWHW4cul_y9Kj_aoD7p0_Y" alt="STI Logo" style="height: 98px;">
# </div>
#
#
# <h1>Calculate Surface-Based Hot Dry Windy for the UFS S2S Model</h1>
# By: Kayla Besong, PhD
#     <br>
# Last Edited: 11/29/23
# <br>
# <br>
# <br>
# Takes models/variables downloaded and calculates surface based hot-dry-windy. The hot-dry-windy calculation uses vapor pressure deficit and multiplies by windspeed, hence leveraging previously calculated variables. The function that computes the 24HR AVG, MIN, MAX outputs is in File_concat_mod_functions.ipynb.
# <br>
# <br>
# NOTE: The operational and 'true' hot-dry-windy index (HDWI) is not computed at the surface, rather it involves analyzing vpd and windspeed in the lowest 500m of the atmosphere and is  more computationally intensive. The 'true' HDWI also takes the max value of the day. Here, by just multiplying vpd by windspeed at the surface, the resulting product is a 'surface-based-hot-dry-windy'. The difference between surface based HDW and the HDWI can be stark depending on the region you are analyzing. Please see: (Kramer et al., 2024; Watts et al., 2020).
# <br>
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ## Import needed libraries, etc.

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from dask.distributed import Client, LocalCluster
import dask.array as da
import os
import glob
from metpy.units import units
import math

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## OPTIONAL: Establish a dask client. This is a lot of data.

# %%
Cluster = LocalCluster(n_workers = 8, threads_per_worker=4, memory_limit='30GB',  processes=True)
#Cluster = LocalCluster()

# %%
client = Client(Cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:41580' processes=8 threads=32, memory=223.52 GiB>

# %% [markdown]
# ### The integral notebook of functions to run

# %%
# %run ../../../Universal_Functions/File_concat_mod_functions.ipynb

# %% [markdown]
# # Calculate HDW

# %%
model = 'UFS_S2S'
#p = 8
ps = [6, 7, 8]        # define which prototype 
ps = [5]        # define which prototype

# %%
var_list = ['wspeed', 'vpd']
var_list
# Out:
# ['wspeed', 'vpd']

# %%
main_dir = '../../../../database_files'

# %%
def resampler_UFS_hdw(v, var_file_cc, output_dir):
     
    model_save_str = get_filename('UFS_S2S')

    try:

        print(f'starting {i} {v}')
               
        model_abs = var_file_cc[v].resample(valid_time='24H').mean(dim='valid_time', skipna = True).to_dataset()
        model_min = var_file_cc[v].resample(valid_time='24H').min(dim='valid_time', skipna = True).to_dataset()
        model_max = var_file_cc[v].resample(valid_time='24H').max(dim='valid_time', skipna = True).to_dataset()
                    
        # save_file(model_abs, f'{i}', f'{v}_UFS_S2S_FORECAST_AVG_Daily_{i.split('/')[-1]}.nc')
        # save_file(model_min, f'{i}', f'{v}_UFS_S2S_FORECAST_MIN_Daily_{i.split('/')[-1]}.nc')
        # save_file(model_max, f'{i}', f'{v}_UFS_S2S_FORECAST_MAX_Daily_{i.split('/')[-1]}.nc')
        # save_file(var_file_cc, f'{i}', f'{v}_UFS_S2S_FORECAST_Abs_{i.split('/')[-1]}.nc')

        save_file(model_abs, f'{i}', f'{v}AVG_{model_save_str}_Daily_{i.split('/')[-1]}.nc')
        save_file(model_min, f'{i}', f'{v}MIN_{model_save_str}_Daily_{i.split('/')[-1]}.nc')
        save_file(model_max, f'{i}', f'{v}MAX_{model_save_str}_Daily_{i.split('/')[-1]}.nc')
        save_file(var_file_cc, f'{i}', f'{v}_{model_save_str}_Abs_{i.split('/')[-1]}.nc')

    except OSError:
        print(f'{v} not available for {i}')

# %%
# %%time

for p in ps:

    parent_dirs = glob.glob(os.path.join(f'{main_dir}/{model}/{p}/', '*'))

    for i in parent_dirs:
                    
        w_files = glob.glob(os.path.join(f'{i}/', f'*{var_list[0]}*Abs*'))[0]                      # read in vpd, windspeed 
        vpd_files = glob.glob(os.path.join(f'{i}/', f'*{var_list[1]}*Abs*'))[0]
    
        w_file_cc = xr.open_dataset(w_files).chunk(get_chunk(model))
        vpd_file_cc = xr.open_dataset(vpd_files).chunk(get_chunk(model))
        
        w_file_cc = w_file_cc.sortby('valid_time')
        vpd_file_cc = vpd_file_cc.sortby('valid_time')
    
        hdwi = (vpd_file_cc['vpd']*w_file_cc['wspeed']).to_dataset(name = 'hdw')                   # calculate the surface based hot-dry-windy
    
        resampler_UFS_hdw('hdw', hdwi.chunk(get_chunk(model)), main_dir)                           # call the special UFS min, max, avg processor in File_concat_mod_functions.ipynb
# Out:
# starting ../../../../database_files/UFS_S2S/5/20170101 hdw
# starting ../../../../database_files/UFS_S2S/5/20170115 hdw
# starting ../../../../database_files/UFS_S2S/5/20170201 hdw
# starting ../../../../database_files/UFS_S2S/5/20170215 hdw
# starting ../../../../database_files/UFS_S2S/5/20170301 hdw
# starting ../../../../database_files/UFS_S2S/5/20170315 hdw
# starting ../../../../database_files/UFS_S2S/5/20170401 hdw
# starting ../../../../database_files/UFS_S2S/5/20170415 hdw
# starting ../../../../database_files/UFS_S2S/5/20170501 hdw
# starting ../../../../database_files/UFS_S2S/5/20170515 hdw
# starting ../../../../database_files/UFS_S2S/5/20170601 hdw
# starting ../../../../database_files/UFS_S2S/5/20170615 hdw
# starting ../../../../database_files/UFS_S2S/5/20170701 hdw
# starting ../../../../database_files/UFS_S2S/5/20170715 hdw
# starting ../../../../database_files/UFS_S2S/5/20170801 hdw
# starting ../../../../database_files/UFS_S2S/5/20170815 hdw
# starting ../../../../database_files/UFS_S2S/5/20170901 hdw
# starting ../../../../database_files/UFS_S2S/5/20170915 hdw
# starting ../../../../database_files/UFS_S2S/5/20171001 hdw
# starting ../../../../database_files/UFS_S2S/5/20171015 hdw
# starting ../../../../database_files/UFS_S2S/5/20171101 hdw
# starting ../../../../database_files/UFS_S2S/5/20171115 hdw
# starting ../../../../database_files/UFS_S2S/5/20171201 hdw
# starting ../../../../database_files/UFS_S2S/5/20171215 hdw
# starting ../../../../database_files/UFS_S2S/5/20110401 hdw
# starting ../../../../database_files/UFS_S2S/5/20110415 hdw
# starting ../../../../database_files/UFS_S2S/5/20110501 hdw
# starting ../../../../database_files/UFS_S2S/5/20110515 hdw
# starting ../../../../database_files/UFS_S2S/5/20110601 hdw
# starting ../../../../database_files/UFS_S2S/5/20110615 hdw
# starting ../../../../database_files/UFS_S2S/5/20110701 hdw
# starting ../../../../database_files/UFS_S2S/5/20110715 hdw
# starting ../../../../database_files/UFS_S2S/5/20110801 hdw
# starting ../../../../database_files/UFS_S2S/5/20110815 hdw
# starting ../../../../database_files/UFS_S2S/5/20110901 hdw
# starting ../../../../database_files/UFS_S2S/5/20110915 hdw
# starting ../../../../database_files/UFS_S2S/5/20111001 hdw
# starting ../../../../database_files/UFS_S2S/5/20111015 hdw
# starting ../../../../database_files/UFS_S2S/5/20111101 hdw
# starting ../../../../database_files/UFS_S2S/5/20111115 hdw
# starting ../../../../database_files/UFS_S2S/5/20111201 hdw
# starting ../../../../database_files/UFS_S2S/5/20111215 hdw
# starting ../../../../database_files/UFS_S2S/5/20120101 hdw
# starting ../../../../database_files/UFS_S2S/5/20120115 hdw
# starting ../../../../database_files/UFS_S2S/5/20120201 hdw
# starting ../../../../database_files/UFS_S2S/5/20120215 hdw
# starting ../../../../database_files/UFS_S2S/5/20120301 hdw
# starting ../../../../database_files/UFS_S2S/5/20120315 hdw
# starting ../../../../database_files/UFS_S2S/5/20120401 hdw
# starting ../../../../database_files/UFS_S2S/5/20120415 hdw
# starting ../../../../database_files/UFS_S2S/5/20120501 hdw
# starting ../../../../database_files/UFS_S2S/5/20120515 hdw
# starting ../../../../database_files/UFS_S2S/5/20120601 hdw
# starting ../../../../database_files/UFS_S2S/5/20120615 hdw
# starting ../../../../database_files/UFS_S2S/5/20120701 hdw
# starting ../../../../database_files/UFS_S2S/5/20120715 hdw
# starting ../../../../database_files/UFS_S2S/5/20120801 hdw
# starting ../../../../database_files/UFS_S2S/5/20120815 hdw
# starting ../../../../database_files/UFS_S2S/5/20120901 hdw
# starting ../../../../database_files/UFS_S2S/5/20120915 hdw
# starting ../../../../database_files/UFS_S2S/5/20121001 hdw
# starting ../../../../database_files/UFS_S2S/5/20121015 hdw
# starting ../../../../database_files/UFS_S2S/5/20121101 hdw
# starting ../../../../database_files/UFS_S2S/5/20121115 hdw
# starting ../../../../database_files/UFS_S2S/5/20121201 hdw
# starting ../../../../database_files/UFS_S2S/5/20121215 hdw
# starting ../../../../database_files/UFS_S2S/5/20130101 hdw
# starting ../../../../database_files/UFS_S2S/5/20130115 hdw
# starting ../../../../database_files/UFS_S2S/5/20130201 hdw
# starting ../../../../database_files/UFS_S2S/5/20130215 hdw
# starting ../../../../database_files/UFS_S2S/5/20130301 hdw
# starting ../../../../database_files/UFS_S2S/5/20130315 hdw
# starting ../../../../database_files/UFS_S2S/5/20130401 hdw
# starting ../../../../database_files/UFS_S2S/5/20130415 hdw
# starting ../../../../database_files/UFS_S2S/5/20130501 hdw
# starting ../../../../database_files/UFS_S2S/5/20130515 hdw
# starting ../../../../database_files/UFS_S2S/5/20130601 hdw
# starting ../../../../database_files/UFS_S2S/5/20130615 hdw
# starting ../../../../database_files/UFS_S2S/5/20130701 hdw
# starting ../../../../database_files/UFS_S2S/5/20130715 hdw
# starting ../../../../database_files/UFS_S2S/5/20130801 hdw
# starting ../../../../database_files/UFS_S2S/5/20130815 hdw
# starting ../../../../database_files/UFS_S2S/5/20130901 hdw
# starting ../../../../database_files/UFS_S2S/5/20130915 hdw
# starting ../../../../database_files/UFS_S2S/5/20131001 hdw
# starting ../../../../database_files/UFS_S2S/5/20131015 hdw
# starting ../../../../database_files/UFS_S2S/5/20131101 hdw
# starting ../../../../database_files/UFS_S2S/5/20131115 hdw
# starting ../../../../database_files/UFS_S2S/5/20131201 hdw
# starting ../../../../database_files/UFS_S2S/5/20131215 hdw
# starting ../../../../database_files/UFS_S2S/5/20140101 hdw
# starting ../../../../database_files/UFS_S2S/5/20140115 hdw
# starting ../../../../database_files/UFS_S2S/5/20140201 hdw
# starting ../../../../database_files/UFS_S2S/5/20140215 hdw
# starting ../../../../database_files/UFS_S2S/5/20140301 hdw
# starting ../../../../database_files/UFS_S2S/5/20140315 hdw
# starting ../../../../database_files/UFS_S2S/5/20140401 hdw
# starting ../../../../database_files/UFS_S2S/5/20140415 hdw
# starting ../../../../database_files/UFS_S2S/5/20140501 hdw
# starting ../../../../database_files/UFS_S2S/5/20140515 hdw
# starting ../../../../database_files/UFS_S2S/5/20140601 hdw
# starting ../../../../database_files/UFS_S2S/5/20140615 hdw
# starting ../../../../database_files/UFS_S2S/5/20140701 hdw
# starting ../../../../database_files/UFS_S2S/5/20140715 hdw
# starting ../../../../database_files/UFS_S2S/5/20140801 hdw
# starting ../../../../database_files/UFS_S2S/5/20140815 hdw
# starting ../../../../database_files/UFS_S2S/5/20140901 hdw
# starting ../../../../database_files/UFS_S2S/5/20140915 hdw
# starting ../../../../database_files/UFS_S2S/5/20141001 hdw
# starting ../../../../database_files/UFS_S2S/5/20141015 hdw
# starting ../../../../database_files/UFS_S2S/5/20141101 hdw
# starting ../../../../database_files/UFS_S2S/5/20141115 hdw
# starting ../../../../database_files/UFS_S2S/5/20141201 hdw
# starting ../../../../database_files/UFS_S2S/5/20141215 hdw
# starting ../../../../database_files/UFS_S2S/5/20150101 hdw
# starting ../../../../database_files/UFS_S2S/5/20150115 hdw
# starting ../../../../database_files/UFS_S2S/5/20150201 hdw
# starting ../../../../database_files/UFS_S2S/5/20150215 hdw
# starting ../../../../database_files/UFS_S2S/5/20150301 hdw
# starting ../../../../database_files/UFS_S2S/5/20150315 hdw
# starting ../../../../database_files/UFS_S2S/5/20150401 hdw
# starting ../../../../database_files/UFS_S2S/5/20150415 hdw
# starting ../../../../database_files/UFS_S2S/5/20150501 hdw
# starting ../../../../database_files/UFS_S2S/5/20150515 hdw
# starting ../../../../database_files/UFS_S2S/5/20150601 hdw
# starting ../../../../database_files/UFS_S2S/5/20150615 hdw
# starting ../../../../database_files/UFS_S2S/5/20150701 hdw
# starting ../../../../database_files/UFS_S2S/5/20150715 hdw
# starting ../../../../database_files/UFS_S2S/5/20150801 hdw
# starting ../../../../database_files/UFS_S2S/5/20150815 hdw
# starting ../../../../database_files/UFS_S2S/5/20150901 hdw
# starting ../../../../database_files/UFS_S2S/5/20150915 hdw
# starting ../../../../database_files/UFS_S2S/5/20151001 hdw
# starting ../../../../database_files/UFS_S2S/5/20151015 hdw
# starting ../../../../database_files/UFS_S2S/5/20151101 hdw
# starting ../../../../database_files/UFS_S2S/5/20151115 hdw
# starting ../../../../database_files/UFS_S2S/5/20151201 hdw
# starting ../../../../database_files/UFS_S2S/5/20151215 hdw
# starting ../../../../database_files/UFS_S2S/5/20160101 hdw
# starting ../../../../database_files/UFS_S2S/5/20160115 hdw
# starting ../../../../database_files/UFS_S2S/5/20160201 hdw
# starting ../../../../database_files/UFS_S2S/5/20160215 hdw
# starting ../../../../database_files/UFS_S2S/5/20160301 hdw
# starting ../../../../database_files/UFS_S2S/5/20160315 hdw
# starting ../../../../database_files/UFS_S2S/5/20160401 hdw
# starting ../../../../database_files/UFS_S2S/5/20160415 hdw
# starting ../../../../database_files/UFS_S2S/5/20160501 hdw
# starting ../../../../database_files/UFS_S2S/5/20160515 hdw
# starting ../../../../database_files/UFS_S2S/5/20160601 hdw
# starting ../../../../database_files/UFS_S2S/5/20160615 hdw
# starting ../../../../database_files/UFS_S2S/5/20160701 hdw
# starting ../../../../database_files/UFS_S2S/5/20160715 hdw
# starting ../../../../database_files/UFS_S2S/5/20160801 hdw
# starting ../../../../database_files/UFS_S2S/5/20160815 hdw
# starting ../../../../database_files/UFS_S2S/5/20160901 hdw
# starting ../../../../database_files/UFS_S2S/5/20160915 hdw
# starting ../../../../database_files/UFS_S2S/5/20161001 hdw
# starting ../../../../database_files/UFS_S2S/5/20161015 hdw
# starting ../../../../database_files/UFS_S2S/5/20161101 hdw
# starting ../../../../database_files/UFS_S2S/5/20161115 hdw
# starting ../../../../database_files/UFS_S2S/5/20161201 hdw
# starting ../../../../database_files/UFS_S2S/5/20161215 hdw
# starting ../../../../database_files/UFS_S2S/5/20180101 hdw
# starting ../../../../database_files/UFS_S2S/5/20180115 hdw
# starting ../../../../database_files/UFS_S2S/5/20180201 hdw
# starting ../../../../database_files/UFS_S2S/5/20180215 hdw
# starting ../../../../database_files/UFS_S2S/5/20180301 hdw
# starting ../../../../database_files/UFS_S2S/5/20180315 hdw
# CPU times: user 4min 54s, sys: 51 s, total: 5min 45s
# Wall time: 17min 16s
