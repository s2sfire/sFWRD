# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://media.licdn.com/dms/image/C4E0BAQFlOZSAJABP4w/company-logo_200_200/0/1548285168598?e=2147483647&v=beta&t=g4jl8rEhB7HLJuNZhU6OkJWHW4cul_y9Kj_aoD7p0_Y" alt="STI Logo" style="height: 98px;">
# </div>
#
#
# <h1>Finalize Database Files</h1>
# By: Kayla Besong, PhD
#     <br>
# Last Edited: 05/15/24
# <br>
# <br>
# <br>
# This script takes all the downloaded, cleaned, and regridded renalaysis and forecast data in the database and generates the final form of each file. This includes changing variable names where needed, adding metadata, and unifying missing/nan values.
# <br>
# <br>
# A second section for finalizing harmonic analysis output is provided.
# <br>
# <br>
# This code is not pretty but it got the job done in the time it needed to get done! Make appropriate edits you need for your version.
# <br>
# <br>
# Note: if you did not regrid the NAM, NARR, HRRR, or CONUS404 this will not work on them to an extent. Some cleaning functions for them can be found in Regrid_Database.ipynb and Regrid_Check_n_Clean.ipynb.
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %%
import numpy as np
import xarray as xr
import pandas as pd
import os
import glob

# %%
# %run File_concat_mod_functions.ipynb

# %%
model_options = ['CONUS404', 'HRRR', 'NAM', 'NARR', 'ERA5', 'NCEP']

# %%
### manually input the attributes you'd like to store as metadata in each netcdf file

var_names_units = {

          'PBL': {'name': 'pbl', 'long': 'Planetary Boundary Layer Height', 'units': 'm'},                   
          'CAPE': {'name': 'cape', 'long': 'Convective Available Potential Enegery', 'units': 'J/kg'},
          'MLCAPE': {'name': 'mlcape',  'long': 'Mixed Layer Convective Available Potential Enegery', 'units': 'J/kg'},
          'SBCAPE': {'name': 'sbcape', 'long': 'Surface Based Convective Available Potential Enegery', 'units': 'J/kg'},
          'SOILM': {'name': 'sm', 'long': 'Soil Moisture', 'units': 'kg/m^3', 'other': 'The first layer below the surface, varies per sFWD to what depth'},
          'VSM': {'name': 'vsm', 'long': 'Volumetric Soil Moisture', 'units': 'm^3/m^3 (ratio)', 'other': 'The first layer below the surface, varies per sFWD to what depth'},
          'U10': {'name': 'u10', 'long': 'u-component of the 10-m wind', 'units': 'm/s'},
          'V10': {'name': 'v10', 'long': 'v-component of the 10-m wind', 'units': 'm/s'},
          'GUST':{'name':  'gust', 'long': 'Instantaneous 10-m Wind Gust', 'units': 'm/s'},
          'PRATE': {'name': 'prate', 'long': 'Precipitation Rate', 'units': 'kg/m^2s'},
          'TP': {'name': 'tp', 'long': 'Total Precipitation', 'units': 'kg/m^2'},
          'TCP': {'name': 'tcp', 'long': 'Total Convective Precipitation', 'units': 'm'},
          'LSPR': {'name': 'lspr', 'long': 'Large Scale Rain Rate', 'units': 'kg/m^2s'},
          'TEMP': {'name': 't2',  'long': '2-m Temperature', 'units': 'K'},
          'RH': {'name': 'rh', 'long': 'Relative Humidity', 'units': '%'},
          'DEWPOINT': {'name': 'd2', 'long': '2-m Dewpoint', 'units': 'K'},
          'WINDSPEED': {'name': 'ws',  'long': 'Wind Speed', 'units': 'm/s'},
          'WINDDIR': {'name': 'wd',  'long': 'Wind Direction', 'units': 'degrees'},
          'HDWI': {'name': 'hdw',  'long': 'Surface-Based Hot Dry Windy', 'units': 'hPa*m/s'},
          'VPD': {'name': 'vpd', 'long': 'Vapor Pressure Deficit', 'units': 'hPa'},
          'FOSBERG': {'name': 'ffwi', 'long': 'Fosberg Fire Weather Index', 'units': 'N/A [0-100 scale]'}}

# %%
### A manual list of variables that link via keys-to-keys to the metadata dict. It is seperate from the dictionaries stored in File_concat_mod_functions.ipynb for that reason. 

variables_by_model =  {

    'CONUS404': {'PBL': 'PBLH', 'SBCAPE': 'SBCAPE', 'MLCAPE': 'MLCAPE','VSM':'SMOIS', 'U10': 'U10', 'V10': 'V10','WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi','VPD': 'vpd', 'TP': 'PREC_ACC_NC', 'TEMP': 'T2', 'RH': 'rh', 'FOSBERG': 'ffwi', 'DEWPOINT': 'TD2'},
    'ERA5': {'PBL': 'blh', 'CAPE': 'cape', 'VSM':'swvl1','U10': 'u10', 'V10': 'v10', 'GUST': 'i10fg','TP': 'tp', 'TCP': 'cp', 'LSPR': 'lsrr','TEMP': 't2m', 'DEWPOINT': 'd2m','RH': 'rh', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'},
    'HRRR': {'PBL': 'blh', 'CAPE': 'cape', 'SOILM':'mstav','U10': 'u10', 'V10': 'v10', 'GUST': 'gust','PRATE': 'prate', 'TP': 'tp', 'TEMP': 't2m', 'DEWPOINT': 'd2m', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi', 'RH': 'rh'},
    'NAM': {'PBL': 'hpbl', 'CAPE': 'cape', 'SOILM': 'sm', 'U10': 'u10', 'V10': 'v10', 'GUST': 'gust', 'TP': 'tp', 'TEMP': 't2m', 'RH': 'r', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'},
    'NARR': {'PBL': 'Planetary_boundary_layer_height_surface', 'SOILM':'Soil_moisture_content_layer_between_two_depths_below_surface_layer', 'U10': 'u-component_of_wind_height_above_ground', 'V10': 'v-component_of_wind_height_above_ground', 'PRATE': 'Precipitation_rate_surface', 'TP': 'Total_precipitation_surface_3_Hour_Accumulation','TEMP': 'Temperature_height_above_ground', 'RH': 'Relative_humidity_height_above_ground', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'},
    'NCEP': {'SOILM':'soilw', 'U10': 'uwnd', 'V10': 'vwnd', 'PRATE': 'prate', 'TEMP': 'air', 'RH': 'rhum', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'},
    'UFS_S2S': {'PBL': 'hpbl', 'CAPE': 'cape', 'VSM':'soilw', 'U10': 'u10', 'V10': 'v10', 'GUST': 'gust', 'PRATE': 'prate', 'TEMP': 't2m', 'RH': 'r2', 'WINDSPEED': 'wspeed', 'WINDDIR': 'wdir', 'HDWI': 'hdwi', 'VPD': 'vpd', 'FOSBERG': 'ffwi'}}

# %% [markdown]
# # For the Database

# %% [markdown]
# ### make final directory for files

# %%
for m in model_options:
    dir_maker(f'database_files_final/{m}')

# %% [markdown]
# ## Final Clean Function

# %%
def special_NCEP_cleaner(db_file, v, f):

    ''' This function takes problematic NCEP Renalysis II files from the database 
        and adds a missing time dimension that got lost or selects one level, converts 
        longitudes to -180 to 0, and changes -inf values to np.nan for consistency. 
    
    
    Inputs:
    
    db_file: (xarray dataset) a NCEP Renalysis file opened with xarray
    v: (str) variable name
    f: (str) file name -- not path, just filename from final_clean_db function
    
    Outputs:
    
    db_file: (xarray dataset) the new, cleaned version of the input 
    
    '''
    

    if 'level' in list(db_file.dims):

        db_file = db_file.isel(level = 0)
        db_file = db_file.drop('level')

    if 'level' in list(db_file.coords):
        
        db_file = db_file.drop('level')        

    if v == 'vpd' and f.split('_')[0][-3:] == 'AVG':

        db_file['time'] = db_file[v].time.values

    db_file[v] = xr.where(db_file[v] == -np.Inf, np.nan, db_file[v])
    db_file = db_file.rename({'lat': 'latitude', 'lon': 'longitude'})
    db_file['longitude'] = ((db_file['longitude'] + 180) % 360) - 180

    return db_file

# %%
def final_clean_db(m, vars):

    ''' This function takes database files and unifies all variable and coordinate names, 
    alters the file out names, performs any cleaning still necessary, assigns attributes
    and information such as units, exporting to the database_files_final directory. 

    This function assumes that CONUS404, HRRR, NAM, and NARR have already been regridded. 
    These 4 models were already 'cleaned' through the regridding process. 
    
    Inputs:
    
    m: (s) model name
    vars: (list of strings) list of variable names for the model 
    
    Outputs:
    
    Nothing, files are just saved to specified output directory. 
    
    '''

    
    vars_dict = {}                                                                                                                           # Initialize a dictionary to store variable mappings
                                                              
    for v in vars:                                                                                                                           # Iterate over variables
        vars_dict[v.split('_')[0]] = v                                                                                                       # Map the first part of the variable name to the full variable name
                                                              
    if m == 'ERA5' or m == 'NCEP':                                                                                                           # Check if the model is ERA5 or NCEP
        input_dir = f'database_files/{m}'                                                                                                    # Set the input directory for standard models
    
    else:                                                          
        input_dir = f'database_files_regridded/{m}'                                                                                          # Set the input directory for regridded models

    bad = []
    
    for f in sorted(os.listdir(input_dir)):                                                                                                  # Iterate over sorted files in the input directory
        
        try:
        
            if f[-2:] == 'nc':                                                                                                                   # Check if the file is a NetCDF file
                file = f'{input_dir}/{f}'                                                                                                        # Construct the full file path
                db_file = xr.open_dataset(file)                                                                                                  
        
                try:
                    v = vars_dict[file.split('/')[-1].split('_')[0]]                                                                             # Extract the variable name from the file name
                    outfile_pre = f'{get_filename(m)}_Abs_{file.split('/')[-1].split('_')[-1]}'                                                  # Prepare the output file prefix
        
                    if m == 'NARR':                                                                                                              # Special handling for NARR model
                        if 'Daily' in file.split('/')[-1].split('_'):                                                                            # Check if the file is daily
                            outfile_pre = f'{get_filename(m)}_{file.split('/')[-1].split('_')[-5][-3:]}_Daily_{file.split('/')[-1].split('_')[-1]}'          
                
                except KeyError:                                                                                                                 # Handle cases where the variable is not found
                    v = vars_dict[file.split('/')[-1].split('_')[0][0:-3]]                                                                       # Adjust the variable extraction for special cases
                    outfile_pre = f'{get_filename(m)}_{file.split('/')[-1].split('_')[0][-3:]}_Daily_{file.split('/')[-1].split('_')[-1]}'          
        
                searchkey = list(variables_by_model[m].keys())[list(variables_by_model[m].values()).index(v)]                                    # Find the search key for the variable
                newkey = var_names_units[searchkey]                                                                                              # Get the new variable name and units
                                                                  
                if newkey['name'] != v:                                                                                                          # Check if the variable name needs to be updated
                    db_file[newkey['name']] = db_file[v]                                                                                         # Update the variable name
                    db_file = db_file.drop(v)                                                                                                    # Drop the old variable name
                                                                  
                attrs_to_del = []                                                                                                                # Clear old attributes 
    
                for key, item in db_file.attrs.items():
                    attrs_to_del.append(key)
                
                for i in attrs_to_del:
                    del db_file.attrs[i]
    
                attrs_to_del_var = []                                                                                                            # Clear old attributes             
                
                for key, item in db_file[newkey['name']].attrs.items():
                    attrs_to_del_var.append(key)
                
                for j in attrs_to_del_var:
                    del db_file[newkey['name']].attrs[j]  
                            
                db_file[newkey['name']] = db_file[newkey['name']].assign_attrs({'Variable Name': newkey['long'], 'Units': newkey['units']})    # Assign new attributes
        
                if m == 'ERA5' or m == 'NCEP':                                                                                                   # Handle attributes for ERA5 and NCEP
                    db_file = db_file.assign_attrs({'Original Grid': 'latlon', 'New Regrid': 'no regridding, latlon'})                      
                else:                      
                    db_file = db_file.assign_attrs({'Original Grid': 'Lambert Conformal', 'New Regrid': 'latlon'})                               # Handle attributes for other models
                              
                if m == 'CONUS404':                                                                                                              # Special handling for CONUS404 model
                    db_file = db_file.rename({'Time': 'time'})                                                            
                elif m == 'NCEP':                                                                                                                # Special cleaning for NCEP model
                    db_file = special_NCEP_cleaner(db_file, v, f)
    
                elif m == 'NAM':
                    db_file = db_file.groupby('time').first()
                                                                    
                db_file = db_file.sortby('time')                                                                                                 # Sort the dataset by time
                                                                    
                outfile = f'{newkey['name']}_{outfile_pre}'                                                                                      # Construct the final output file name
                db_file.to_netcdf(f'database_files_final/{m}/{outfile}')                                                                         # Save the dataset to a NetCDF file
                
                print(outfile)                                                                                                                   
                del outfile                                                                                                                      
        
        except:
    
            bad.append(f)
    
    return bad

# %% [markdown]
# ### ERA5

# %%
m = 'ERA5'

# %%
era_vars = [value for key,value in variables_by_model[m].items()]

# %%
era_vars
# Out:
# ['blh',
#  'cape',
#  'swvl1',
#  'u10',
#  'v10',
#  'i10fg',
#  'tp',
#  'cp',
#  'lsrr',
#  't2m',
#  'd2m',
#  'rh',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

final_clean_db(m, era_vars)
# Out:
# pbl_ERA5_REANALYSIS_AVG_Daily_2011.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2012.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2013.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2014.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2015.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2016.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2017.nc
# pbl_ERA5_REANALYSIS_AVG_Daily_2018.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2011.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2012.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2013.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2014.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2015.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2016.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2017.nc
# pbl_ERA5_REANALYSIS_MAX_Daily_2018.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2011.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2012.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2013.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2014.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2015.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2016.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2017.nc
# pbl_ERA5_REANALYSIS_MIN_Daily_2018.nc
# pbl_ERA5_REANALYSIS_Abs_2011.nc
# pbl_ERA5_REANALYSIS_Abs_2012.nc
# pbl_ERA5_REANALYSIS_Abs_2013.nc
# pbl_ERA5_REANALYSIS_Abs_2014.nc
# pbl_ERA5_REANALYSIS_Abs_2015.nc
# pbl_ERA5_REANALYSIS_Abs_2016.nc
# pbl_ERA5_REANALYSIS_Abs_2017.nc
# pbl_ERA5_REANALYSIS_Abs_2018.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2011.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2012.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2013.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2014.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2015.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2016.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2017.nc
# cape_ERA5_REANALYSIS_AVG_Daily_2018.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2011.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2012.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2013.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2014.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2015.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2016.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2017.nc
# cape_ERA5_REANALYSIS_MAX_Daily_2018.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2011.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2012.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2013.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2014.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2015.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2016.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2017.nc
# cape_ERA5_REANALYSIS_MIN_Daily_2018.nc
# cape_ERA5_REANALYSIS_Abs_2011.nc
# cape_ERA5_REANALYSIS_Abs_2012.nc
# cape_ERA5_REANALYSIS_Abs_2013.nc
# cape_ERA5_REANALYSIS_Abs_2014.nc
# cape_ERA5_REANALYSIS_Abs_2015.nc
# cape_ERA5_REANALYSIS_Abs_2016.nc
# cape_ERA5_REANALYSIS_Abs_2017.nc
# cape_ERA5_REANALYSIS_Abs_2018.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2011.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2012.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2013.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2014.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2015.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2016.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2017.nc
# tcp_ERA5_REANALYSIS_AVG_Daily_2018.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2011.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2012.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2013.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2014.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2015.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2016.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2017.nc
# tcp_ERA5_REANALYSIS_MAX_Daily_2018.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2011.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2012.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2013.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2014.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2015.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2016.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2017.nc
# tcp_ERA5_REANALYSIS_MIN_Daily_2018.nc
# tcp_ERA5_REANALYSIS_Abs_2011.nc
# tcp_ERA5_REANALYSIS_Abs_2012.nc
# tcp_ERA5_REANALYSIS_Abs_2013.nc
# tcp_ERA5_REANALYSIS_Abs_2014.nc
# tcp_ERA5_REANALYSIS_Abs_2015.nc
# tcp_ERA5_REANALYSIS_Abs_2016.nc
# tcp_ERA5_REANALYSIS_Abs_2017.nc
# tcp_ERA5_REANALYSIS_Abs_2018.nc
# d2_ERA5_REANALYSIS_AVG_Daily_2011.nc
# d2_ERA5_REANALYSIS_AVG_Daily_2012.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2012.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2013.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2014.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2015.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2016.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2017.nc
# vsm_ERA5_REANALYSIS_MAX_Daily_2018.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2011.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2012.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2013.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2014.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2015.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2016.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2017.nc
# vsm_ERA5_REANALYSIS_MIN_Daily_2018.nc
# vsm_ERA5_REANALYSIS_Abs_2011.nc
# vsm_ERA5_REANALYSIS_Abs_2012.nc
# vsm_ERA5_REANALYSIS_Abs_2013.nc
# vsm_ERA5_REANALYSIS_Abs_2014.nc
# vsm_ERA5_REANALYSIS_Abs_2015.nc
# vsm_ERA5_REANALYSIS_Abs_2016.nc
# vsm_ERA5_REANALYSIS_Abs_2017.nc
# vsm_ERA5_REANALYSIS_Abs_2018.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2011.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2012.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2013.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2014.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2015.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2016.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2017.nc
# t2_ERA5_REANALYSIS_AVG_Daily_2018.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2011.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2012.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2013.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2014.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2015.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2016.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2017.nc
# t2_ERA5_REANALYSIS_MAX_Daily_2018.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2011.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2012.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2013.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2014.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2015.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2016.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2017.nc
# t2_ERA5_REANALYSIS_MIN_Daily_2018.nc
# t2_ERA5_REANALYSIS_Abs_2011.nc
# t2_ERA5_REANALYSIS_Abs_2012.nc
# t2_ERA5_REANALYSIS_Abs_2013.nc
# wd_ERA5_REANALYSIS_MIN_Daily_2014.nc
# wd_ERA5_REANALYSIS_MIN_Daily_2015.nc
# wd_ERA5_REANALYSIS_MIN_Daily_2016.nc
# wd_ERA5_REANALYSIS_MIN_Daily_2017.nc
# wd_ERA5_REANALYSIS_MIN_Daily_2018.nc
# wd_ERA5_REANALYSIS_Abs_2011.nc
# wd_ERA5_REANALYSIS_Abs_2012.nc
# wd_ERA5_REANALYSIS_Abs_2013.nc
# wd_ERA5_REANALYSIS_Abs_2014.nc
# wd_ERA5_REANALYSIS_Abs_2015.nc
# wd_ERA5_REANALYSIS_Abs_2016.nc
# wd_ERA5_REANALYSIS_Abs_2017.nc
# wd_ERA5_REANALYSIS_Abs_2018.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2011.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2012.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2013.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2014.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2015.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2016.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2017.nc
# ws_ERA5_REANALYSIS_AVG_Daily_2018.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2011.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2012.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2013.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2014.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2015.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2016.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2017.nc
# ws_ERA5_REANALYSIS_MAX_Daily_2018.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2011.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2012.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2013.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2014.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2015.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2016.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2017.nc
# ws_ERA5_REANALYSIS_MIN_Daily_2018.nc
# ws_ERA5_REANALYSIS_Abs_2011.nc
# ws_ERA5_REANALYSIS_Abs_2012.nc
# ws_ERA5_REANALYSIS_Abs_2013.nc
# ws_ERA5_REANALYSIS_Abs_2014.nc
# ws_ERA5_REANALYSIS_Abs_2015.nc
# ws_ERA5_REANALYSIS_Abs_2016.nc
# ws_ERA5_REANALYSIS_Abs_2017.nc
# ws_ERA5_REANALYSIS_Abs_2018.nc
# CPU times: user 15.3 s, sys: 12min 20s, total: 12min 36s
# Wall time: 24min 44s

# %% [markdown]
# ### NCEP

# %%
m = 'NCEP'

# %%
ncep_vars = [value for key,value in variables_by_model[m].items()]

# %%
ncep_vars
# Out:
# ['soilw',
#  'uwnd',
#  'vwnd',
#  'prate',
#  'air',
#  'rhum',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

final_clean_db(m, ncep_vars)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/xarray/core/dataset.py", line 1446, in _construct_dataarray
#     variable = self._variables[name]
#                ~~~~~~~~~~~~~~~^^^^^^
# KeyError: 'air'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/magics/execution.py", line 1332, in time
#     out = eval(code, glob, local_ns)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<timed eval>", line 1, in <module>
#   File "/tmp/ipykernel_27033/3566287398.py", line 83, in final_clean_db
#     db_file = special_NCEP_cleaner(db_file, v, f)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_27033/171401216.py", line 30, in special_NCEP_cleaner
#     db_file[v] = xr.where(db_file[v] == -np.Inf, np.nan, db_file[v])
#                           ~~~~~~~^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/xarray/core/dataset.py", line 1544, in __getitem__
#     return self._construct_dataarray(key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/xarray/core/dataset.py", line 1448, in _construct_dataarray
#     _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/xarray/core/dataset.py", line 214, in _get_virtual_variable
#     raise KeyError(key)
# KeyError: 'air'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2142, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1155, in get_records
#     FrameInfo(
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/site-packages/IPython/core/ultratb.py", line 780, in __init__
#     ix = inspect.getsourcelines(frame)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/inspect.py", line 1264, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "/home/s2sfire/miniconda3/envs/noaa_s2s/lib/python3.12/inspect.py", line 1093, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %% [markdown]
# ### NARR

# %%
m = 'NARR'

# %%
narr_vars = [value for key,value in variables_by_model[m].items()]

# %%
narr_vars
# Out:
# ['Planetary_boundary_layer_height_surface',
#  'Soil_moisture_content_layer_between_two_depths_below_surface_layer',
#  'u-component_of_wind_height_above_ground',
#  'v-component_of_wind_height_above_ground',
#  'Precipitation_rate_surface',
#  'Total_precipitation_surface_3_Hour_Accumulation',
#  'Temperature_height_above_ground',
#  'Relative_humidity_height_above_ground',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

final_clean_db(m, narr_vars)
# Out:
# pbl_NARR_REANALYSIS_AVG_Daily_2011.nc
# pbl_NARR_REANALYSIS_AVG_Daily_2012.nc
# pbl_NARR_REANALYSIS_AVG_Daily_2013.nc
# pbl_NARR_REANALYSIS_AVG_Daily_2014.nc
# pbl_NARR_REANALYSIS_MAX_Daily_2011.nc
# pbl_NARR_REANALYSIS_MAX_Daily_2012.nc
# pbl_NARR_REANALYSIS_MAX_Daily_2013.nc
# pbl_NARR_REANALYSIS_MAX_Daily_2014.nc
# pbl_NARR_REANALYSIS_MIN_Daily_2011.nc
# pbl_NARR_REANALYSIS_MIN_Daily_2012.nc
# pbl_NARR_REANALYSIS_MIN_Daily_2013.nc
# pbl_NARR_REANALYSIS_MIN_Daily_2014.nc
# pbl_NARR_REANALYSIS_Abs_2011.nc
# pbl_NARR_REANALYSIS_Abs_2012.nc
# pbl_NARR_REANALYSIS_Abs_2013.nc
# pbl_NARR_REANALYSIS_Abs_2014.nc
# prate_NARR_REANALYSIS_AVG_Daily_2011.nc
# prate_NARR_REANALYSIS_AVG_Daily_2012.nc
# prate_NARR_REANALYSIS_AVG_Daily_2013.nc
# prate_NARR_REANALYSIS_AVG_Daily_2014.nc
# prate_NARR_REANALYSIS_MAX_Daily_2011.nc
# prate_NARR_REANALYSIS_MAX_Daily_2012.nc
# prate_NARR_REANALYSIS_MAX_Daily_2013.nc
# prate_NARR_REANALYSIS_MAX_Daily_2014.nc
# prate_NARR_REANALYSIS_MIN_Daily_2011.nc
# prate_NARR_REANALYSIS_MIN_Daily_2012.nc
# prate_NARR_REANALYSIS_MIN_Daily_2013.nc
# prate_NARR_REANALYSIS_MIN_Daily_2014.nc
# prate_NARR_REANALYSIS_Abs_2011.nc
# prate_NARR_REANALYSIS_Abs_2012.nc
# prate_NARR_REANALYSIS_Abs_2013.nc
# prate_NARR_REANALYSIS_Abs_2014.nc
# rh_NARR_REANALYSIS_AVG_Daily_2011.nc
# rh_NARR_REANALYSIS_AVG_Daily_2012.nc
# rh_NARR_REANALYSIS_AVG_Daily_2013.nc
# rh_NARR_REANALYSIS_AVG_Daily_2014.nc
# rh_NARR_REANALYSIS_MAX_Daily_2011.nc
# rh_NARR_REANALYSIS_MAX_Daily_2012.nc
# rh_NARR_REANALYSIS_MAX_Daily_2013.nc
# rh_NARR_REANALYSIS_MAX_Daily_2014.nc
# rh_NARR_REANALYSIS_MIN_Daily_2011.nc
# rh_NARR_REANALYSIS_MIN_Daily_2012.nc
# rh_NARR_REANALYSIS_MIN_Daily_2013.nc
# rh_NARR_REANALYSIS_MIN_Daily_2014.nc
# rh_NARR_REANALYSIS_Abs_2011.nc
# rh_NARR_REANALYSIS_Abs_2012.nc
# rh_NARR_REANALYSIS_Abs_2013.nc
# rh_NARR_REANALYSIS_Abs_2014.nc
# sm_NARR_REANALYSIS_AVG_Daily_2011.nc
# sm_NARR_REANALYSIS_AVG_Daily_2012.nc
# sm_NARR_REANALYSIS_AVG_Daily_2013.nc
# sm_NARR_REANALYSIS_AVG_Daily_2014.nc
# sm_NARR_REANALYSIS_MAX_Daily_2011.nc
# sm_NARR_REANALYSIS_MAX_Daily_2012.nc
# sm_NARR_REANALYSIS_MAX_Daily_2013.nc
# sm_NARR_REANALYSIS_MAX_Daily_2014.nc
# sm_NARR_REANALYSIS_MIN_Daily_2011.nc
# sm_NARR_REANALYSIS_MIN_Daily_2012.nc
# sm_NARR_REANALYSIS_MIN_Daily_2013.nc
# sm_NARR_REANALYSIS_MIN_Daily_2014.nc
# sm_NARR_REANALYSIS_Abs_2011.nc
# sm_NARR_REANALYSIS_Abs_2012.nc
# sm_NARR_REANALYSIS_Abs_2013.nc
# sm_NARR_REANALYSIS_Abs_2014.nc
# t2_NARR_REANALYSIS_AVG_Daily_2011.nc
# t2_NARR_REANALYSIS_AVG_Daily_2012.nc
# t2_NARR_REANALYSIS_AVG_Daily_2013.nc
# t2_NARR_REANALYSIS_AVG_Daily_2014.nc
# t2_NARR_REANALYSIS_MAX_Daily_2011.nc
# t2_NARR_REANALYSIS_MAX_Daily_2012.nc
# t2_NARR_REANALYSIS_MAX_Daily_2013.nc
# t2_NARR_REANALYSIS_MAX_Daily_2014.nc
# t2_NARR_REANALYSIS_MIN_Daily_2011.nc
# t2_NARR_REANALYSIS_MIN_Daily_2012.nc
# t2_NARR_REANALYSIS_MIN_Daily_2013.nc
# t2_NARR_REANALYSIS_MIN_Daily_2014.nc
# t2_NARR_REANALYSIS_Abs_2011.nc
# t2_NARR_REANALYSIS_Abs_2012.nc
# t2_NARR_REANALYSIS_Abs_2013.nc
# t2_NARR_REANALYSIS_Abs_2014.nc
# tp_NARR_REANALYSIS_AVG_Daily_2011.nc
# tp_NARR_REANALYSIS_AVG_Daily_2012.nc
# tp_NARR_REANALYSIS_AVG_Daily_2013.nc
# tp_NARR_REANALYSIS_AVG_Daily_2014.nc
# tp_NARR_REANALYSIS_MAX_Daily_2011.nc
# tp_NARR_REANALYSIS_MAX_Daily_2012.nc
# tp_NARR_REANALYSIS_MAX_Daily_2013.nc
# tp_NARR_REANALYSIS_MAX_Daily_2014.nc
# tp_NARR_REANALYSIS_MIN_Daily_2011.nc
# tp_NARR_REANALYSIS_MIN_Daily_2012.nc
# tp_NARR_REANALYSIS_MIN_Daily_2013.nc
# tp_NARR_REANALYSIS_MIN_Daily_2014.nc
# tp_NARR_REANALYSIS_Abs_2011.nc
# tp_NARR_REANALYSIS_Abs_2012.nc
# tp_NARR_REANALYSIS_Abs_2013.nc
# tp_NARR_REANALYSIS_Abs_2014.nc
# ffwi_NARR_REANALYSIS_AVG_Daily_2011.nc
# ffwi_NARR_REANALYSIS_AVG_Daily_2012.nc
# ffwi_NARR_REANALYSIS_AVG_Daily_2013.nc
# ffwi_NARR_REANALYSIS_AVG_Daily_2014.nc
# ffwi_NARR_REANALYSIS_MAX_Daily_2011.nc
# ffwi_NARR_REANALYSIS_MAX_Daily_2012.nc
# ffwi_NARR_REANALYSIS_MAX_Daily_2013.nc
# ffwi_NARR_REANALYSIS_MAX_Daily_2014.nc
# ffwi_NARR_REANALYSIS_MIN_Daily_2011.nc
# ffwi_NARR_REANALYSIS_MIN_Daily_2012.nc
# ffwi_NARR_REANALYSIS_MIN_Daily_2013.nc
# ffwi_NARR_REANALYSIS_MIN_Daily_2014.nc
# ffwi_NARR_REANALYSIS_Abs_2011.nc
# ffwi_NARR_REANALYSIS_Abs_2012.nc
# ffwi_NARR_REANALYSIS_Abs_2013.nc
# ffwi_NARR_REANALYSIS_Abs_2014.nc
# hdw_NARR_REANALYSIS_AVG_Daily_2011.nc
# hdw_NARR_REANALYSIS_AVG_Daily_2012.nc
# hdw_NARR_REANALYSIS_AVG_Daily_2013.nc
# hdw_NARR_REANALYSIS_AVG_Daily_2014.nc
# hdw_NARR_REANALYSIS_MAX_Daily_2011.nc
# hdw_NARR_REANALYSIS_MAX_Daily_2012.nc
# hdw_NARR_REANALYSIS_MAX_Daily_2013.nc
# hdw_NARR_REANALYSIS_MAX_Daily_2014.nc
# hdw_NARR_REANALYSIS_MIN_Daily_2011.nc
# hdw_NARR_REANALYSIS_MIN_Daily_2012.nc
# hdw_NARR_REANALYSIS_MIN_Daily_2013.nc
# hdw_NARR_REANALYSIS_MIN_Daily_2014.nc
# hdw_NARR_REANALYSIS_Abs_2011.nc
# hdw_NARR_REANALYSIS_Abs_2012.nc
# hdw_NARR_REANALYSIS_Abs_2013.nc
# hdw_NARR_REANALYSIS_Abs_2014.nc
# u10_NARR_REANALYSIS_AVG_Daily_2011.nc
# u10_NARR_REANALYSIS_AVG_Daily_2012.nc
# u10_NARR_REANALYSIS_AVG_Daily_2013.nc
# u10_NARR_REANALYSIS_AVG_Daily_2014.nc
# u10_NARR_REANALYSIS_MAX_Daily_2011.nc
# u10_NARR_REANALYSIS_MAX_Daily_2012.nc
# u10_NARR_REANALYSIS_MAX_Daily_2013.nc
# u10_NARR_REANALYSIS_MAX_Daily_2014.nc
# u10_NARR_REANALYSIS_MIN_Daily_2011.nc
# u10_NARR_REANALYSIS_MIN_Daily_2012.nc
# u10_NARR_REANALYSIS_MIN_Daily_2013.nc
# u10_NARR_REANALYSIS_MIN_Daily_2014.nc
# u10_NARR_REANALYSIS_Abs_2011.nc
# u10_NARR_REANALYSIS_Abs_2012.nc
# u10_NARR_REANALYSIS_Abs_2013.nc
# u10_NARR_REANALYSIS_Abs_2014.nc
# v10_NARR_REANALYSIS_AVG_Daily_2011.nc
# v10_NARR_REANALYSIS_AVG_Daily_2012.nc
# v10_NARR_REANALYSIS_AVG_Daily_2013.nc
# v10_NARR_REANALYSIS_AVG_Daily_2014.nc
# v10_NARR_REANALYSIS_MAX_Daily_2011.nc
# v10_NARR_REANALYSIS_MAX_Daily_2012.nc
# v10_NARR_REANALYSIS_MAX_Daily_2013.nc
# v10_NARR_REANALYSIS_MAX_Daily_2014.nc
# v10_NARR_REANALYSIS_MIN_Daily_2011.nc
# v10_NARR_REANALYSIS_MIN_Daily_2012.nc
# v10_NARR_REANALYSIS_MIN_Daily_2013.nc
# v10_NARR_REANALYSIS_MIN_Daily_2014.nc
# v10_NARR_REANALYSIS_Abs_2011.nc
# v10_NARR_REANALYSIS_Abs_2012.nc
# v10_NARR_REANALYSIS_Abs_2013.nc
# v10_NARR_REANALYSIS_Abs_2014.nc
# vpd_NARR_REANALYSIS_AVG_Daily_2011.nc
# vpd_NARR_REANALYSIS_AVG_Daily_2012.nc
# vpd_NARR_REANALYSIS_AVG_Daily_2013.nc
# vpd_NARR_REANALYSIS_AVG_Daily_2014.nc
# vpd_NARR_REANALYSIS_MAX_Daily_2011.nc
# vpd_NARR_REANALYSIS_MAX_Daily_2012.nc
# vpd_NARR_REANALYSIS_MAX_Daily_2013.nc
# vpd_NARR_REANALYSIS_MAX_Daily_2014.nc
# vpd_NARR_REANALYSIS_MIN_Daily_2011.nc
# vpd_NARR_REANALYSIS_MIN_Daily_2012.nc
# vpd_NARR_REANALYSIS_MIN_Daily_2013.nc
# vpd_NARR_REANALYSIS_MIN_Daily_2014.nc
# vpd_NARR_REANALYSIS_Abs_2011.nc
# vpd_NARR_REANALYSIS_Abs_2012.nc
# vpd_NARR_REANALYSIS_Abs_2013.nc
# vpd_NARR_REANALYSIS_Abs_2014.nc
# wd_NARR_REANALYSIS_AVG_Daily_2011.nc
# wd_NARR_REANALYSIS_AVG_Daily_2012.nc
# wd_NARR_REANALYSIS_AVG_Daily_2013.nc
# wd_NARR_REANALYSIS_AVG_Daily_2014.nc
# wd_NARR_REANALYSIS_MAX_Daily_2011.nc
# wd_NARR_REANALYSIS_MAX_Daily_2012.nc
# wd_NARR_REANALYSIS_MAX_Daily_2013.nc
# wd_NARR_REANALYSIS_MAX_Daily_2014.nc
# wd_NARR_REANALYSIS_MIN_Daily_2011.nc
# wd_NARR_REANALYSIS_MIN_Daily_2012.nc
# wd_NARR_REANALYSIS_MIN_Daily_2013.nc
# wd_NARR_REANALYSIS_MIN_Daily_2014.nc
# wd_NARR_REANALYSIS_Abs_2011.nc
# wd_NARR_REANALYSIS_Abs_2012.nc
# wd_NARR_REANALYSIS_Abs_2013.nc
# wd_NARR_REANALYSIS_Abs_2014.nc
# ws_NARR_REANALYSIS_AVG_Daily_2011.nc
# ws_NARR_REANALYSIS_AVG_Daily_2012.nc
# ws_NARR_REANALYSIS_AVG_Daily_2013.nc
# ws_NARR_REANALYSIS_AVG_Daily_2014.nc
# ws_NARR_REANALYSIS_MAX_Daily_2011.nc
# ws_NARR_REANALYSIS_MAX_Daily_2012.nc
# ws_NARR_REANALYSIS_MAX_Daily_2013.nc
# ws_NARR_REANALYSIS_MAX_Daily_2014.nc
# ws_NARR_REANALYSIS_MIN_Daily_2011.nc
# ws_NARR_REANALYSIS_MIN_Daily_2012.nc
# ws_NARR_REANALYSIS_MIN_Daily_2013.nc
# ws_NARR_REANALYSIS_MIN_Daily_2014.nc
# ws_NARR_REANALYSIS_Abs_2011.nc
# ws_NARR_REANALYSIS_Abs_2012.nc
# ws_NARR_REANALYSIS_Abs_2013.nc
# ws_NARR_REANALYSIS_Abs_2014.nc
# CPU times: user 58.1 s, sys: 3min 41s, total: 4min 39s
# Wall time: 6min 18s

# %% [markdown]
# ### NAM

# %%
m = 'NAM'

# %%
nam_vars = [value for key,value in variables_by_model[m].items()]

# %%
nam_vars
# Out:
# ['hpbl',
#  'cape',
#  'sm',
#  'u10',
#  'v10',
#  'gust',
#  'tp',
#  't2m',
#  'r',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

final_clean_db(m, nam_vars)
# Out:
# cape_NAM_HISTORICAL_AVG_Daily_2017.nc
# cape_NAM_HISTORICAL_AVG_Daily_2018.nc
# cape_NAM_HISTORICAL_MAX_Daily_2017.nc
# cape_NAM_HISTORICAL_MAX_Daily_2018.nc
# cape_NAM_HISTORICAL_MIN_Daily_2017.nc
# cape_NAM_HISTORICAL_MIN_Daily_2018.nc
# cape_NAM_HISTORICAL_Abs_2017.nc
# cape_NAM_HISTORICAL_Abs_2018.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2011.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2013.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2014.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2015.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2016.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2017.nc
# ffwi_NAM_HISTORICAL_AVG_Daily_2018.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2011.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2013.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2014.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2015.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2016.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2017.nc
# ffwi_NAM_HISTORICAL_MAX_Daily_2018.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2011.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2013.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2014.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2015.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2016.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2017.nc
# ffwi_NAM_HISTORICAL_MIN_Daily_2018.nc
# ffwi_NAM_HISTORICAL_Abs_2011.nc
# ffwi_NAM_HISTORICAL_Abs_2013.nc
# ffwi_NAM_HISTORICAL_Abs_2014.nc
# ffwi_NAM_HISTORICAL_Abs_2015.nc
# ffwi_NAM_HISTORICAL_Abs_2016.nc
# ffwi_NAM_HISTORICAL_Abs_2017.nc
# ffwi_NAM_HISTORICAL_Abs_2018.nc
# gust_NAM_HISTORICAL_AVG_Daily_2017.nc
# gust_NAM_HISTORICAL_AVG_Daily_2018.nc
# gust_NAM_HISTORICAL_MAX_Daily_2017.nc
# gust_NAM_HISTORICAL_MAX_Daily_2018.nc
# gust_NAM_HISTORICAL_MIN_Daily_2017.nc
# gust_NAM_HISTORICAL_MIN_Daily_2018.nc
# gust_NAM_HISTORICAL_Abs_2017.nc
# gust_NAM_HISTORICAL_Abs_2018.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2011.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2012.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2013.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2014.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2015.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2016.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2017.nc
# hdw_NAM_HISTORICAL_AVG_Daily_2018.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2011.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2012.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2013.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2014.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2015.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2016.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2017.nc
# hdw_NAM_HISTORICAL_MAX_Daily_2018.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2011.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2012.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2013.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2014.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2015.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2016.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2017.nc
# hdw_NAM_HISTORICAL_MIN_Daily_2018.nc
# hdw_NAM_HISTORICAL_Abs_2011.nc
# hdw_NAM_HISTORICAL_Abs_2012.nc
# hdw_NAM_HISTORICAL_Abs_2013.nc
# hdw_NAM_HISTORICAL_Abs_2014.nc
# hdw_NAM_HISTORICAL_Abs_2015.nc
# hdw_NAM_HISTORICAL_Abs_2016.nc
# hdw_NAM_HISTORICAL_Abs_2017.nc
# hdw_NAM_HISTORICAL_Abs_2018.nc
# rh_NAM_HISTORICAL_AVG_Daily_2018.nc
# rh_NAM_HISTORICAL_AVG_Daily_2011.nc
# rh_NAM_HISTORICAL_AVG_Daily_2012.nc
# rh_NAM_HISTORICAL_AVG_Daily_2013.nc
# rh_NAM_HISTORICAL_AVG_Daily_2014.nc
# rh_NAM_HISTORICAL_AVG_Daily_2015.nc
# rh_NAM_HISTORICAL_AVG_Daily_2016.nc
# rh_NAM_HISTORICAL_AVG_Daily_2017.nc
# rh_NAM_HISTORICAL_MAX_Daily_2018.nc
# rh_NAM_HISTORICAL_MAX_Daily_2011.nc
# rh_NAM_HISTORICAL_MAX_Daily_2012.nc
# rh_NAM_HISTORICAL_MAX_Daily_2013.nc
# rh_NAM_HISTORICAL_MAX_Daily_2014.nc
# rh_NAM_HISTORICAL_MAX_Daily_2015.nc
# rh_NAM_HISTORICAL_MAX_Daily_2016.nc
# rh_NAM_HISTORICAL_MAX_Daily_2017.nc
# rh_NAM_HISTORICAL_MIN_Daily_2018.nc
# rh_NAM_HISTORICAL_MIN_Daily_2011.nc
# rh_NAM_HISTORICAL_MIN_Daily_2012.nc
# rh_NAM_HISTORICAL_MIN_Daily_2013.nc
# rh_NAM_HISTORICAL_MIN_Daily_2014.nc
# rh_NAM_HISTORICAL_MIN_Daily_2015.nc
# rh_NAM_HISTORICAL_MIN_Daily_2016.nc
# rh_NAM_HISTORICAL_MIN_Daily_2017.nc
# rh_NAM_HISTORICAL_Abs_2011.nc
# rh_NAM_HISTORICAL_Abs_2012.nc
# rh_NAM_HISTORICAL_Abs_2013.nc
# rh_NAM_HISTORICAL_Abs_2014.nc
# rh_NAM_HISTORICAL_Abs_2015.nc
# rh_NAM_HISTORICAL_Abs_2016.nc
# rh_NAM_HISTORICAL_Abs_2017.nc
# rh_NAM_HISTORICAL_Abs_2018.nc
# sm_NAM_HISTORICAL_AVG_Daily_2018.nc
# sm_NAM_HISTORICAL_AVG_Daily_2011.nc
# sm_NAM_HISTORICAL_AVG_Daily_2012.nc
# sm_NAM_HISTORICAL_AVG_Daily_2013.nc
# sm_NAM_HISTORICAL_AVG_Daily_2014.nc
# sm_NAM_HISTORICAL_AVG_Daily_2015.nc
# sm_NAM_HISTORICAL_AVG_Daily_2016.nc
# sm_NAM_HISTORICAL_AVG_Daily_2017.nc
# sm_NAM_HISTORICAL_MAX_Daily_2018.nc
# sm_NAM_HISTORICAL_MAX_Daily_2011.nc
# sm_NAM_HISTORICAL_MAX_Daily_2012.nc
# sm_NAM_HISTORICAL_MAX_Daily_2013.nc
# sm_NAM_HISTORICAL_MAX_Daily_2014.nc
# sm_NAM_HISTORICAL_MAX_Daily_2015.nc
# sm_NAM_HISTORICAL_MAX_Daily_2016.nc
# sm_NAM_HISTORICAL_MAX_Daily_2017.nc
# sm_NAM_HISTORICAL_MIN_Daily_2018.nc
# sm_NAM_HISTORICAL_MIN_Daily_2011.nc
# sm_NAM_HISTORICAL_MIN_Daily_2012.nc
# sm_NAM_HISTORICAL_MIN_Daily_2013.nc
# sm_NAM_HISTORICAL_MIN_Daily_2014.nc
# sm_NAM_HISTORICAL_MIN_Daily_2015.nc
# sm_NAM_HISTORICAL_MIN_Daily_2016.nc
# sm_NAM_HISTORICAL_MIN_Daily_2017.nc
# sm_NAM_HISTORICAL_Abs_2011.nc
# sm_NAM_HISTORICAL_Abs_2012.nc
# sm_NAM_HISTORICAL_Abs_2013.nc
# sm_NAM_HISTORICAL_Abs_2014.nc
# sm_NAM_HISTORICAL_Abs_2015.nc
# sm_NAM_HISTORICAL_Abs_2016.nc
# sm_NAM_HISTORICAL_Abs_2017.nc
# sm_NAM_HISTORICAL_Abs_2018.nc
# t2_NAM_HISTORICAL_AVG_Daily_2011.nc
# t2_NAM_HISTORICAL_AVG_Daily_2012.nc
# t2_NAM_HISTORICAL_AVG_Daily_2013.nc
# t2_NAM_HISTORICAL_AVG_Daily_2014.nc
# t2_NAM_HISTORICAL_AVG_Daily_2015.nc
# t2_NAM_HISTORICAL_AVG_Daily_2016.nc
# t2_NAM_HISTORICAL_AVG_Daily_2017.nc
# t2_NAM_HISTORICAL_AVG_Daily_2018.nc
# t2_NAM_HISTORICAL_MAX_Daily_2011.nc
# t2_NAM_HISTORICAL_MAX_Daily_2012.nc
# t2_NAM_HISTORICAL_MAX_Daily_2013.nc
# t2_NAM_HISTORICAL_MAX_Daily_2014.nc
# t2_NAM_HISTORICAL_MAX_Daily_2015.nc
# t2_NAM_HISTORICAL_MAX_Daily_2016.nc
# t2_NAM_HISTORICAL_MAX_Daily_2017.nc
# t2_NAM_HISTORICAL_MAX_Daily_2018.nc
# t2_NAM_HISTORICAL_MIN_Daily_2011.nc
# t2_NAM_HISTORICAL_MIN_Daily_2012.nc
# t2_NAM_HISTORICAL_MIN_Daily_2013.nc
# t2_NAM_HISTORICAL_MIN_Daily_2014.nc
# t2_NAM_HISTORICAL_MIN_Daily_2015.nc
# t2_NAM_HISTORICAL_MIN_Daily_2016.nc
# t2_NAM_HISTORICAL_MIN_Daily_2017.nc
# t2_NAM_HISTORICAL_MIN_Daily_2018.nc
# t2_NAM_HISTORICAL_Abs_2011.nc
# t2_NAM_HISTORICAL_Abs_2012.nc
# t2_NAM_HISTORICAL_Abs_2013.nc
# t2_NAM_HISTORICAL_Abs_2014.nc
# t2_NAM_HISTORICAL_Abs_2015.nc
# t2_NAM_HISTORICAL_Abs_2016.nc
# t2_NAM_HISTORICAL_Abs_2017.nc
# t2_NAM_HISTORICAL_Abs_2018.nc
# tp_NAM_HISTORICAL_AVG_Daily_2013.nc
# tp_NAM_HISTORICAL_AVG_Daily_2014.nc
# tp_NAM_HISTORICAL_AVG_Daily_2015.nc
# tp_NAM_HISTORICAL_AVG_Daily_2016.nc
# tp_NAM_HISTORICAL_AVG_Daily_2017.nc
# tp_NAM_HISTORICAL_AVG_Daily_2018.nc
# tp_NAM_HISTORICAL_MAX_Daily_2013.nc
# tp_NAM_HISTORICAL_MAX_Daily_2014.nc
# tp_NAM_HISTORICAL_MAX_Daily_2015.nc
# tp_NAM_HISTORICAL_MAX_Daily_2016.nc
# tp_NAM_HISTORICAL_MAX_Daily_2017.nc
# tp_NAM_HISTORICAL_MAX_Daily_2018.nc
# tp_NAM_HISTORICAL_MIN_Daily_2013.nc
# tp_NAM_HISTORICAL_MIN_Daily_2014.nc
# tp_NAM_HISTORICAL_MIN_Daily_2015.nc
# tp_NAM_HISTORICAL_MIN_Daily_2016.nc
# tp_NAM_HISTORICAL_MIN_Daily_2017.nc
# tp_NAM_HISTORICAL_MIN_Daily_2018.nc
# tp_NAM_HISTORICAL_Abs_2013.nc
# tp_NAM_HISTORICAL_Abs_2014.nc
# tp_NAM_HISTORICAL_Abs_2015.nc
# tp_NAM_HISTORICAL_Abs_2016.nc
# tp_NAM_HISTORICAL_Abs_2017.nc
# tp_NAM_HISTORICAL_Abs_2018.nc
# u10_NAM_HISTORICAL_AVG_Daily_2011.nc
# u10_NAM_HISTORICAL_AVG_Daily_2012.nc
# u10_NAM_HISTORICAL_AVG_Daily_2013.nc
# u10_NAM_HISTORICAL_AVG_Daily_2014.nc
# u10_NAM_HISTORICAL_AVG_Daily_2015.nc
# u10_NAM_HISTORICAL_AVG_Daily_2016.nc
# u10_NAM_HISTORICAL_AVG_Daily_2017.nc
# u10_NAM_HISTORICAL_AVG_Daily_2018.nc
# u10_NAM_HISTORICAL_MAX_Daily_2011.nc
# u10_NAM_HISTORICAL_MAX_Daily_2012.nc
# u10_NAM_HISTORICAL_MAX_Daily_2013.nc
# u10_NAM_HISTORICAL_MAX_Daily_2014.nc
# u10_NAM_HISTORICAL_MAX_Daily_2015.nc
# u10_NAM_HISTORICAL_MAX_Daily_2016.nc
# u10_NAM_HISTORICAL_MAX_Daily_2017.nc
# u10_NAM_HISTORICAL_MAX_Daily_2018.nc
# u10_NAM_HISTORICAL_MIN_Daily_2011.nc
# u10_NAM_HISTORICAL_MIN_Daily_2012.nc
# u10_NAM_HISTORICAL_MIN_Daily_2013.nc
# u10_NAM_HISTORICAL_MIN_Daily_2014.nc
# u10_NAM_HISTORICAL_MIN_Daily_2015.nc
# u10_NAM_HISTORICAL_MIN_Daily_2016.nc
# u10_NAM_HISTORICAL_MIN_Daily_2017.nc
# u10_NAM_HISTORICAL_MIN_Daily_2018.nc
# u10_NAM_HISTORICAL_Abs_2011.nc
# u10_NAM_HISTORICAL_Abs_2012.nc
# u10_NAM_HISTORICAL_Abs_2013.nc
# u10_NAM_HISTORICAL_Abs_2014.nc
# u10_NAM_HISTORICAL_Abs_2015.nc
# u10_NAM_HISTORICAL_Abs_2016.nc
# u10_NAM_HISTORICAL_Abs_2017.nc
# u10_NAM_HISTORICAL_Abs_2018.nc
# v10_NAM_HISTORICAL_AVG_Daily_2011.nc
# v10_NAM_HISTORICAL_AVG_Daily_2012.nc
# v10_NAM_HISTORICAL_AVG_Daily_2013.nc
# v10_NAM_HISTORICAL_AVG_Daily_2014.nc
# v10_NAM_HISTORICAL_AVG_Daily_2015.nc
# v10_NAM_HISTORICAL_AVG_Daily_2016.nc
# v10_NAM_HISTORICAL_AVG_Daily_2017.nc
# v10_NAM_HISTORICAL_AVG_Daily_2018.nc
# v10_NAM_HISTORICAL_MAX_Daily_2011.nc
# v10_NAM_HISTORICAL_MAX_Daily_2012.nc
# v10_NAM_HISTORICAL_MAX_Daily_2013.nc
# v10_NAM_HISTORICAL_MAX_Daily_2014.nc
# v10_NAM_HISTORICAL_MAX_Daily_2015.nc
# v10_NAM_HISTORICAL_MAX_Daily_2016.nc
# v10_NAM_HISTORICAL_MAX_Daily_2017.nc
# v10_NAM_HISTORICAL_MAX_Daily_2018.nc
# v10_NAM_HISTORICAL_MIN_Daily_2011.nc
# v10_NAM_HISTORICAL_MIN_Daily_2012.nc
# v10_NAM_HISTORICAL_MIN_Daily_2013.nc
# v10_NAM_HISTORICAL_MIN_Daily_2014.nc
# v10_NAM_HISTORICAL_MIN_Daily_2015.nc
# v10_NAM_HISTORICAL_MIN_Daily_2016.nc
# v10_NAM_HISTORICAL_MIN_Daily_2017.nc
# v10_NAM_HISTORICAL_MIN_Daily_2018.nc
# v10_NAM_HISTORICAL_Abs_2011.nc
# v10_NAM_HISTORICAL_Abs_2012.nc
# v10_NAM_HISTORICAL_Abs_2013.nc
# v10_NAM_HISTORICAL_Abs_2014.nc
# v10_NAM_HISTORICAL_Abs_2015.nc
# v10_NAM_HISTORICAL_Abs_2016.nc
# v10_NAM_HISTORICAL_Abs_2017.nc
# v10_NAM_HISTORICAL_Abs_2018.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2011.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2012.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2013.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2014.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2015.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2016.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2017.nc
# vpd_NAM_HISTORICAL_AVG_Daily_2018.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2011.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2012.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2013.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2014.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2015.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2016.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2017.nc
# vpd_NAM_HISTORICAL_MAX_Daily_2018.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2011.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2012.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2013.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2014.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2015.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2016.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2017.nc
# vpd_NAM_HISTORICAL_MIN_Daily_2018.nc
# vpd_NAM_HISTORICAL_Abs_2011.nc
# vpd_NAM_HISTORICAL_Abs_2012.nc
# vpd_NAM_HISTORICAL_Abs_2013.nc
# vpd_NAM_HISTORICAL_Abs_2014.nc
# vpd_NAM_HISTORICAL_Abs_2015.nc
# vpd_NAM_HISTORICAL_Abs_2016.nc
# vpd_NAM_HISTORICAL_Abs_2017.nc
# vpd_NAM_HISTORICAL_Abs_2018.nc
# wd_NAM_HISTORICAL_AVG_Daily_2011.nc
# wd_NAM_HISTORICAL_AVG_Daily_2012.nc
# wd_NAM_HISTORICAL_AVG_Daily_2013.nc
# wd_NAM_HISTORICAL_AVG_Daily_2014.nc
# wd_NAM_HISTORICAL_AVG_Daily_2015.nc
# wd_NAM_HISTORICAL_AVG_Daily_2016.nc
# wd_NAM_HISTORICAL_AVG_Daily_2017.nc
# wd_NAM_HISTORICAL_AVG_Daily_2018.nc
# wd_NAM_HISTORICAL_MAX_Daily_2011.nc
# wd_NAM_HISTORICAL_MAX_Daily_2012.nc
# wd_NAM_HISTORICAL_MAX_Daily_2013.nc
# wd_NAM_HISTORICAL_MAX_Daily_2014.nc
# wd_NAM_HISTORICAL_MAX_Daily_2015.nc
# wd_NAM_HISTORICAL_MAX_Daily_2016.nc
# wd_NAM_HISTORICAL_MAX_Daily_2017.nc
# wd_NAM_HISTORICAL_MAX_Daily_2018.nc
# wd_NAM_HISTORICAL_MIN_Daily_2011.nc
# wd_NAM_HISTORICAL_MIN_Daily_2012.nc
# wd_NAM_HISTORICAL_MIN_Daily_2013.nc
# wd_NAM_HISTORICAL_MIN_Daily_2014.nc
# wd_NAM_HISTORICAL_MIN_Daily_2015.nc
# wd_NAM_HISTORICAL_MIN_Daily_2016.nc
# wd_NAM_HISTORICAL_MIN_Daily_2017.nc
# wd_NAM_HISTORICAL_MIN_Daily_2018.nc
# wd_NAM_HISTORICAL_Abs_2011.nc
# wd_NAM_HISTORICAL_Abs_2012.nc
# wd_NAM_HISTORICAL_Abs_2013.nc
# wd_NAM_HISTORICAL_Abs_2014.nc
# wd_NAM_HISTORICAL_Abs_2015.nc
# wd_NAM_HISTORICAL_Abs_2016.nc
# wd_NAM_HISTORICAL_Abs_2017.nc
# wd_NAM_HISTORICAL_Abs_2018.nc
# ws_NAM_HISTORICAL_AVG_Daily_2011.nc
# ws_NAM_HISTORICAL_AVG_Daily_2012.nc
# ws_NAM_HISTORICAL_AVG_Daily_2013.nc
# ws_NAM_HISTORICAL_AVG_Daily_2014.nc
# ws_NAM_HISTORICAL_AVG_Daily_2015.nc
# ws_NAM_HISTORICAL_AVG_Daily_2016.nc
# ws_NAM_HISTORICAL_AVG_Daily_2017.nc
# ws_NAM_HISTORICAL_AVG_Daily_2018.nc
# ws_NAM_HISTORICAL_MAX_Daily_2011.nc
# ws_NAM_HISTORICAL_MAX_Daily_2012.nc
# ws_NAM_HISTORICAL_MAX_Daily_2013.nc
# ws_NAM_HISTORICAL_MAX_Daily_2014.nc
# ws_NAM_HISTORICAL_MAX_Daily_2015.nc
# ws_NAM_HISTORICAL_MAX_Daily_2016.nc
# ws_NAM_HISTORICAL_MAX_Daily_2017.nc
# ws_NAM_HISTORICAL_MAX_Daily_2018.nc
# ws_NAM_HISTORICAL_MIN_Daily_2011.nc
# ws_NAM_HISTORICAL_MIN_Daily_2012.nc
# ws_NAM_HISTORICAL_MIN_Daily_2013.nc
# ws_NAM_HISTORICAL_MIN_Daily_2014.nc
# ws_NAM_HISTORICAL_MIN_Daily_2015.nc
# ws_NAM_HISTORICAL_MIN_Daily_2016.nc
# ws_NAM_HISTORICAL_MIN_Daily_2017.nc
# ws_NAM_HISTORICAL_MIN_Daily_2018.nc
# ws_NAM_HISTORICAL_Abs_2011.nc
# ws_NAM_HISTORICAL_Abs_2012.nc
# ws_NAM_HISTORICAL_Abs_2013.nc
# ws_NAM_HISTORICAL_Abs_2014.nc
# ws_NAM_HISTORICAL_Abs_2015.nc
# ws_NAM_HISTORICAL_Abs_2016.nc
# ws_NAM_HISTORICAL_Abs_2017.nc
# ws_NAM_HISTORICAL_Abs_2018.nc
# CPU times: user 5min 15s, sys: 12min 35s, total: 17min 51s
# Wall time: 21min 44s

# %% [markdown]
# ### HRRR

# %%
m = 'HRRR'

# %%
hrrr_vars = [value for key,value in variables_by_model[m].items()]

# %%
hrrr_vars
# Out:
# ['blh',
#  'cape',
#  'mstav',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  'tp',
#  't2m',
#  'd2m',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi',
#  'rh']

# %%
# %%time

final_clean_db(m, hrrr_vars)
# Out:
# pbl_HRRR_HISTORICAL_AVG_Daily_2014.nc
# pbl_HRRR_HISTORICAL_AVG_Daily_2015.nc
# pbl_HRRR_HISTORICAL_AVG_Daily_2016.nc
# pbl_HRRR_HISTORICAL_AVG_Daily_2017.nc
# pbl_HRRR_HISTORICAL_AVG_Daily_2018.nc
# pbl_HRRR_HISTORICAL_MAX_Daily_2014.nc
# pbl_HRRR_HISTORICAL_MAX_Daily_2015.nc
# pbl_HRRR_HISTORICAL_MAX_Daily_2016.nc
# pbl_HRRR_HISTORICAL_MAX_Daily_2017.nc
# pbl_HRRR_HISTORICAL_MAX_Daily_2018.nc
# pbl_HRRR_HISTORICAL_MIN_Daily_2014.nc
# pbl_HRRR_HISTORICAL_MIN_Daily_2015.nc
# pbl_HRRR_HISTORICAL_MIN_Daily_2016.nc
# pbl_HRRR_HISTORICAL_MIN_Daily_2017.nc
# pbl_HRRR_HISTORICAL_MIN_Daily_2018.nc
# pbl_HRRR_HISTORICAL_Abs_2014.nc
# pbl_HRRR_HISTORICAL_Abs_2015.nc
# pbl_HRRR_HISTORICAL_Abs_2016.nc
# pbl_HRRR_HISTORICAL_Abs_2017.nc
# pbl_HRRR_HISTORICAL_Abs_2018.nc
# cape_HRRR_HISTORICAL_AVG_Daily_2014.nc
# cape_HRRR_HISTORICAL_AVG_Daily_2015.nc
# cape_HRRR_HISTORICAL_AVG_Daily_2016.nc
# cape_HRRR_HISTORICAL_AVG_Daily_2017.nc
# cape_HRRR_HISTORICAL_AVG_Daily_2018.nc
# cape_HRRR_HISTORICAL_MAX_Daily_2014.nc
# cape_HRRR_HISTORICAL_MAX_Daily_2015.nc
# cape_HRRR_HISTORICAL_MAX_Daily_2016.nc
# cape_HRRR_HISTORICAL_MAX_Daily_2017.nc
# cape_HRRR_HISTORICAL_MAX_Daily_2018.nc
# cape_HRRR_HISTORICAL_MIN_Daily_2014.nc
# cape_HRRR_HISTORICAL_MIN_Daily_2015.nc
# cape_HRRR_HISTORICAL_MIN_Daily_2016.nc
# cape_HRRR_HISTORICAL_MIN_Daily_2017.nc
# cape_HRRR_HISTORICAL_MIN_Daily_2018.nc
# cape_HRRR_HISTORICAL_Abs_2014.nc
# cape_HRRR_HISTORICAL_Abs_2015.nc
# cape_HRRR_HISTORICAL_Abs_2016.nc
# cape_HRRR_HISTORICAL_Abs_2017.nc
# cape_HRRR_HISTORICAL_Abs_2018.nc
# d2_HRRR_HISTORICAL_AVG_Daily_2014.nc
# d2_HRRR_HISTORICAL_AVG_Daily_2015.nc
# d2_HRRR_HISTORICAL_AVG_Daily_2016.nc
# d2_HRRR_HISTORICAL_AVG_Daily_2017.nc
# d2_HRRR_HISTORICAL_AVG_Daily_2018.nc
# d2_HRRR_HISTORICAL_MAX_Daily_2014.nc
# d2_HRRR_HISTORICAL_MAX_Daily_2015.nc
# d2_HRRR_HISTORICAL_MAX_Daily_2016.nc
# d2_HRRR_HISTORICAL_MAX_Daily_2017.nc
# d2_HRRR_HISTORICAL_MAX_Daily_2018.nc
# d2_HRRR_HISTORICAL_MIN_Daily_2014.nc
# d2_HRRR_HISTORICAL_MIN_Daily_2015.nc
# d2_HRRR_HISTORICAL_MIN_Daily_2016.nc
# d2_HRRR_HISTORICAL_MIN_Daily_2017.nc
# d2_HRRR_HISTORICAL_MIN_Daily_2018.nc
# d2_HRRR_HISTORICAL_Abs_2014.nc
# d2_HRRR_HISTORICAL_Abs_2015.nc
# d2_HRRR_HISTORICAL_Abs_2016.nc
# d2_HRRR_HISTORICAL_Abs_2017.nc
# d2_HRRR_HISTORICAL_Abs_2018.nc
# ffwi_HRRR_HISTORICAL_AVG_Daily_2014.nc
# ffwi_HRRR_HISTORICAL_AVG_Daily_2015.nc
# rh_HRRR_HISTORICAL_AVG_Daily_2017.nc
# rh_HRRR_HISTORICAL_AVG_Daily_2018.nc
# rh_HRRR_HISTORICAL_MAX_Daily_2014.nc
# rh_HRRR_HISTORICAL_MAX_Daily_2015.nc
# rh_HRRR_HISTORICAL_MAX_Daily_2016.nc
# rh_HRRR_HISTORICAL_MAX_Daily_2017.nc
# rh_HRRR_HISTORICAL_MAX_Daily_2018.nc
# rh_HRRR_HISTORICAL_MIN_Daily_2014.nc
# rh_HRRR_HISTORICAL_MIN_Daily_2015.nc
# rh_HRRR_HISTORICAL_MIN_Daily_2016.nc
# rh_HRRR_HISTORICAL_MIN_Daily_2017.nc
# rh_HRRR_HISTORICAL_MIN_Daily_2018.nc
# rh_HRRR_HISTORICAL_Abs_2014.nc
# rh_HRRR_HISTORICAL_Abs_2015.nc
# rh_HRRR_HISTORICAL_Abs_2016.nc
# rh_HRRR_HISTORICAL_Abs_2017.nc
# rh_HRRR_HISTORICAL_Abs_2018.nc
# t2_HRRR_HISTORICAL_AVG_Daily_2014.nc
# t2_HRRR_HISTORICAL_AVG_Daily_2015.nc
# t2_HRRR_HISTORICAL_AVG_Daily_2016.nc
# t2_HRRR_HISTORICAL_AVG_Daily_2017.nc
# t2_HRRR_HISTORICAL_AVG_Daily_2018.nc
# t2_HRRR_HISTORICAL_MAX_Daily_2014.nc
# t2_HRRR_HISTORICAL_MAX_Daily_2015.nc
# t2_HRRR_HISTORICAL_MAX_Daily_2016.nc
# t2_HRRR_HISTORICAL_MAX_Daily_2017.nc
# t2_HRRR_HISTORICAL_MAX_Daily_2018.nc
# t2_HRRR_HISTORICAL_MIN_Daily_2014.nc
# t2_HRRR_HISTORICAL_MIN_Daily_2015.nc
# t2_HRRR_HISTORICAL_MIN_Daily_2016.nc
# t2_HRRR_HISTORICAL_MIN_Daily_2017.nc
# t2_HRRR_HISTORICAL_MIN_Daily_2018.nc
# t2_HRRR_HISTORICAL_Abs_2014.nc
# t2_HRRR_HISTORICAL_Abs_2015.nc
# t2_HRRR_HISTORICAL_Abs_2016.nc
# t2_HRRR_HISTORICAL_Abs_2017.nc
# t2_HRRR_HISTORICAL_Abs_2018.nc
# tp_HRRR_HISTORICAL_AVG_Daily_2014.nc
# tp_HRRR_HISTORICAL_AVG_Daily_2015.nc
# tp_HRRR_HISTORICAL_AVG_Daily_2016.nc
# tp_HRRR_HISTORICAL_AVG_Daily_2017.nc
# tp_HRRR_HISTORICAL_AVG_Daily_2018.nc
# tp_HRRR_HISTORICAL_MAX_Daily_2014.nc
# tp_HRRR_HISTORICAL_MAX_Daily_2015.nc
# tp_HRRR_HISTORICAL_MAX_Daily_2016.nc
# tp_HRRR_HISTORICAL_MAX_Daily_2017.nc
# tp_HRRR_HISTORICAL_MAX_Daily_2018.nc
# tp_HRRR_HISTORICAL_MIN_Daily_2014.nc
# tp_HRRR_HISTORICAL_MIN_Daily_2015.nc
# tp_HRRR_HISTORICAL_MIN_Daily_2016.nc
# tp_HRRR_HISTORICAL_MIN_Daily_2017.nc
# tp_HRRR_HISTORICAL_MIN_Daily_2018.nc
# tp_HRRR_HISTORICAL_Abs_2014.nc
# tp_HRRR_HISTORICAL_Abs_2015.nc
# tp_HRRR_HISTORICAL_Abs_2016.nc
# tp_HRRR_HISTORICAL_Abs_2017.nc
# tp_HRRR_HISTORICAL_Abs_2018.nc
# u10_HRRR_HISTORICAL_AVG_Daily_2014.nc
# u10_HRRR_HISTORICAL_AVG_Daily_2015.nc
# u10_HRRR_HISTORICAL_AVG_Daily_2016.nc
# u10_HRRR_HISTORICAL_AVG_Daily_2017.nc
# u10_HRRR_HISTORICAL_AVG_Daily_2018.nc
# u10_HRRR_HISTORICAL_MAX_Daily_2014.nc
# u10_HRRR_HISTORICAL_MAX_Daily_2015.nc
# u10_HRRR_HISTORICAL_MAX_Daily_2016.nc
# u10_HRRR_HISTORICAL_MAX_Daily_2017.nc
# u10_HRRR_HISTORICAL_MAX_Daily_2018.nc
# u10_HRRR_HISTORICAL_MIN_Daily_2014.nc
# u10_HRRR_HISTORICAL_MIN_Daily_2015.nc
# u10_HRRR_HISTORICAL_MIN_Daily_2016.nc
# u10_HRRR_HISTORICAL_MIN_Daily_2017.nc
# u10_HRRR_HISTORICAL_MIN_Daily_2018.nc
# u10_HRRR_HISTORICAL_Abs_2014.nc
# u10_HRRR_HISTORICAL_Abs_2015.nc
# u10_HRRR_HISTORICAL_Abs_2016.nc
# u10_HRRR_HISTORICAL_Abs_2017.nc
# u10_HRRR_HISTORICAL_Abs_2018.nc
# v10_HRRR_HISTORICAL_AVG_Daily_2014.nc
# v10_HRRR_HISTORICAL_AVG_Daily_2015.nc
# v10_HRRR_HISTORICAL_AVG_Daily_2016.nc
# v10_HRRR_HISTORICAL_AVG_Daily_2017.nc
# v10_HRRR_HISTORICAL_AVG_Daily_2018.nc
# v10_HRRR_HISTORICAL_MAX_Daily_2016.nc
# v10_HRRR_HISTORICAL_MIN_Daily_2016.nc
# v10_HRRR_HISTORICAL_Abs_2014.nc
# v10_HRRR_HISTORICAL_Abs_2015.nc
# v10_HRRR_HISTORICAL_Abs_2016.nc
# v10_HRRR_HISTORICAL_Abs_2017.nc
# v10_HRRR_HISTORICAL_Abs_2018.nc
# vpd_HRRR_HISTORICAL_AVG_Daily_2016.nc
# vpd_HRRR_HISTORICAL_MAX_Daily_2016.nc
# vpd_HRRR_HISTORICAL_MIN_Daily_2016.nc
# vpd_HRRR_HISTORICAL_Abs_2016.nc
# wd_HRRR_HISTORICAL_AVG_Daily_2016.nc
# wd_HRRR_HISTORICAL_MAX_Daily_2016.nc
# wd_HRRR_HISTORICAL_MIN_Daily_2016.nc
# wd_HRRR_HISTORICAL_Abs_2016.nc
# ws_HRRR_HISTORICAL_AVG_Daily_2016.nc
# ws_HRRR_HISTORICAL_MAX_Daily_2016.nc
# ws_HRRR_HISTORICAL_MIN_Daily_2016.nc
# ws_HRRR_HISTORICAL_Abs_2016.nc
# CPU times: user 21min 42s, sys: 1h 14min 2s, total: 1h 35min 44s
# Wall time: 3h 54min 15s
# ['wspeed_HRRR_HISTORICAL_Abs_2018.nc']

# %% [markdown]
# ### CONUS404

# %%
m = 'CONUS404'

# %%
c44_vars = [value for key,value in variables_by_model[m].items()]

# %%
c44_vars
# Out:
# ['PBLH',
#  'SBCAPE',
#  'MLCAPE',
#  'SMOIS',
#  'U10',
#  'V10',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'PREC_ACC_NC',
#  'T2',
#  'rh',
#  'ffwi',
#  'TD2']

# %%
# %%time

final_clean_db(m, c44_vars)
# Out:
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2011.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2012.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2013.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2014.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2015.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2016.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2018.nc
# mlcape_CONUS404_ANALYSIS_AVG_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2011.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2012.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2013.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2014.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2015.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2016.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2018.nc
# mlcape_CONUS404_ANALYSIS_MAX_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2011.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2012.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2013.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2014.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2015.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2016.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2018.nc
# mlcape_CONUS404_ANALYSIS_MIN_Daily_2017.nc
# mlcape_CONUS404_ANALYSIS_Abs_2011.nc
# mlcape_CONUS404_ANALYSIS_Abs_2012.nc
# mlcape_CONUS404_ANALYSIS_Abs_2013.nc
# mlcape_CONUS404_ANALYSIS_Abs_2014.nc
# mlcape_CONUS404_ANALYSIS_Abs_2015.nc
# mlcape_CONUS404_ANALYSIS_Abs_2016.nc
# mlcape_CONUS404_ANALYSIS_Abs_2017.nc
# mlcape_CONUS404_ANALYSIS_Abs_2018.nc
# mlcape_CONUS404_ANALYSIS_Abs_2017.nc
# pbl_CONUS404_ANALYSIS_AVG_Daily_2011.nc
# pbl_CONUS404_ANALYSIS_AVG_Daily_2012.nc
# sbcape_CONUS404_ANALYSIS_Abs_2014.nc
# sbcape_CONUS404_ANALYSIS_Abs_2015.nc
# sbcape_CONUS404_ANALYSIS_Abs_2016.nc
# sbcape_CONUS404_ANALYSIS_Abs_2017.nc
# sbcape_CONUS404_ANALYSIS_Abs_2018.nc
# sbcape_CONUS404_ANALYSIS_Abs_2017.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2011.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2012.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2013.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2014.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2015.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2016.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2018.nc
# vsm_CONUS404_ANALYSIS_AVG_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2011.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2012.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2013.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2014.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2015.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2016.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2018.nc
# vsm_CONUS404_ANALYSIS_MAX_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2011.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2012.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2013.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2014.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2015.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2016.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2018.nc
# vsm_CONUS404_ANALYSIS_MIN_Daily_2017.nc
# vsm_CONUS404_ANALYSIS_Abs_2011.nc
# vsm_CONUS404_ANALYSIS_Abs_2012.nc
# vsm_CONUS404_ANALYSIS_Abs_2013.nc
# vsm_CONUS404_ANALYSIS_Abs_2015.nc
# vsm_CONUS404_ANALYSIS_Abs_2016.nc
# vsm_CONUS404_ANALYSIS_Abs_2017.nc
# vsm_CONUS404_ANALYSIS_Abs_2018.nc
# vsm_CONUS404_ANALYSIS_Abs_2017.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2011.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2012.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2013.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2014.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2015.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2016.nc
# t2_CONUS404_ANALYSIS_AVG_Daily_2017.nc
# d2_CONUS404_ANALYSIS_MIN_Daily_2018.nc
# d2_CONUS404_ANALYSIS_Abs_2011.nc
# d2_CONUS404_ANALYSIS_Abs_2012.nc
# d2_CONUS404_ANALYSIS_Abs_2013.nc
# d2_CONUS404_ANALYSIS_Abs_2014.nc
# d2_CONUS404_ANALYSIS_Abs_2015.nc
# d2_CONUS404_ANALYSIS_Abs_2016.nc
# d2_CONUS404_ANALYSIS_Abs_2017.nc
# d2_CONUS404_ANALYSIS_Abs_2018.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2011.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2012.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2013.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2014.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2015.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2016.nc
# u10_CONUS404_ANALYSIS_AVG_Daily_2017.nc

# %% [markdown]
# # For Harmonic Normals and Anomalies

# %%
harms = ['anoms', 'climos']

for m in model_options:
    for h in harms:
        dir_maker(f'database_files_final/{m}/{h}')

# %%
def get_harmonic(m, v, ac):


    '' This function is designed to generate specific attribute information for harmonics. 
    
    Inputs:
    
    m: (s) model name
    v: (s) variable name
    ac: (s) anomaly or normal harmonic 
    
    Outputs:
    
    harm_dict: (s) attribute information for harmonic
    
    '''


    k_vals = {'CONUS404': '5',
              'ERA5':  '5',
              'HRRR':  '5',
              'NAM':  '5',
              'NARR': '3 (only 2011-2014 available)',
              'NCEP':  '5',
              'UFS_S2S':  '5'}
  
    k_out = k_vals[m]

    if m == 'NAM':
        if v == 'cape' or v == 'gust':

            k_out = '1 (only 2017-2018 available)'

    if ac == 'anoms':

        harm_dict = f'Anomaly generated by taking the difference of the timeseries with the period normal which was computed as the sum of the first ({kout}) harmonics'

    else:

        harm_dict = f'Period normal computed as the sum of the first ({k_out}) harmonics'
            
    
    return harm_dict

# %%
def special_NCEP_cleaner_ac(db_file, v, f):

    ''' This function takes problematic NCEP Renalysis II files from the database 
        and adds a missing time dimension that got lost or selects one level, and 
        changes -inf values to np.nan for consistency. 
    
    
    Inputs:
    
    db_file: (xarray dataset) a NCEP Renalysis file opened with xarray
    v: (str) variable name
    f: (str) file name -- not path, just filename from final_clean_db function
    
    Outputs:
    
    db_file: (xarray dataset) the new, cleaned version of the input 
    
    '''
    

    if 'level' in list(db_file.dims):

        db_file = db_file.isel(level = 0)
        db_file = db_file.drop('level')

    if 'level' in list(db_file.coords):
        
        db_file = db_file.drop('level')        

    db_file[v] = xr.where(db_file[v] == -np.Inf, np.nan, db_file[v])

    try:
    
        db_file = db_file.rename({'lat': 'latitude', 'lon': 'longitude'})

    except:
        pass

    return db_file

# %%
def final_clean_db_ac(m, vars, ac):

    ''' This function takes database files and unifies all variable and coordinate names, 
    alters the file out names, performs any cleaning still necessary, assigns attributes
    and information such as units, exporting to the database_files_final directory. 

    This function assumes that CONUS404, HRRR, NAM, and NARR have already been regridded. 
    These 4 models were already 'cleaned' through the regridding process. 
    
    Inputs:
    
    m: (s) model name
    vars: (list of strings) list of variable names for the model 
    
    Outputs:
    
    Nothing, files are just saved to specified output directory. 
    
    '''

    
    vars_dict = {}                                                                                                                                # Initialize a dictionary to store variable mappings
                                                                   
    for v in vars:                                                                                                                                # Iterate over variables
        vars_dict[v.split('_')[0]] = v                                                                                                            # Map the first part of the variable name to the full variable name
                                                                   
    if m == 'ERA5' or m == 'NCEP':                                                                                                                # Check if the model is ERA5 or NCEP
        input_dir = f'database_files/{m}/{ac}'                                                                                                    # Set the input directory for standard models
    
    else:                                                          
        input_dir = f'database_files_regridded/{ac}/{m}'                                                                                          # Set the input directory for regridded models

    bad = []
    
    for f in sorted(os.listdir(input_dir)):                                                                                                       # Iterate over sorted files in the input directory
        
        try:
        
            if f[-2:] == 'nc':                                                                                                                    # Check if the file is a NetCDF file
                file = f'{input_dir}/{f}'                                                                                                         # Construct the full file path
                db_file = xr.open_dataset(file)                                                                                                  

                file_split = file.split('/')[-1].split('_')
                v = vars_dict[file_split[0]]                                                                                                      # Extract the variable name from the file name
        
                if ac == 'anoms':
        
                    ac_file = f'ANOM'
        
                else:
        
                    ac_file = f'NORM'
                  
                if 'Daily' in file.split('/')[-1].split('_'):
        
                    if m == 'NARR':
                        possible = ['MIN', 'MAX', 'AVG']
                        outfile_pre = f'{list(set(possible) & set(file_split))[0]}_{ac_file}_{get_filename(m)}_Daily_{file.split('/')[-1].split('_')[-1]}'           # Prepare the output file prefix
        
                    else:
                        
                        outfile_pre = f'{file_split[1]}_{ac_file}_{get_filename(m)}_Daily_{file.split('/')[-1].split('_')[-1]}'                                      # Prepare the output file prefix
        
                else:
                
                    outfile_pre = f'{ac_file}_{get_filename(m)}_Abs_{file.split('/')[-1].split('_')[-1]}'                                                            # Prepare the output file prefix
        
                searchkey = list(variables_by_model[m].keys())[list(variables_by_model[m].values()).index(v)]                                                        # Find the search key for the variable
                newkey = var_names_units[searchkey]                                                                                                                  # Get the new variable name and units

                try:

                    if newkey['name'] != v:
                        db_file[newkey['name']] = db_file[v]                                                                                                         # Update the variable name
                        db_file = db_file.drop(v)                                                                                                                    # Drop the old variable name

                    elif newkey['name'] == v:

                        try:
                            
                            db_file[newkey['name']] = db_file[v]                                                                                                     # Update the variable name

                        except KeyError:
                            
                            if ac == 'anoms':
                                v = f'{v}_anoms'
                
                            else:
                                v = f'{v}_climo'                        
                            
                            db_file[newkey['name']] = db_file[v]                                                                                                     # Update the variable name
                            db_file = db_file.drop(v)                                                                                                                # Drop the old variable name
                    
                
                except KeyError:
    
                    try:
                    
                        if ac == 'anoms':
                            v = f'{v}_anoms'
            
                        else:
                            v = f'{v}_climo'
                        
                        if newkey['name'] != v:
                            db_file[newkey['name']] = db_file[v]                                                                                                    # Update the variable name
                            db_file = db_file.drop(v)                                                                                                               # Drop the old variable name

                    except:
                        
                        raise                                                                  
                
                attrs_to_del = []                                                                                                                                   # Clear old attributes 
    
                for key, item in db_file.attrs.items():
                    attrs_to_del.append(key)
                
                for i in attrs_to_del:
                    del db_file.attrs[i]
    
                attrs_to_del_var = []                                                                                                                               # Clear old attributes             
                
                for key, item in db_file[newkey['name']].attrs.items():
                    attrs_to_del_var.append(key)
                
                for j in attrs_to_del_var:
                    del db_file[newkey['name']].attrs[j]  
                            
                db_file[newkey['name']] = db_file[newkey['name']].assign_attrs({'Variable Name': newkey['long'], 'Units': newkey['units'], 'Harmonic': get_harmonic(m, newkey['name'], ac)})    # Assign new attributes
        
                if m == 'ERA5' or m == 'NCEP':                                                                                                                               # Handle attributes for ERA5 and NCEP
                    db_file = db_file.assign_attrs({'Original Grid': 'latlon', 'New Regrid': 'no regridding, latlon'})                                                  
                else:                                                  
                    db_file = db_file.assign_attrs({'Original Grid': 'Lambert Conformal', 'New Regrid': 'latlon'})                                                           # Handle attributes for other models
                                                          
                if m == 'CONUS404':                                                                                                                                          # Special handling for CONUS404 model
                    db_file = db_file.rename({'Time': 'time'})                                                                                        
                elif m == 'NCEP':                                                                                                                                            # Special cleaning for NCEP model
                    db_file = special_NCEP_cleaner_ac(db_file, newkey['name'], f)                            
                                
                elif m == 'NAM':                            
                    try:                            
                        db_file = db_file.groupby('time').first()                            
                    except:                            
                        pass                            
                            
                vars_to_keep = ['latitude', 'longitude', 'time', newkey['name']]                            
                for vout in list(db_file.variables):                            
                    if vout not in vars_to_keep:                            
                        db_file = db_file.drop(vout)                            
                                            
                db_file = db_file.sortby('time')                                                                                                                             # Sort the dataset by time
                            
                outfile = f'{newkey['name']}_{outfile_pre}'                                                                                                                  # Construct the final output file name
                print(outfile)                                                                                                                                                                                                                   
                db_file.to_netcdf(f'database_files_final/{m}/{ac}/{outfile}')                                                                                                # Save the dataset to a NetCDF file
                                            
                                                                                                                                   
                del outfile                                                                                                                      
        
        except:
    
            bad.append(f)
    
    return bad

# %% [markdown]
# ### ERA5

# %%
m = 'ERA5'

# %%
era_vars = [value for key,value in variables_by_model[m].items()]

# %%
era_vars
# Out:
# ['blh',
#  'cape',
#  'swvl1',
#  'u10',
#  'v10',
#  'i10fg',
#  'tp',
#  'cp',
#  'lsrr',
#  't2m',
#  'd2m',
#  'rh',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_eras = []

for ac in harms:
    print(f'{ac} for {m}')
    bad_eras.append(final_clean_db_ac(m, era_vars, ac))
# Out:
# anoms for ERA5
# pbl_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# pbl_ANOM_ERA5_REANALYSIS_Abs_period.nc
# pbl_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# pbl_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# cape_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# cape_ANOM_ERA5_REANALYSIS_Abs_period.nc
# cape_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# cape_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tcp_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tcp_ANOM_ERA5_REANALYSIS_Abs_period.nc
# tcp_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tcp_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# d2_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# d2_ANOM_ERA5_REANALYSIS_Abs_period.nc
# d2_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# d2_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_ANOM_ERA5_REANALYSIS_Abs_period.nc
# ffwi_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# hdw_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# hdw_ANOM_ERA5_REANALYSIS_Abs_period.nc
# hdw_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# hdw_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# gust_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# gust_ANOM_ERA5_REANALYSIS_Abs_period.nc
# gust_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# gust_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# lspr_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# lspr_ANOM_ERA5_REANALYSIS_Abs_period.nc
# lspr_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# lspr_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# rh_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# rh_ANOM_ERA5_REANALYSIS_Abs_period.nc
# rh_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# rh_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vsm_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vsm_ANOM_ERA5_REANALYSIS_Abs_period.nc
# vsm_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vsm_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# t2_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# t2_ANOM_ERA5_REANALYSIS_Abs_period.nc
# t2_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# t2_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tp_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tp_ANOM_ERA5_REANALYSIS_Abs_period.nc
# tp_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# tp_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# u10_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# u10_ANOM_ERA5_REANALYSIS_Abs_period.nc
# u10_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# u10_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# v10_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# v10_ANOM_ERA5_REANALYSIS_Abs_period.nc
# v10_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# v10_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vpd_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vpd_ANOM_ERA5_REANALYSIS_Abs_period.nc
# vpd_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# vpd_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# wd_AVG_ANOM_ERA5_REANALYSIS_Daily_period.nc
# wd_ANOM_ERA5_REANALYSIS_Abs_period.nc
# wd_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# wd_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# ws_ANOM_ERA5_REANALYSIS_Abs_period.nc
# ws_MAX_ANOM_ERA5_REANALYSIS_Daily_period.nc
# ws_MIN_ANOM_ERA5_REANALYSIS_Daily_period.nc
# climos for ERA5
# pbl_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# pbl_NORM_ERA5_REANALYSIS_Abs_period.nc
# pbl_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# pbl_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# cape_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# cape_NORM_ERA5_REANALYSIS_Abs_period.nc
# cape_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# cape_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# tcp_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# tcp_NORM_ERA5_REANALYSIS_Abs_period.nc
# tcp_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# tcp_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# d2_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# d2_NORM_ERA5_REANALYSIS_Abs_period.nc
# d2_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# d2_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_NORM_ERA5_REANALYSIS_Abs_period.nc
# ffwi_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# ffwi_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# hdw_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# hdw_NORM_ERA5_REANALYSIS_Abs_period.nc
# hdw_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# hdw_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# gust_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# gust_NORM_ERA5_REANALYSIS_Abs_period.nc
# gust_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# gust_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# lspr_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# lspr_NORM_ERA5_REANALYSIS_Abs_period.nc
# lspr_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# lspr_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# rh_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# rh_NORM_ERA5_REANALYSIS_Abs_period.nc
# rh_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# rh_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# vsm_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# vsm_NORM_ERA5_REANALYSIS_Abs_period.nc
# vsm_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# vsm_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# t2_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# t2_NORM_ERA5_REANALYSIS_Abs_period.nc
# t2_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# t2_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# tp_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# tp_NORM_ERA5_REANALYSIS_Abs_period.nc
# tp_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# tp_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# u10_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# u10_NORM_ERA5_REANALYSIS_Abs_period.nc
# u10_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# u10_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# v10_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# v10_NORM_ERA5_REANALYSIS_Abs_period.nc
# v10_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# v10_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# vpd_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# vpd_NORM_ERA5_REANALYSIS_Abs_period.nc
# vpd_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# vpd_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# wd_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# wd_NORM_ERA5_REANALYSIS_Abs_period.nc
# wd_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# wd_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# ws_AVG_NORM_ERA5_REANALYSIS_Daily_period.nc
# ws_NORM_ERA5_REANALYSIS_Abs_period.nc
# ws_MAX_NORM_ERA5_REANALYSIS_Daily_period.nc
# ws_MIN_NORM_ERA5_REANALYSIS_Daily_period.nc
# CPU times: user 5.07 s, sys: 29min, total: 29min 5s
# Wall time: 44min 10s

# %%
bad_eras
# Out:
# [[], []]

# %% [markdown]
# ### NCEP

# %%
m = 'NCEP'

# %%
ncep_vars = [value for key,value in variables_by_model[m].items()]

# %%
ncep_vars
# Out:
# ['soilw',
#  'uwnd',
#  'vwnd',
#  'prate',
#  'air',
#  'rhum',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_nceps = []

for ac in harms[1:]:
    print(f'{ac} for {m}')
    bad_nceps.append(final_clean_db_ac(m, ncep_vars, ac))
# Out:
# climos for NCEP
# t2_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# t2_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# t2_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# t2_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# ffwi_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ffwi_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ffwi_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ffwi_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# hdw_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# hdw_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# hdw_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# hdw_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# prate_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# prate_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# prate_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# prate_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# rh_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# rh_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# rh_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# rh_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# sm_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# sm_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# sm_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# sm_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# u10_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# u10_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# u10_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# u10_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# vpd_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# vpd_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# vpd_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# vpd_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# v10_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# v10_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# v10_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# v10_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# wd_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# wd_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# wd_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# wd_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# ws_AVG_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ws_MAX_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ws_MIN_NORM_NCEP_REANALYSIS_V2_Daily_period.nc
# ws_NORM_NCEP_REANALYSIS_V2_Abs_period.nc
# CPU times: user 6.19 s, sys: 22.3 s, total: 28.5 s
# Wall time: 1min 5s

# %%
bad_nceps
# Out:
# [[]]

# %% [markdown]
# ### NARR

# %%
m = 'NARR'

# %%
narr_vars = [value for key,value in variables_by_model[m].items()]

# %%
narr_vars
# Out:
# ['Planetary_boundary_layer_height_surface',
#  'Soil_moisture_content_layer_between_two_depths_below_surface_layer',
#  'u-component_of_wind_height_above_ground',
#  'v-component_of_wind_height_above_ground',
#  'Precipitation_rate_surface',
#  'Total_precipitation_surface_3_Hour_Accumulation',
#  'Temperature_height_above_ground',
#  'Relative_humidity_height_above_ground',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_narr = []

for ac in harms:
    print(f'{ac} for {m}')
    bad_narr.append(final_clean_db_ac(m, narr_vars, ac))
# Out:
# anoms for NARR
# pbl_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# pbl_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# pbl_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# pbl_ANOM_NARR_REANALYSIS_Abs_period.nc
# prate_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# prate_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# prate_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# prate_ANOM_NARR_REANALYSIS_Abs_period.nc
# rh_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# rh_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# rh_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# rh_ANOM_NARR_REANALYSIS_Abs_period.nc
# sm_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# sm_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# sm_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# sm_ANOM_NARR_REANALYSIS_Abs_period.nc
# t2_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# t2_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# t2_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# t2_ANOM_NARR_REANALYSIS_Abs_period.nc
# tp_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# tp_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# tp_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# tp_ANOM_NARR_REANALYSIS_Abs_period.nc
# hdw_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# hdw_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# hdw_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# hdw_ANOM_NARR_REANALYSIS_Abs_period.nc
# u10_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# u10_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# u10_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# u10_ANOM_NARR_REANALYSIS_Abs_period.nc
# v10_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# v10_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# v10_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# v10_ANOM_NARR_REANALYSIS_Abs_period.nc
# wd_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# wd_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# wd_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# wd_ANOM_NARR_REANALYSIS_Abs_period.nc
# ws_AVG_ANOM_NARR_REANALYSIS_Daily_period.nc
# ws_MAX_ANOM_NARR_REANALYSIS_Daily_period.nc
# ws_MIN_ANOM_NARR_REANALYSIS_Daily_period.nc
# ws_ANOM_NARR_REANALYSIS_Abs_period.nc
# climos for NARR
# pbl_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# pbl_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# pbl_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# pbl_NORM_NARR_REANALYSIS_Abs_period.nc
# prate_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# prate_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# prate_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# prate_NORM_NARR_REANALYSIS_Abs_period.nc
# rh_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# rh_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# rh_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# rh_NORM_NARR_REANALYSIS_Abs_period.nc
# sm_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# sm_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# sm_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# sm_NORM_NARR_REANALYSIS_Abs_period.nc
# t2_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# t2_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# t2_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# t2_NORM_NARR_REANALYSIS_Abs_period.nc
# tp_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# tp_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# tp_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# tp_NORM_NARR_REANALYSIS_Abs_period.nc
# ffwi_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# ffwi_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# ffwi_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# ffwi_NORM_NARR_REANALYSIS_Abs_period.nc
# hdw_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# hdw_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# hdw_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# hdw_NORM_NARR_REANALYSIS_Abs_period.nc
# u10_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# u10_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# u10_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# u10_NORM_NARR_REANALYSIS_Abs_period.nc
# v10_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# v10_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# v10_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# v10_NORM_NARR_REANALYSIS_Abs_period.nc
# vpd_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# vpd_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# vpd_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# vpd_NORM_NARR_REANALYSIS_Abs_period.nc
# wd_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# wd_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# wd_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# wd_NORM_NARR_REANALYSIS_Abs_period.nc
# ws_AVG_NORM_NARR_REANALYSIS_Daily_period.nc
# ws_MAX_NORM_NARR_REANALYSIS_Daily_period.nc
# ws_MIN_NORM_NARR_REANALYSIS_Daily_period.nc
# ws_NORM_NARR_REANALYSIS_Abs_period.nc
# CPU times: user 2min 33s, sys: 11min, total: 13min 33s
# Wall time: 18min 16s

# %%
bad_narr

# %% [markdown]
# ### NAM

# %%
m = 'NAM'

# %%
nam_vars = [value for key,value in variables_by_model[m].items()]

# %%
nam_vars
# Out:
# ['hpbl',
#  'cape',
#  'sm',
#  'u10',
#  'v10',
#  'gust',
#  'tp',
#  't2m',
#  'r',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi']

# %%
# %%time

bad_nam = []

for ac in harms:
    print(f'{ac} for {m}')
    bad_nam.append(final_clean_db_ac(m, nam_vars, ac))
# Out:
# anoms for NAM
# cape_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# cape_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# cape_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# cape_ANOM_NAM_HISTORICAL_Abs_period.nc
# ffwi_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# ffwi_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# ffwi_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# ffwi_ANOM_NAM_HISTORICAL_Abs_period.nc
# gust_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# gust_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# gust_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# gust_ANOM_NAM_HISTORICAL_Abs_period.nc
# hdw_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# hdw_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# hdw_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# hdw_ANOM_NAM_HISTORICAL_Abs_period.nc
# rh_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# rh_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# rh_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# rh_ANOM_NAM_HISTORICAL_Abs_period.nc
# sm_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# sm_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# sm_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# sm_ANOM_NAM_HISTORICAL_Abs_period.nc
# t2_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# t2_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# t2_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# t2_ANOM_NAM_HISTORICAL_Abs_period.nc
# tp_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# tp_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# tp_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# tp_ANOM_NAM_HISTORICAL_Abs_period.nc
# u10_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# u10_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# u10_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# u10_ANOM_NAM_HISTORICAL_Abs_period.nc
# v10_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# v10_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# v10_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# v10_ANOM_NAM_HISTORICAL_Abs_period.nc
# vpd_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# vpd_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# vpd_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# vpd_ANOM_NAM_HISTORICAL_Abs_period.nc
# wd_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# wd_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# wd_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# wd_ANOM_NAM_HISTORICAL_Abs_period.nc
# ws_AVG_ANOM_NAM_HISTORICAL_Daily_period.nc
# ws_MAX_ANOM_NAM_HISTORICAL_Daily_period.nc
# ws_MIN_ANOM_NAM_HISTORICAL_Daily_period.nc
# ws_ANOM_NAM_HISTORICAL_Abs_period.nc
# climos for NAM
# cape_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# cape_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# cape_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# cape_NORM_NAM_HISTORICAL_Abs_period.nc
# ffwi_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# ffwi_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# ffwi_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# ffwi_NORM_NAM_HISTORICAL_Abs_period.nc
# gust_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# gust_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# gust_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# gust_NORM_NAM_HISTORICAL_Abs_period.nc
# hdw_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# hdw_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# hdw_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# rh_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# rh_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# rh_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# sm_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# sm_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# sm_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# t2_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# t2_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# t2_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# tp_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# tp_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# tp_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# tp_NORM_NAM_HISTORICAL_Abs_period.nc
# u10_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# u10_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# u10_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# v10_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# v10_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# v10_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# vpd_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# vpd_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# vpd_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# wd_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# wd_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# wd_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# ws_AVG_NORM_NAM_HISTORICAL_Daily_period.nc
# ws_MAX_NORM_NAM_HISTORICAL_Daily_period.nc
# ws_MIN_NORM_NAM_HISTORICAL_Daily_period.nc
# CPU times: user 24min 18s, sys: 47min 7s, total: 1h 11min 25s
# Wall time: 1h 26min 34s

# %%
bad_nam

# %% [markdown]
# ### HRRR

# %%
m = 'HRRR'

# %%
hrrr_vars = [value for key,value in variables_by_model[m].items()]

# %%
hrrr_vars
# Out:
# ['blh',
#  'cape',
#  'mstav',
#  'u10',
#  'v10',
#  'gust',
#  'prate',
#  'tp',
#  't2m',
#  'd2m',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'ffwi',
#  'rh']

# %%
# %%time 

bad_hrrr = []

for ac in harms:
    print(f'{ac} for {m}')
    bad_hrrr.append(final_clean_db_ac(m, hrrr_vars, ac))
# Out:
# anoms for HRRR
# pbl_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# pbl_ANOM_HRRR_HISTORICAL_Abs_period.nc
# pbl_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# pbl_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# cape_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# cape_ANOM_HRRR_HISTORICAL_Abs_period.nc
# cape_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# cape_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# d2_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# d2_ANOM_HRRR_HISTORICAL_Abs_period.nc
# d2_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# d2_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_ANOM_HRRR_HISTORICAL_Abs_period.nc
# ffwi_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# gust_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# gust_ANOM_HRRR_HISTORICAL_Abs_period.nc
# gust_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# gust_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# hdw_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# hdw_ANOM_HRRR_HISTORICAL_Abs_period.nc
# hdw_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# hdw_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# sm_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# sm_ANOM_HRRR_HISTORICAL_Abs_period.nc
# sm_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# sm_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# prate_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# prate_ANOM_HRRR_HISTORICAL_Abs_period.nc
# prate_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# prate_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# rh_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# rh_ANOM_HRRR_HISTORICAL_Abs_period.nc
# rh_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# rh_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# t2_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# t2_ANOM_HRRR_HISTORICAL_Abs_period.nc
# t2_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# t2_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# tp_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# tp_ANOM_HRRR_HISTORICAL_Abs_period.nc
# tp_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# tp_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# u10_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# u10_ANOM_HRRR_HISTORICAL_Abs_period.nc
# u10_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# u10_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# v10_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# v10_ANOM_HRRR_HISTORICAL_Abs_period.nc
# v10_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# v10_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# vpd_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# vpd_ANOM_HRRR_HISTORICAL_Abs_period.nc
# vpd_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# vpd_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# wd_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# wd_ANOM_HRRR_HISTORICAL_Abs_period.nc
# wd_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# wd_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ws_AVG_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ws_ANOM_HRRR_HISTORICAL_Abs_period.nc
# ws_MAX_ANOM_HRRR_HISTORICAL_Daily_period.nc
# ws_MIN_ANOM_HRRR_HISTORICAL_Daily_period.nc
# climos for HRRR
# pbl_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# pbl_NORM_HRRR_HISTORICAL_Abs_period.nc
# pbl_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# pbl_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# cape_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# cape_NORM_HRRR_HISTORICAL_Abs_period.nc
# cape_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# cape_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# d2_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# d2_NORM_HRRR_HISTORICAL_Abs_period.nc
# d2_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# d2_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_NORM_HRRR_HISTORICAL_Abs_period.nc
# ffwi_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# ffwi_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# gust_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# gust_NORM_HRRR_HISTORICAL_Abs_period.nc
# gust_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# gust_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# hdw_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# hdw_NORM_HRRR_HISTORICAL_Abs_period.nc
# hdw_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# hdw_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# sm_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# sm_NORM_HRRR_HISTORICAL_Abs_period.nc
# sm_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# sm_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# prate_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# prate_NORM_HRRR_HISTORICAL_Abs_period.nc
# prate_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# prate_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# rh_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# rh_NORM_HRRR_HISTORICAL_Abs_period.nc
# rh_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# rh_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# t2_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# t2_NORM_HRRR_HISTORICAL_Abs_period.nc
# t2_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# t2_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# tp_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# tp_NORM_HRRR_HISTORICAL_Abs_period.nc
# tp_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# tp_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# u10_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# u10_NORM_HRRR_HISTORICAL_Abs_period.nc
# u10_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# u10_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# v10_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# v10_NORM_HRRR_HISTORICAL_Abs_period.nc
# v10_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# v10_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# vpd_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# vpd_NORM_HRRR_HISTORICAL_Abs_period.nc
# vpd_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# vpd_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# wd_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# wd_NORM_HRRR_HISTORICAL_Abs_period.nc
# wd_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# wd_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# ws_AVG_NORM_HRRR_HISTORICAL_Daily_period.nc
# ws_NORM_HRRR_HISTORICAL_Abs_period.nc
# ws_MAX_NORM_HRRR_HISTORICAL_Daily_period.nc
# ws_MIN_NORM_HRRR_HISTORICAL_Daily_period.nc
# CPU times: user 40min 14s, sys: 2h 27min, total: 3h 7min 14s
# Wall time: 3h 46min 49s

# %%
bad_hrrr
# Out:
# [[], []]

# %% [markdown]
# ### CONUS404

# %%
m = 'CONUS404'

# %%
c44_vars = [value for key,value in variables_by_model[m].items()]

# %%
c44_vars
# Out:
# ['PBLH',
#  'SBCAPE',
#  'MLCAPE',
#  'SMOIS',
#  'U10',
#  'V10',
#  'wspeed',
#  'wdir',
#  'hdwi',
#  'vpd',
#  'PREC_ACC_NC',
#  'T2',
#  'rh',
#  'ffwi',
#  'TD2']

# %%
# %%time

bad_c44 = []

for ac in harms:
    print(f'{ac} for {m}')
    bad_c44.append(final_clean_db_ac(m, c44_vars, ac))
# Out:
# anoms for CONUS404
# mlcape_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# mlcape_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# mlcape_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# mlcape_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# pbl_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# tp_ACC_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# tp_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# tp_ACC_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# tp_ACC_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# sbcape_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# sbcape_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# sbcape_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# sbcape_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# vsm_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# t2_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# t2_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# t2_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# t2_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# d2_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# d2_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# d2_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# d2_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# u10_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# u10_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# u10_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# u10_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# v10_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# v10_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# v10_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# v10_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# ffwi_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# hdw_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# rh_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# rh_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# rh_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# rh_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# vpd_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# wd_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# wd_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# wd_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# wd_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ws_AVG_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ws_ANOM_CONUS404_ANALYSIS_Abs_period.nc
# ws_MAX_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# ws_MIN_ANOM_CONUS404_ANALYSIS_Daily_period.nc
# climos for CONUS404
# mlcape_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# mlcape_NORM_CONUS404_ANALYSIS_Abs_period.nc
# mlcape_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# mlcape_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_NORM_CONUS404_ANALYSIS_Abs_period.nc
# pbl_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# pbl_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# tp_ACC_NORM_CONUS404_ANALYSIS_Daily_period.nc
# tp_NORM_CONUS404_ANALYSIS_Abs_period.nc
# tp_ACC_NORM_CONUS404_ANALYSIS_Daily_period.nc
# tp_ACC_NORM_CONUS404_ANALYSIS_Daily_period.nc
# sbcape_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# sbcape_NORM_CONUS404_ANALYSIS_Abs_period.nc
# sbcape_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_NORM_CONUS404_ANALYSIS_Abs_period.nc
# vsm_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vsm_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# t2_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# t2_NORM_CONUS404_ANALYSIS_Abs_period.nc
# t2_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# t2_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# d2_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# d2_NORM_CONUS404_ANALYSIS_Abs_period.nc
# d2_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# d2_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# u10_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# u10_NORM_CONUS404_ANALYSIS_Abs_period.nc
# u10_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# u10_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# v10_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# v10_NORM_CONUS404_ANALYSIS_Abs_period.nc
# v10_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# v10_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_NORM_CONUS404_ANALYSIS_Abs_period.nc
# ffwi_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ffwi_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_NORM_CONUS404_ANALYSIS_Abs_period.nc
# hdw_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# hdw_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# rh_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# rh_NORM_CONUS404_ANALYSIS_Abs_period.nc
# rh_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# rh_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_NORM_CONUS404_ANALYSIS_Abs_period.nc
# vpd_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# vpd_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# wd_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# wd_NORM_CONUS404_ANALYSIS_Abs_period.nc
# wd_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# wd_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ws_AVG_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ws_NORM_CONUS404_ANALYSIS_Abs_period.nc
# ws_MAX_NORM_CONUS404_ANALYSIS_Daily_period.nc
# ws_MIN_NORM_CONUS404_ANALYSIS_Daily_period.nc
# CPU times: user 55min, sys: 3h 19min 56s, total: 4h 14min 56s
# Wall time: 5h 4min 27s

# %%
bad_c44
# Out:
# [[], []]
